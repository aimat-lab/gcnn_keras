# %%
import time

import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

from kgcnn.data.datasets.cora_lu import CoraLUDataset
from kgcnn.literature.GCN import make_gcn
from kgcnn.literature.GNNExplain import GNNExplainer, GNNInterface
from kgcnn.utils.adj import precompute_adjacency_scaled, sort_edge_indices, make_adjacency_from_edge_indices, \
    make_adjacency_undirected_logical_or, convert_scaled_adjacency_to_list
from kgcnn.utils.data import ragged_tensor_from_nested_numpy
from kgcnn.utils.learning import lr_lin_reduction
# Out:
# Keras utils: Register custom activation:  {'leaky_softplus': <function leaky_softplus at 0x00000234069403A0>, 'shifted_softplus': <function shifted_softplus at 0x0000023406940310>, 'softplus2': <function softplus2 at 0x00000234069401F0>, 'leaky_relu': <function leaky_relu at 0x0000023406940430>, 'swish': <function swish at 0x00000234069404C0>}

# %% [markdown]
# ## Loading graph data

# %%
dataset = CoraLUDataset()
nodes, edge_index, labels, class_label_mapping = dataset.get_graph()
nodes = nodes[:, 1:]  # Remove IDs
edge_index = sort_edge_indices(edge_index)
adj_matrix = make_adjacency_from_edge_indices(edge_index)
adj_matrix = precompute_adjacency_scaled(make_adjacency_undirected_logical_or(adj_matrix))
edge_index, edge_weight = convert_scaled_adjacency_to_list(adj_matrix)
edge_weight = np.expand_dims(edge_weight, axis=-1)
labels = np.expand_dims(labels, axis=-1)
labels = np.array(labels == np.arange(7), dtype=np.float32)

# Find a color to visualize a label
def get_label_color(label):
    return plt.get_cmap('Set1')(label / 7)


# Map label to class
def get_label_name(label):
    return ["Case_Based",
            "Genetic_Algorithms",
            "Neural_Networks",
            "Probabilistic_Methods",
            "Reinforcement_Learning",
            "Rule_Learning",
            "Theory"][label]
# Out:
# INFO: Dataset directory located at C:\Users\Patrick\.kgcnn\datasets
# INFO: Dataset directory found... done
# INFO: Dataset found... done
# INFO: Directory for extraction exists... done
# INFO: Not extracting tar File... stopped

# %% [markdown]
# ## Train test split

# %%
# Make test/train split
# Since only one graph in the dataset
# Use a mask to hide test nodes labels
inds = np.arange(len(labels))
ind_train, ind_val = train_test_split(inds, test_size=0.10, random_state=0)
val_mask = np.zeros_like(inds)
train_mask = np.zeros_like(inds)
val_mask[ind_val] = 1
train_mask[ind_train] = 1
val_mask = np.expand_dims(val_mask, axis=0)  # One graph in batch
train_mask = np.expand_dims(train_mask, axis=0)  # One graph in batch

# Make ragged graph tensors with 1 graph in batch
nodes, edges, edge_indices = ragged_tensor_from_nested_numpy([nodes]), ragged_tensor_from_nested_numpy(
    [edge_weight]), ragged_tensor_from_nested_numpy([edge_index])  # One graph in batch

# Set training data. But requires mask and batch-dimension of 1
xtrain = nodes, edges, edge_indices
ytrain = np.expand_dims(labels, axis=0)  # One graph in batch

# %% [markdown]
# ## Train GCN model on cora dataset

# %%
model = make_gcn(
    input_node_shape=[None, 1433],
    input_edge_shape=[None, 1],
    # Output
    output_embedd={"output_mode": 'node'},
    output_mlp={"use_bias": [True, True, False], "units": [64, 16, 7], "activation": ['relu', 'relu', 'softmax']},
    # model specs
    depth=3,
    gcn_args={"units": 124, "use_bias": True, "activation": "relu", "has_unconnected": True}
)

# Set learning rate and epochs
learning_rate_start = 1e-3
learning_rate_stop = 1e-4
epo = 300
epomin = 260
epostep = 10

# Compile model with optimizer and loss
optimizer = tf.keras.optimizers.Adam(lr=learning_rate_start)
cbks = tf.keras.callbacks.LearningRateScheduler(lr_lin_reduction(learning_rate_start, learning_rate_stop, epomin, epo))
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              weighted_metrics=['categorical_accuracy'])
print(model.summary())

# Training loop
trainlossall = []
testlossall = []
start = time.process_time()
for iepoch in range(0, epo, epostep):
    hist = model.fit(xtrain, ytrain,
                     epochs=iepoch + epostep,
                     initial_epoch=iepoch,
                     batch_size=1,
                     callbacks=[cbks],
                     verbose=2,
                     sample_weight=train_mask  # Important!!!
                     )

    trainlossall.append(hist.history)
    testlossall.append(model.evaluate(xtrain, ytrain, sample_weight=val_mask))
stop = time.process_time()
print("Print Time for taining: ", stop - start)

# Pick out accuracy
testlossall = np.array(testlossall)
trainlossall = np.concatenate([x['categorical_accuracy'] for x in trainlossall])

# Plot loss vs epochs
plt.figure()
plt.plot(np.arange(1, len(trainlossall) + 1), trainlossall, label='Training Loss', c='blue')
plt.plot(np.arange(epostep, epo + epostep, epostep), testlossall[:, 1], label='Test Loss', c='red')
plt.xlabel('Epochs')
plt.ylabel('Accurarcy')
plt.title('GCN')
plt.legend(loc='lower right', fontsize='x-large')
plt.savefig('gcn_explain_loss_cora.png')
plt.show()

# Evaluate model
model.evaluate(xtrain, ytrain, sample_weight=val_mask)
# Out:
# WARNING:tensorflow:From c:\users\patrick\.conda\envs\aimat\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Warning: For [values, partition] tensor input, default node_indexing is considered 'batch'. mlp will use node_indexing sample
# c:\users\patrick\.conda\envs\aimat\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# node_input (InputLayer)         [(None, None, 1433)] 0
# __________________________________________________________________________________________________
# edge_index_input (InputLayer)   [(None, None, 2)]    0
# __________________________________________________________________________________________________
# change_tensor_type (ChangeTenso [(None, 1433), (None 0           node_input[0][0]
# __________________________________________________________________________________________________
# edge_input (InputLayer)         [(None, None, 1)]    0
# __________________________________________________________________________________________________
# change_tensor_type_2 (ChangeTen [(None, 2), (None,)] 0           edge_index_input[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   [(None, 124), (None, 177816      change_tensor_type[0][0]
#                                                                  change_tensor_type[0][1]
# __________________________________________________________________________________________________
# change_tensor_type_1 (ChangeTen [(None, 1), (None,)] 0           edge_input[0][0]
# __________________________________________________________________________________________________
# change_indexing (ChangeIndexing [(None, 2), (None,)] 0           change_tensor_type[0][0]
#                                                                  change_tensor_type[0][1]
#                                                                  change_tensor_type_2[0][0]
#                                                                  change_tensor_type_2[0][1]
# __________________________________________________________________________________________________
# gcn (GCN)                       [(None, 124), (None, 15500       dense[0][0]
#                                                                  dense[0][1]
#                                                                  change_tensor_type_1[0][0]
#                                                                  change_tensor_type_1[0][1]
#                                                                  change_indexing[0][0]
#                                                                  change_indexing[0][1]
# __________________________________________________________________________________________________
# gcn_1 (GCN)                     [(None, 124), (None, 15500       gcn[0][0]
#                                                                  gcn[0][1]
#                                                                  change_tensor_type_1[0][0]
#                                                                  change_tensor_type_1[0][1]
#                                                                  change_indexing[0][0]
#                                                                  change_indexing[0][1]
# __________________________________________________________________________________________________
# gcn_2 (GCN)                     [(None, 124), (None, 15500       gcn_1[0][0]
#                                                                  gcn_1[0][1]
#                                                                  change_tensor_type_1[0][0]
#                                                                  change_tensor_type_1[0][1]
#                                                                  change_indexing[0][0]
#                                                                  change_indexing[0][1]
# __________________________________________________________________________________________________
# mlp (MLP)                       [(None, 7), (None,)] 9152        gcn_2[0][0]
#                                                                  gcn_2[0][1]
# __________________________________________________________________________________________________
# change_tensor_type_3 (ChangeTen (None, None, 7)      0           mlp[0][0]
#                                                                  mlp[0][1]
# ==================================================================================================
# Total params: 233,468
# Trainable params: 233,468
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/10
# c:\users\patrick\.conda\envs\aimat\lib\site-packages\tensorflow\python\framework\indexed_slices.py:447: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradients/RaggedToTensor/RaggedTensorToTensor_grad/boolean_mask_1/GatherV2:0", shape=(None,), dtype=int32), values=Tensor("gradients/RaggedToTensor/RaggedTensorToTensor_grad/boolean_mask/GatherV2:0", shape=(None, 7), dtype=float32), dense_shape=Tensor("gradients/RaggedToTensor/RaggedTensorToTensor_grad/Shape:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# c:\users\patrick\.conda\envs\aimat\lib\site-packages\tensorflow\python\framework\indexed_slices.py:447: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn_2/pooling_weighted_local_edges_2/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/gcn_2/pooling_weighted_local_edges_2/Reshape:0", shape=(None, 124), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn_2/pooling_weighted_local_edges_2/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# c:\users\patrick\.conda\envs\aimat\lib\site-packages\tensorflow\python\framework\indexed_slices.py:447: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn_2/gather_nodes_outgoing_2/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/gcn_2/gather_nodes_outgoing_2/Reshape:0", shape=(None, 124), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn_2/gather_nodes_outgoing_2/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# c:\users\patrick\.conda\envs\aimat\lib\site-packages\tensorflow\python\framework\indexed_slices.py:447: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn_1/pooling_weighted_local_edges_1/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/gcn_1/pooling_weighted_local_edges_1/Reshape:0", shape=(None, 124), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn_1/pooling_weighted_local_edges_1/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# c:\users\patrick\.conda\envs\aimat\lib\site-packages\tensorflow\python\framework\indexed_slices.py:447: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn_1/gather_nodes_outgoing_1/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/gcn_1/gather_nodes_outgoing_1/Reshape:0", shape=(None, 124), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn_1/gather_nodes_outgoing_1/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# c:\users\patrick\.conda\envs\aimat\lib\site-packages\tensorflow\python\framework\indexed_slices.py:447: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn/pooling_weighted_local_edges/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/gcn/pooling_weighted_local_edges/Reshape:0", shape=(None, 124), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn/pooling_weighted_local_edges/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# c:\users\patrick\.conda\envs\aimat\lib\site-packages\tensorflow\python\framework\indexed_slices.py:447: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn/gather_nodes_outgoing/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/gcn/gather_nodes_outgoing/Reshape:0", shape=(None, 124), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn/gather_nodes_outgoing/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# 1/1 - 3s - loss: 1.7527 - categorical_accuracy: 0.1485
# Epoch 2/10
# 1/1 - 0s - loss: 1.7432 - categorical_accuracy: 0.3299
# Epoch 3/10
# 1/1 - 0s - loss: 1.7348 - categorical_accuracy: 0.4177
# Epoch 4/10
# 1/1 - 0s - loss: 1.7234 - categorical_accuracy: 0.4382
# Epoch 5/10
# 1/1 - 0s - loss: 1.7090 - categorical_accuracy: 0.4391
# Epoch 6/10
# 1/1 - 0s - loss: 1.6897 - categorical_accuracy: 0.4571
# Epoch 7/10
# 1/1 - 0s - loss: 1.6648 - categorical_accuracy: 0.4805
# Epoch 8/10
# 1/1 - 0s - loss: 1.6344 - categorical_accuracy: 0.5059
# Epoch 9/10
# 1/1 - 0s - loss: 1.5984 - categorical_accuracy: 0.5269
# Epoch 10/10
# 1/1 - 0s - loss: 1.5569 - categorical_accuracy: 0.5478
# 1/1 [==============================] - 1s 639ms/step - loss: 0.1712 - categorical_accuracy: 0.5240
# Epoch 11/20
# 1/1 - 0s - loss: 1.5089 - categorical_accuracy: 0.5531
# Epoch 12/20
# 1/1 - 0s - loss: 1.4547 - categorical_accuracy: 0.5572
# Epoch 13/20
# 1/1 - 0s - loss: 1.3944 - categorical_accuracy: 0.5577
# Epoch 14/20
# 1/1 - 0s - loss: 1.3277 - categorical_accuracy: 0.5696
# Epoch 15/20
# 1/1 - 0s - loss: 1.2560 - categorical_accuracy: 0.5991
# Epoch 16/20
# 1/1 - 0s - loss: 1.1804 - categorical_accuracy: 0.6221
# Epoch 17/20
# 1/1 - 0s - loss: 1.1032 - categorical_accuracy: 0.6315
# Epoch 18/20
# 1/1 - 0s - loss: 1.0260 - categorical_accuracy: 0.6512
# Epoch 19/20
# 1/1 - 0s - loss: 0.9503 - categorical_accuracy: 0.6816
# Epoch 20/20
# 1/1 - 0s - loss: 0.8782 - categorical_accuracy: 0.7074
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1003 - categorical_accuracy: 0.7085
# Epoch 21/30
# 1/1 - 0s - loss: 0.8108 - categorical_accuracy: 0.7390
# Epoch 22/30
# 1/1 - 0s - loss: 0.7487 - categorical_accuracy: 0.7538
# Epoch 23/30
# 1/1 - 0s - loss: 0.6929 - categorical_accuracy: 0.7636
# Epoch 24/30
# 1/1 - 0s - loss: 0.6415 - categorical_accuracy: 0.7710
# Epoch 25/30
# 1/1 - 0s - loss: 0.5910 - categorical_accuracy: 0.7772
# Epoch 26/30
# 1/1 - 0s - loss: 0.5428 - categorical_accuracy: 0.8182
# Epoch 27/30
# 1/1 - 0s - loss: 0.4975 - categorical_accuracy: 0.8449
# Epoch 28/30
# 1/1 - 0s - loss: 0.4577 - categorical_accuracy: 0.8703
# Epoch 29/30
# 1/1 - 0s - loss: 0.4264 - categorical_accuracy: 0.8789
# Epoch 30/30
# 1/1 - 0s - loss: 0.3997 - categorical_accuracy: 0.8831
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0507 - categorical_accuracy: 0.8745
# Epoch 31/40
# 1/1 - 0s - loss: 0.3763 - categorical_accuracy: 0.8806
# Epoch 32/40
# 1/1 - 0s - loss: 0.3583 - categorical_accuracy: 0.8806
# Epoch 33/40
# 1/1 - 0s - loss: 0.3427 - categorical_accuracy: 0.8826
# Epoch 34/40
# 1/1 - 0s - loss: 0.3274 - categorical_accuracy: 0.8913
# Epoch 35/40
# 1/1 - 0s - loss: 0.3147 - categorical_accuracy: 0.8966
# Epoch 36/40
# 1/1 - 0s - loss: 0.3063 - categorical_accuracy: 0.8986
# Epoch 37/40
# 1/1 - 0s - loss: 0.2974 - categorical_accuracy: 0.9023
# Epoch 38/40
# 1/1 - 0s - loss: 0.2889 - categorical_accuracy: 0.9048
# Epoch 39/40
# 1/1 - 0s - loss: 0.2844 - categorical_accuracy: 0.9081
# Epoch 40/40
# 1/1 - 0s - loss: 0.2751 - categorical_accuracy: 0.9073
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0508 - categorical_accuracy: 0.8745
# Epoch 41/50
# 1/1 - 0s - loss: 0.2570 - categorical_accuracy: 0.9138
# Epoch 42/50
# 1/1 - 0s - loss: 0.2559 - categorical_accuracy: 0.9126
# Epoch 43/50
# 1/1 - 0s - loss: 0.2472 - categorical_accuracy: 0.9114
# Epoch 44/50
# 1/1 - 0s - loss: 0.2370 - categorical_accuracy: 0.9163
# Epoch 45/50
# 1/1 - 0s - loss: 0.2350 - categorical_accuracy: 0.9151
# Epoch 46/50
# 1/1 - 0s - loss: 0.2245 - categorical_accuracy: 0.9208
# Epoch 47/50
# 1/1 - 0s - loss: 0.2228 - categorical_accuracy: 0.9220
# Epoch 48/50
# 1/1 - 0s - loss: 0.2150 - categorical_accuracy: 0.9249
# Epoch 49/50
# 1/1 - 0s - loss: 0.2119 - categorical_accuracy: 0.9241
# Epoch 50/50
# 1/1 - 0s - loss: 0.2070 - categorical_accuracy: 0.9274
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0526 - categorical_accuracy: 0.8782
# Epoch 51/60
# 1/1 - 0s - loss: 0.2009 - categorical_accuracy: 0.9261
# Epoch 52/60
# 1/1 - 0s - loss: 0.2001 - categorical_accuracy: 0.9278
# Epoch 53/60
# 1/1 - 0s - loss: 0.1956 - categorical_accuracy: 0.9286
# Epoch 54/60
# 1/1 - 0s - loss: 0.1970 - categorical_accuracy: 0.9233
# Epoch 55/60
# 1/1 - 0s - loss: 0.1974 - categorical_accuracy: 0.9274
# Epoch 56/60
# 1/1 - 0s - loss: 0.1845 - categorical_accuracy: 0.9348
# Epoch 57/60
# 1/1 - 0s - loss: 0.1852 - categorical_accuracy: 0.9307
# Epoch 58/60
# 1/1 - 0s - loss: 0.1850 - categorical_accuracy: 0.9307
# Epoch 59/60
# 1/1 - 0s - loss: 0.1769 - categorical_accuracy: 0.9372
# Epoch 60/60
# 1/1 - 0s - loss: 0.1773 - categorical_accuracy: 0.9331
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0587 - categorical_accuracy: 0.8745
# Epoch 61/70
# 1/1 - 0s - loss: 0.1747 - categorical_accuracy: 0.9360
# Epoch 62/70
# 1/1 - 0s - loss: 0.1678 - categorical_accuracy: 0.9397
# Epoch 63/70
# 1/1 - 0s - loss: 0.1694 - categorical_accuracy: 0.9384
# Epoch 64/70
# 1/1 - 0s - loss: 0.1617 - categorical_accuracy: 0.9413
# Epoch 65/70
# 1/1 - 0s - loss: 0.1630 - categorical_accuracy: 0.9409
# Epoch 66/70
# 1/1 - 0s - loss: 0.1577 - categorical_accuracy: 0.9446
# Epoch 67/70
# 1/1 - 0s - loss: 0.1570 - categorical_accuracy: 0.9442
# Epoch 68/70
# 1/1 - 0s - loss: 0.1540 - categorical_accuracy: 0.9413
# Epoch 69/70
# 1/1 - 0s - loss: 0.1509 - categorical_accuracy: 0.9421
# Epoch 70/70
# 1/1 - 0s - loss: 0.1503 - categorical_accuracy: 0.9446
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0603 - categorical_accuracy: 0.8782
# Epoch 71/80
# 1/1 - 0s - loss: 0.1456 - categorical_accuracy: 0.9471
# Epoch 72/80
# 1/1 - 0s - loss: 0.1463 - categorical_accuracy: 0.9426
# Epoch 73/80
# 1/1 - 0s - loss: 0.1414 - categorical_accuracy: 0.9487
# Epoch 74/80
# 1/1 - 0s - loss: 0.1419 - categorical_accuracy: 0.9479
# Epoch 75/80
# 1/1 - 0s - loss: 0.1382 - categorical_accuracy: 0.9454
# Epoch 76/80
# 1/1 - 0s - loss: 0.1368 - categorical_accuracy: 0.9483
# Epoch 77/80
# 1/1 - 0s - loss: 0.1351 - categorical_accuracy: 0.9495
# Epoch 78/80
# 1/1 - 0s - loss: 0.1325 - categorical_accuracy: 0.9508
# Epoch 79/80
# 1/1 - 0s - loss: 0.1309 - categorical_accuracy: 0.9487
# Epoch 80/80
# 1/1 - 0s - loss: 0.1293 - categorical_accuracy: 0.9524
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0640 - categorical_accuracy: 0.8708
# Epoch 81/90
# 1/1 - 0s - loss: 0.1269 - categorical_accuracy: 0.9549
# Epoch 82/90
# 1/1 - 0s - loss: 0.1251 - categorical_accuracy: 0.9540
# Epoch 83/90
# 1/1 - 0s - loss: 0.1241 - categorical_accuracy: 0.9553
# Epoch 84/90
# 1/1 - 0s - loss: 0.1215 - categorical_accuracy: 0.9561
# Epoch 85/90
# 1/1 - 0s - loss: 0.1198 - categorical_accuracy: 0.9553
# Epoch 86/90
# 1/1 - 0s - loss: 0.1191 - categorical_accuracy: 0.9569
# Epoch 87/90
# 1/1 - 0s - loss: 0.1167 - categorical_accuracy: 0.9573
# Epoch 88/90
# 1/1 - 0s - loss: 0.1148 - categorical_accuracy: 0.9577
# Epoch 89/90
# 1/1 - 0s - loss: 0.1141 - categorical_accuracy: 0.9590
# Epoch 90/90
# 1/1 - 0s - loss: 0.1123 - categorical_accuracy: 0.9586
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0674 - categorical_accuracy: 0.8745
# Epoch 91/100
# 1/1 - 0s - loss: 0.1103 - categorical_accuracy: 0.9610
# Epoch 92/100
# 1/1 - 0s - loss: 0.1088 - categorical_accuracy: 0.9618
# Epoch 93/100
# 1/1 - 0s - loss: 0.1075 - categorical_accuracy: 0.9618
# Epoch 94/100
# 1/1 - 0s - loss: 0.1063 - categorical_accuracy: 0.9618
# Epoch 95/100
# 1/1 - 0s - loss: 0.1047 - categorical_accuracy: 0.9639
# Epoch 96/100
# 1/1 - 0s - loss: 0.1027 - categorical_accuracy: 0.9647
# Epoch 97/100
# 1/1 - 0s - loss: 0.1012 - categorical_accuracy: 0.9651
# Epoch 98/100
# 1/1 - 0s - loss: 0.1002 - categorical_accuracy: 0.9647
# Epoch 99/100
# 1/1 - 0s - loss: 0.0989 - categorical_accuracy: 0.9643
# Epoch 100/100
# 1/1 - 0s - loss: 0.0976 - categorical_accuracy: 0.9655
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0720 - categorical_accuracy: 0.8708
# Epoch 101/110
# 1/1 - 0s - loss: 0.0964 - categorical_accuracy: 0.9659
# Epoch 102/110
# 1/1 - 0s - loss: 0.0952 - categorical_accuracy: 0.9672
# Epoch 103/110
# 1/1 - 0s - loss: 0.0937 - categorical_accuracy: 0.9664
# Epoch 104/110
# 1/1 - 0s - loss: 0.0922 - categorical_accuracy: 0.9668
# Epoch 105/110
# 1/1 - 0s - loss: 0.0910 - categorical_accuracy: 0.9659
# Epoch 106/110
# 1/1 - 0s - loss: 0.0898 - categorical_accuracy: 0.9684
# Epoch 107/110
# 1/1 - 0s - loss: 0.0886 - categorical_accuracy: 0.9676
# Epoch 108/110
# 1/1 - 0s - loss: 0.0873 - categorical_accuracy: 0.9696
# Epoch 109/110
# 1/1 - 0s - loss: 0.0863 - categorical_accuracy: 0.9692
# Epoch 110/110
# 1/1 - 0s - loss: 0.0857 - categorical_accuracy: 0.9696
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0765 - categorical_accuracy: 0.8708
# Epoch 111/120
# 1/1 - 0s - loss: 0.0855 - categorical_accuracy: 0.9700
# Epoch 112/120
# 1/1 - 0s - loss: 0.0863 - categorical_accuracy: 0.9664
# Epoch 113/120
# 1/1 - 0s - loss: 0.0875 - categorical_accuracy: 0.9680
# Epoch 114/120
# 1/1 - 0s - loss: 0.0884 - categorical_accuracy: 0.9684
# Epoch 115/120
# 1/1 - 0s - loss: 0.0855 - categorical_accuracy: 0.9672
# Epoch 116/120
# 1/1 - 0s - loss: 0.0799 - categorical_accuracy: 0.9729
# Epoch 117/120
# 1/1 - 0s - loss: 0.0770 - categorical_accuracy: 0.9709
# Epoch 118/120
# 1/1 - 0s - loss: 0.0786 - categorical_accuracy: 0.9717
# Epoch 119/120
# 1/1 - 0s - loss: 0.0796 - categorical_accuracy: 0.9725
# Epoch 120/120
# 1/1 - 0s - loss: 0.0765 - categorical_accuracy: 0.9705
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0806 - categorical_accuracy: 0.8635
# Epoch 121/130
# 1/1 - 0s - loss: 0.0729 - categorical_accuracy: 0.9754
# Epoch 122/130
# 1/1 - 0s - loss: 0.0728 - categorical_accuracy: 0.9733
# Epoch 123/130
# 1/1 - 0s - loss: 0.0745 - categorical_accuracy: 0.9696
# Epoch 124/130
# 1/1 - 0s - loss: 0.0732 - categorical_accuracy: 0.9729
# Epoch 125/130
# 1/1 - 0s - loss: 0.0699 - categorical_accuracy: 0.9741
# Epoch 126/130
# 1/1 - 0s - loss: 0.0679 - categorical_accuracy: 0.9778
# Epoch 127/130
# 1/1 - 0s - loss: 0.0686 - categorical_accuracy: 0.9762
# Epoch 128/130
# 1/1 - 0s - loss: 0.0695 - categorical_accuracy: 0.9725
# Epoch 129/130
# 1/1 - 0s - loss: 0.0677 - categorical_accuracy: 0.9750
# Epoch 130/130
# 1/1 - 0s - loss: 0.0650 - categorical_accuracy: 0.9778
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0843 - categorical_accuracy: 0.8672
# Epoch 131/140
# 1/1 - 0s - loss: 0.0635 - categorical_accuracy: 0.9803
# Epoch 132/140
# 1/1 - 0s - loss: 0.0638 - categorical_accuracy: 0.9778
# Epoch 133/140
# 1/1 - 0s - loss: 0.0643 - categorical_accuracy: 0.9766
# Epoch 134/140
# 1/1 - 0s - loss: 0.0633 - categorical_accuracy: 0.9762
# Epoch 135/140
# 1/1 - 0s - loss: 0.0615 - categorical_accuracy: 0.9795
# Epoch 136/140
# 1/1 - 0s - loss: 0.0601 - categorical_accuracy: 0.9799
# Epoch 137/140
# 1/1 - 0s - loss: 0.0604 - categorical_accuracy: 0.9799
# Epoch 138/140
# 1/1 - 0s - loss: 0.0616 - categorical_accuracy: 0.9750
# Epoch 139/140
# 1/1 - 0s - loss: 0.0615 - categorical_accuracy: 0.9799
# Epoch 140/140
# 1/1 - 0s - loss: 0.0596 - categorical_accuracy: 0.9787
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0904 - categorical_accuracy: 0.8524
# Epoch 141/150
# 1/1 - 0s - loss: 0.0572 - categorical_accuracy: 0.9819
# Epoch 142/150
# 1/1 - 0s - loss: 0.0560 - categorical_accuracy: 0.9811
# Epoch 143/150
# 1/1 - 0s - loss: 0.0561 - categorical_accuracy: 0.9795
# Epoch 144/150
# 1/1 - 0s - loss: 0.0562 - categorical_accuracy: 0.9803
# Epoch 145/150
# 1/1 - 0s - loss: 0.0554 - categorical_accuracy: 0.9783
# Epoch 146/150
# 1/1 - 0s - loss: 0.0534 - categorical_accuracy: 0.9819
# Epoch 147/150
# 1/1 - 0s - loss: 0.0520 - categorical_accuracy: 0.9824
# Epoch 148/150
# 1/1 - 0s - loss: 0.0519 - categorical_accuracy: 0.9836
# Epoch 149/150
# 1/1 - 0s - loss: 0.0523 - categorical_accuracy: 0.9815
# Epoch 150/150
# 1/1 - 0s - loss: 0.0526 - categorical_accuracy: 0.9807
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0940 - categorical_accuracy: 0.8524
# Epoch 151/160
# 1/1 - 0s - loss: 0.0519 - categorical_accuracy: 0.9815
# Epoch 152/160
# 1/1 - 0s - loss: 0.0511 - categorical_accuracy: 0.9832
# Epoch 153/160
# 1/1 - 0s - loss: 0.0503 - categorical_accuracy: 0.9828
# Epoch 154/160
# 1/1 - 0s - loss: 0.0504 - categorical_accuracy: 0.9848
# Epoch 155/160
# 1/1 - 0s - loss: 0.0517 - categorical_accuracy: 0.9819
# Epoch 156/160
# 1/1 - 0s - loss: 0.0521 - categorical_accuracy: 0.9840
# Epoch 157/160
# 1/1 - 0s - loss: 0.0504 - categorical_accuracy: 0.9819
# Epoch 158/160
# 1/1 - 0s - loss: 0.0468 - categorical_accuracy: 0.9865
# Epoch 159/160
# 1/1 - 0s - loss: 0.0450 - categorical_accuracy: 0.9832
# Epoch 160/160
# 1/1 - 0s - loss: 0.0462 - categorical_accuracy: 0.9844
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0999 - categorical_accuracy: 0.8487
# Epoch 161/170
# 1/1 - 0s - loss: 0.0471 - categorical_accuracy: 0.9848
# Epoch 162/170
# 1/1 - 0s - loss: 0.0454 - categorical_accuracy: 0.9852
# Epoch 163/170
# 1/1 - 0s - loss: 0.0431 - categorical_accuracy: 0.9873
# Epoch 164/170
# 1/1 - 0s - loss: 0.0431 - categorical_accuracy: 0.9865
# Epoch 165/170
# 1/1 - 0s - loss: 0.0445 - categorical_accuracy: 0.9836
# Epoch 166/170
# 1/1 - 0s - loss: 0.0438 - categorical_accuracy: 0.9856
# Epoch 167/170
# 1/1 - 0s - loss: 0.0416 - categorical_accuracy: 0.9840
# Epoch 168/170
# 1/1 - 0s - loss: 0.0405 - categorical_accuracy: 0.9869
# Epoch 169/170
# 1/1 - 0s - loss: 0.0411 - categorical_accuracy: 0.9881
# Epoch 170/170
# 1/1 - 0s - loss: 0.0414 - categorical_accuracy: 0.9877
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1031 - categorical_accuracy: 0.8487
# Epoch 171/180
# 1/1 - 0s - loss: 0.0398 - categorical_accuracy: 0.9881
# Epoch 172/180
# 1/1 - 0s - loss: 0.0385 - categorical_accuracy: 0.9881
# Epoch 173/180
# 1/1 - 0s - loss: 0.0384 - categorical_accuracy: 0.9869
# Epoch 174/180
# 1/1 - 0s - loss: 0.0384 - categorical_accuracy: 0.9885
# Epoch 175/180
# 1/1 - 0s - loss: 0.0379 - categorical_accuracy: 0.9869
# Epoch 176/180
# 1/1 - 0s - loss: 0.0368 - categorical_accuracy: 0.9889
# Epoch 177/180
# 1/1 - 0s - loss: 0.0360 - categorical_accuracy: 0.9877
# Epoch 178/180
# 1/1 - 0s - loss: 0.0360 - categorical_accuracy: 0.9885
# Epoch 179/180
# 1/1 - 0s - loss: 0.0360 - categorical_accuracy: 0.9897
# Epoch 180/180
# 1/1 - 0s - loss: 0.0357 - categorical_accuracy: 0.9877
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1083 - categorical_accuracy: 0.8450
# Epoch 181/190
# 1/1 - 0s - loss: 0.0349 - categorical_accuracy: 0.9906
# Epoch 182/190
# 1/1 - 0s - loss: 0.0342 - categorical_accuracy: 0.9893
# Epoch 183/190
# 1/1 - 0s - loss: 0.0339 - categorical_accuracy: 0.9885
# Epoch 184/190
# 1/1 - 0s - loss: 0.0342 - categorical_accuracy: 0.9889
# Epoch 185/190
# 1/1 - 0s - loss: 0.0357 - categorical_accuracy: 0.9873
# Epoch 186/190
# 1/1 - 0s - loss: 0.0389 - categorical_accuracy: 0.9852
# Epoch 187/190
# 1/1 - 0s - loss: 0.0481 - categorical_accuracy: 0.9811
# Epoch 188/190
# 1/1 - 0s - loss: 0.0701 - categorical_accuracy: 0.9696
# Epoch 189/190
# 1/1 - 0s - loss: 0.0787 - categorical_accuracy: 0.9688
# Epoch 190/190
# 1/1 - 0s - loss: 0.0595 - categorical_accuracy: 0.9758
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1117 - categorical_accuracy: 0.8450
# Epoch 191/200
# 1/1 - 0s - loss: 0.0400 - categorical_accuracy: 0.9840
# Epoch 192/200
# 1/1 - 0s - loss: 0.0626 - categorical_accuracy: 0.9783
# Epoch 193/200
# 1/1 - 0s - loss: 0.0369 - categorical_accuracy: 0.9869
# Epoch 194/200
# 1/1 - 0s - loss: 0.0546 - categorical_accuracy: 0.9795
# Epoch 195/200
# 1/1 - 0s - loss: 0.0395 - categorical_accuracy: 0.9860
# Epoch 196/200
# 1/1 - 0s - loss: 0.0475 - categorical_accuracy: 0.9844
# Epoch 197/200
# 1/1 - 0s - loss: 0.0406 - categorical_accuracy: 0.9836
# Epoch 198/200
# 1/1 - 0s - loss: 0.0413 - categorical_accuracy: 0.9852
# Epoch 199/200
# 1/1 - 0s - loss: 0.0394 - categorical_accuracy: 0.9869
# Epoch 200/200
# 1/1 - 0s - loss: 0.0369 - categorical_accuracy: 0.9881
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1129 - categorical_accuracy: 0.8413
# Epoch 201/210
# 1/1 - 0s - loss: 0.0382 - categorical_accuracy: 0.9844
# Epoch 202/210
# 1/1 - 0s - loss: 0.0341 - categorical_accuracy: 0.9885
# Epoch 203/210
# 1/1 - 0s - loss: 0.0358 - categorical_accuracy: 0.9881
# Epoch 204/210
# 1/1 - 0s - loss: 0.0324 - categorical_accuracy: 0.9885
# Epoch 205/210
# 1/1 - 0s - loss: 0.0337 - categorical_accuracy: 0.9869
# Epoch 206/210
# 1/1 - 0s - loss: 0.0302 - categorical_accuracy: 0.9889
# Epoch 207/210
# 1/1 - 0s - loss: 0.0323 - categorical_accuracy: 0.9897
# Epoch 208/210
# 1/1 - 0s - loss: 0.0286 - categorical_accuracy: 0.9914
# Epoch 209/210
# 1/1 - 0s - loss: 0.0305 - categorical_accuracy: 0.9902
# Epoch 210/210
# 1/1 - 0s - loss: 0.0280 - categorical_accuracy: 0.9914
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1183 - categorical_accuracy: 0.8413
# Epoch 211/220
# 1/1 - 0s - loss: 0.0295 - categorical_accuracy: 0.9914
# Epoch 212/220
# 1/1 - 0s - loss: 0.0268 - categorical_accuracy: 0.9926
# Epoch 213/220
# 1/1 - 0s - loss: 0.0284 - categorical_accuracy: 0.9906
# Epoch 214/220
# 1/1 - 0s - loss: 0.0261 - categorical_accuracy: 0.9922
# Epoch 215/220
# 1/1 - 0s - loss: 0.0273 - categorical_accuracy: 0.9918
# Epoch 216/220
# 1/1 - 0s - loss: 0.0256 - categorical_accuracy: 0.9926
# Epoch 217/220
# 1/1 - 0s - loss: 0.0264 - categorical_accuracy: 0.9914
# Epoch 218/220
# 1/1 - 0s - loss: 0.0249 - categorical_accuracy: 0.9938
# Epoch 219/220
# 1/1 - 0s - loss: 0.0256 - categorical_accuracy: 0.9918
# Epoch 220/220
# 1/1 - 0s - loss: 0.0243 - categorical_accuracy: 0.9934
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1206 - categorical_accuracy: 0.8339
# Epoch 221/230
# 1/1 - 0s - loss: 0.0250 - categorical_accuracy: 0.9922
# Epoch 222/230
# 1/1 - 0s - loss: 0.0238 - categorical_accuracy: 0.9938
# Epoch 223/230
# 1/1 - 0s - loss: 0.0244 - categorical_accuracy: 0.9930
# Epoch 224/230
# 1/1 - 0s - loss: 0.0233 - categorical_accuracy: 0.9947
# Epoch 225/230
# 1/1 - 0s - loss: 0.0237 - categorical_accuracy: 0.9934
# Epoch 226/230
# 1/1 - 0s - loss: 0.0229 - categorical_accuracy: 0.9938
# Epoch 227/230
# 1/1 - 0s - loss: 0.0232 - categorical_accuracy: 0.9938
# Epoch 228/230
# 1/1 - 0s - loss: 0.0225 - categorical_accuracy: 0.9943
# Epoch 229/230
# 1/1 - 0s - loss: 0.0227 - categorical_accuracy: 0.9943
# Epoch 230/230
# 1/1 - 0s - loss: 0.0222 - categorical_accuracy: 0.9947
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1267 - categorical_accuracy: 0.8339
# Epoch 231/240
# 1/1 - 0s - loss: 0.0222 - categorical_accuracy: 0.9951
# Epoch 232/240
# 1/1 - 0s - loss: 0.0218 - categorical_accuracy: 0.9947
# Epoch 233/240
# 1/1 - 0s - loss: 0.0216 - categorical_accuracy: 0.9951
# Epoch 234/240
# 1/1 - 0s - loss: 0.0215 - categorical_accuracy: 0.9947
# Epoch 235/240
# 1/1 - 0s - loss: 0.0212 - categorical_accuracy: 0.9959
# Epoch 236/240
# 1/1 - 0s - loss: 0.0211 - categorical_accuracy: 0.9955
# Epoch 237/240
# 1/1 - 0s - loss: 0.0208 - categorical_accuracy: 0.9955
# Epoch 238/240
# 1/1 - 0s - loss: 0.0208 - categorical_accuracy: 0.9955
# Epoch 239/240
# 1/1 - 0s - loss: 0.0204 - categorical_accuracy: 0.9943
# Epoch 240/240
# 1/1 - 0s - loss: 0.0204 - categorical_accuracy: 0.9955
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1296 - categorical_accuracy: 0.8339
# Epoch 241/250
# 1/1 - 0s - loss: 0.0201 - categorical_accuracy: 0.9955
# Epoch 242/250
# 1/1 - 0s - loss: 0.0201 - categorical_accuracy: 0.9955
# Epoch 243/250
# 1/1 - 0s - loss: 0.0199 - categorical_accuracy: 0.9955
# Epoch 244/250
# 1/1 - 0s - loss: 0.0197 - categorical_accuracy: 0.9951
# Epoch 245/250
# 1/1 - 0s - loss: 0.0195 - categorical_accuracy: 0.9963
# Epoch 246/250
# 1/1 - 0s - loss: 0.0194 - categorical_accuracy: 0.9959
# Epoch 247/250
# 1/1 - 0s - loss: 0.0193 - categorical_accuracy: 0.9951
# Epoch 248/250
# 1/1 - 0s - loss: 0.0191 - categorical_accuracy: 0.9959
# Epoch 249/250
# 1/1 - 0s - loss: 0.0190 - categorical_accuracy: 0.9959
# Epoch 250/250
# 1/1 - 0s - loss: 0.0187 - categorical_accuracy: 0.9959
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1324 - categorical_accuracy: 0.8339
# Epoch 251/260
# 1/1 - 0s - loss: 0.0187 - categorical_accuracy: 0.9959
# Epoch 252/260
# 1/1 - 0s - loss: 0.0185 - categorical_accuracy: 0.9959
# Epoch 253/260
# 1/1 - 0s - loss: 0.0183 - categorical_accuracy: 0.9963
# Epoch 254/260
# 1/1 - 0s - loss: 0.0182 - categorical_accuracy: 0.9959
# Epoch 255/260
# 1/1 - 0s - loss: 0.0181 - categorical_accuracy: 0.9963
# Epoch 256/260
# 1/1 - 0s - loss: 0.0180 - categorical_accuracy: 0.9959
# Epoch 257/260
# 1/1 - 0s - loss: 0.0178 - categorical_accuracy: 0.9963
# Epoch 258/260
# 1/1 - 0s - loss: 0.0177 - categorical_accuracy: 0.9963
# Epoch 259/260
# 1/1 - 0s - loss: 0.0175 - categorical_accuracy: 0.9963
# Epoch 260/260
# 1/1 - 0s - loss: 0.0174 - categorical_accuracy: 0.9967
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1354 - categorical_accuracy: 0.8376
# Epoch 261/270
# 1/1 - 0s - loss: 0.0173 - categorical_accuracy: 0.9959
# Epoch 262/270
# 1/1 - 0s - loss: 0.0172 - categorical_accuracy: 0.9963
# Epoch 263/270
# 1/1 - 0s - loss: 0.0170 - categorical_accuracy: 0.9963
# Epoch 264/270
# 1/1 - 0s - loss: 0.0169 - categorical_accuracy: 0.9963
# Epoch 265/270
# 1/1 - 0s - loss: 0.0168 - categorical_accuracy: 0.9963
# Epoch 266/270
# 1/1 - 0s - loss: 0.0167 - categorical_accuracy: 0.9963
# Epoch 267/270
# 1/1 - 0s - loss: 0.0166 - categorical_accuracy: 0.9963
# Epoch 268/270
# 1/1 - 0s - loss: 0.0165 - categorical_accuracy: 0.9959
# Epoch 269/270
# 1/1 - 0s - loss: 0.0163 - categorical_accuracy: 0.9967
# Epoch 270/270
# 1/1 - 0s - loss: 0.0162 - categorical_accuracy: 0.9967
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1381 - categorical_accuracy: 0.8339
# Epoch 271/280
# 1/1 - 0s - loss: 0.0161 - categorical_accuracy: 0.9963
# Epoch 272/280
# 1/1 - 0s - loss: 0.0161 - categorical_accuracy: 0.9967
# Epoch 273/280
# 1/1 - 0s - loss: 0.0159 - categorical_accuracy: 0.9967
# Epoch 274/280
# 1/1 - 0s - loss: 0.0158 - categorical_accuracy: 0.9967
# Epoch 275/280
# 1/1 - 0s - loss: 0.0157 - categorical_accuracy: 0.9967
# Epoch 276/280
# 1/1 - 0s - loss: 0.0156 - categorical_accuracy: 0.9963
# Epoch 277/280
# 1/1 - 0s - loss: 0.0155 - categorical_accuracy: 0.9967
# Epoch 278/280
# 1/1 - 0s - loss: 0.0154 - categorical_accuracy: 0.9963
# Epoch 279/280
# 1/1 - 0s - loss: 0.0153 - categorical_accuracy: 0.9967
# Epoch 280/280
# 1/1 - 0s - loss: 0.0152 - categorical_accuracy: 0.9967
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1416 - categorical_accuracy: 0.8339
# Epoch 281/290
# 1/1 - 0s - loss: 0.0152 - categorical_accuracy: 0.9967
# Epoch 282/290
# 1/1 - 0s - loss: 0.0151 - categorical_accuracy: 0.9967
# Epoch 283/290
# 1/1 - 0s - loss: 0.0150 - categorical_accuracy: 0.9967
# Epoch 284/290
# 1/1 - 0s - loss: 0.0148 - categorical_accuracy: 0.9967
# Epoch 285/290
# 1/1 - 0s - loss: 0.0147 - categorical_accuracy: 0.9971
# Epoch 286/290
# 1/1 - 0s - loss: 0.0146 - categorical_accuracy: 0.9975
# Epoch 287/290
# 1/1 - 0s - loss: 0.0145 - categorical_accuracy: 0.9967
# Epoch 288/290
# 1/1 - 0s - loss: 0.0145 - categorical_accuracy: 0.9971
# Epoch 289/290
# 1/1 - 0s - loss: 0.0143 - categorical_accuracy: 0.9967
# Epoch 290/290
# 1/1 - 0s - loss: 0.0142 - categorical_accuracy: 0.9975
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1439 - categorical_accuracy: 0.8339
# Epoch 291/300
# 1/1 - 0s - loss: 0.0141 - categorical_accuracy: 0.9971
# Epoch 292/300
# 1/1 - 0s - loss: 0.0141 - categorical_accuracy: 0.9967
# Epoch 293/300
# 1/1 - 0s - loss: 0.0140 - categorical_accuracy: 0.9971
# Epoch 294/300
# 1/1 - 0s - loss: 0.0139 - categorical_accuracy: 0.9967
# Epoch 295/300
# 1/1 - 0s - loss: 0.0138 - categorical_accuracy: 0.9975
# Epoch 296/300
# 1/1 - 0s - loss: 0.0138 - categorical_accuracy: 0.9967
# Epoch 297/300
# 1/1 - 0s - loss: 0.0137 - categorical_accuracy: 0.9975
# Epoch 298/300
# 1/1 - 0s - loss: 0.0136 - categorical_accuracy: 0.9971
# Epoch 299/300
# 1/1 - 0s - loss: 0.0135 - categorical_accuracy: 0.9975
# Epoch 300/300
# 1/1 - 0s - loss: 0.0134 - categorical_accuracy: 0.9971
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1465 - categorical_accuracy: 0.8339
# Print Time for taining:  18.90625
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1465 - categorical_accuracy: 0.8339
# [0.1464547961950302, 0.8339483141899109]

# %% [markdown]
# ## Explaining Predictions
#
#
# Implementing the GNNInterface:

# %%
class ExplainableGCN(GNNInterface):

    def __init__(self, gnn_model, node_index, **kwargs):
        super(ExplainableGCN, self).__init__()
        self.gnn_model = gnn_model
        self.node_index = node_index

    def predict(self, gnn_input, masking_info=None):
        return tf.expand_dims(self.gnn_model(gnn_input, training=False)[0][self.node_index], 0)

    def masked_predict(self, gnn_input, edge_mask, feature_mask, node_mask, training=False):
        node_input, edge_input, edge_index_input = gnn_input

        masked_edge_input = tf.ragged.map_flat_values(tf.math.multiply, tf.dtypes.cast(edge_input, tf.float32),
                                                      edge_mask)
        masked_feature_input = tf.ragged.map_flat_values(tf.math.multiply, tf.dtypes.cast(node_input, tf.float32),
                                                         tf.transpose(feature_mask))
        masked_pred = tf.expand_dims(
            self.gnn_model([masked_feature_input, masked_edge_input, edge_index_input], training=training)[0][
                self.node_index], 0)
        return masked_pred

    def get_number_of_nodes(self, gnn_input):
        node_input, _, _ = gnn_input
        return node_input[0].shape[0]

    def get_number_of_node_features(self, gnn_input):
        node_input, _, _ = gnn_input
        return node_input[0].shape[1]

    def get_number_of_edges(self, gnn_input):
        _, edge_input, _ = gnn_input
        return edge_input[0].shape[0]

    def get_explanation(self, gnn_input, edge_mask, feature_mask, node_mask, node_labels=None):
        edge_relevance = np.array(edge_mask[:, 0])
        node_relevance = np.array(node_mask[:, 0])
        features = np.array(gnn_input[0][0])
        edges = np.array(gnn_input[2][0])
        g = nx.Graph()
        for i, f in enumerate(features):
            if node_labels is None:
                g.add_node(i, features=f, relevance=node_relevance[i])
            else:
                g.add_node(i, features=f, relevance=node_relevance[i], label=node_labels[i])
        for i, e in enumerate(edges):
            if edge_relevance is None:
                g.add_edge(e[0], e[1])
            else:
                g.add_edge(e[0], e[1], relevance=edge_relevance[i])
        return g

    def present_explanation(self, explanation, threshold=0.5):
        relevant_edges = []
        edge_color_map = []
        for (v, u, relevance) in explanation.edges.data('relevance'):
            if relevance > threshold:
                relevant_edges.append((v, u))
                edge_color_map.append((0, 0, 0, relevance))
        subgraph = explanation.edge_subgraph(relevant_edges)
        node_colors = []
        for n, l in subgraph.nodes.data('label'):
            r, g, b, a = get_label_color(l)
            a = subgraph.nodes[n]['relevance']
            node_colors.append((r, g, b, a))
        nx.draw(subgraph, node_color=node_colors, edge_color=edge_color_map, with_labels=True)

# %%
# Helper functions
def get_output_tensor_for_label(label):
    assert 0 <= label <= 6
    output_to_explain = np.zeros(7)
    output_to_explain[label] = 1.
    output_to_explain = np.expand_dims(output_to_explain, 0)
    return tf.Variable(output_to_explain)


def get_label_from_tensor(tensor_output):
    return np.argmax(tensor_output)

# %% [markdown]
# Choose a node to explain and instantiate an explainable GNN:

# %%
node_index = np.argwhere(val_mask[0] == 1)[:, 0][0]
# node_index = 9
explainable_gcn = ExplainableGCN(model, node_index)

# %% [markdown]
# Get the prediction of the GNN for the chosen node:

# %%
prediction = explainable_gcn.predict(xtrain)
predicted_label = get_label_from_tensor(prediction)
print('predicted label: ', predicted_label, get_label_name(predicted_label))
print("true label:", get_label_from_tensor(labels[node_index]))
print('node_index: ', node_index)
# Out:
# predicted label:  2 Neural_Networks
# true label: 2
# node_index:  9

# %% [markdown]
# Setup the GNNExplainer:

# %%
gnnexplaineroptimizer_options = {'edge_mask_loss_weight': 0.001,
                                 'edge_mask_norm_ord': 2,
                                 'feature_mask_loss_weight': 0,
                                 'feature_mask_norm_ord': 2,
                                 'node_mask_loss_weight': 0,
                                 'node_mask_norm_ord': 1}
compile_options = {'loss': 'categorical_crossentropy', 'optimizer': tf.keras.optimizers.Adam(lr=1)}
fit_options = {'epochs': 80, 'verbose': 0}

explainer = GNNExplainer(explainable_gcn,
                         compile_options=compile_options,
                         fit_options=fit_options,
                         gnnexplaineroptimizer_options=gnnexplaineroptimizer_options)
# Out:
# c:\users\patrick\.conda\envs\aimat\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %% [markdown]
# Explain the instance with index node_index:

# %%
# %%capture
inspection_result = explainer.explain(xtrain, inspection=True)

# %%
plt.figure()
explainer.present_explanation(explainer.get_explanation(node_labels=np.argmax(ytrain[0], axis=1)), threshold=0.1)
plt.show()

# %%
# Plot the inspection_result to see if we chose suitable parameters:
plt.figure()
for i in range(7):
    plt.plot(np.array(inspection_result['predictions'])[:, i], color=get_label_color(i))
plt.show()

# %%
# Plot Loss
plt.figure()
plt.plot(np.array(inspection_result['total_loss']), color="black")
plt.show()

# %%
# For comparison, the 2-hop graph around the chosen instance:
plt.figure()
cora_graph = nx.Graph()
cora_graph.add_nodes_from([(i, {"label": labels[i]}) for i in inds])
cora_graph.add_edges_from(edge_index)
hops = 2
khopgraph = nx.generators.ego.ego_graph(cora_graph, node_index, radius=hops)
for n in khopgraph.nodes:
    khopgraph.nodes[n]['label'] = np.argmax(khopgraph.nodes[n]['label'])
    khopgraph.nodes[n]['relevance'] = 1.
for (u, v) in khopgraph.edges:
    khopgraph.edges[u, v]['relevance'] = 1.0
explainer.present_explanation(khopgraph)
plt.show()
