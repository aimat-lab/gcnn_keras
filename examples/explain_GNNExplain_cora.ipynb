# %%
import time

import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

from kgcnn.data.cora.cora_lu import cora_graph
from kgcnn.literature.GCN import make_gcn
from kgcnn.literature.GNNExplain import GNNExplainer, GNNInterface
from kgcnn.utils.adj import precompute_adjacency_scaled, sort_edge_indices, make_adjacency_from_edge_indices, \
    make_adjacency_undirected_logical_or, convert_scaled_adjacency_to_list
from kgcnn.utils.data import ragged_tensor_from_nested_numpy
from kgcnn.utils.learning import lr_lin_reduction
# Out:
# Keras utils: Register custom activation:  {'leaky_softplus': <function leaky_softplus at 0x000002CF60A95A60>, 'shifted_softplus': <function shifted_softplus at 0x000002CF60A95940>, 'softplus2': <function softplus2 at 0x000002CF60A959D0>}

# %% [markdown]
# ## Loading graph data

# %%
nodes, edge_index, labels, class_label_mapping = cora_graph()
nodes = nodes[:, 1:]  # Remove IDs
edge_index = sort_edge_indices(edge_index)
adj_matrix = make_adjacency_from_edge_indices(edge_index)
adj_matrix = precompute_adjacency_scaled(make_adjacency_undirected_logical_or(adj_matrix))
edge_index, edge_weight = convert_scaled_adjacency_to_list(adj_matrix)
edge_weight = np.expand_dims(edge_weight, axis=-1)
labels = np.expand_dims(labels, axis=-1)
labels = np.array(labels == np.arange(7), dtype=np.float32)

# Find a color to visualize a label
def get_label_color(label):
    return plt.get_cmap('Set1')(label / 7)


# Map label to class
def get_label_name(label):
    return ["Case_Based",
            "Genetic_Algorithms",
            "Neural_Networks",
            "Probabilistic_Methods",
            "Reinforcement_Learning",
            "Rule_Learning",
            "Theory"][label]
# Out:
# Database path: C:\Users\Patrick\.kgcnn\data\cora

# %% [markdown]
# ## Train test split

# %%
# Make test/train split
# Since only one graph in the dataset
# Use a mask to hide test nodes labels
inds = np.arange(len(labels))
ind_train, ind_val = train_test_split(inds, test_size=0.10, random_state=0)
val_mask = np.zeros_like(inds)
train_mask = np.zeros_like(inds)
val_mask[ind_val] = 1
train_mask[ind_train] = 1
val_mask = np.expand_dims(val_mask, axis=0)  # One graph in batch
train_mask = np.expand_dims(train_mask, axis=0)  # One graph in batch

# Make ragged graph tensors with 1 graph in batch
nodes, edges, edge_indices = ragged_tensor_from_nested_numpy([nodes]), ragged_tensor_from_nested_numpy(
    [edge_weight]), ragged_tensor_from_nested_numpy([edge_index])  # One graph in batch

# Set training data. But requires mask and batch-dimension of 1
xtrain = nodes, edges, edge_indices
ytrain = np.expand_dims(labels, axis=0)  # One graph in batch

# %% [markdown]
# ## Train GCN model on cora dataset

# %%
model = make_gcn(
    input_node_shape=[None, 1433],
    input_edge_shape=[None, 1],
    # Output
    output_embedd={"output_mode": 'node'},
    output_mlp={"use_bias": [True, True, False], "units": [64, 16, 7], "activation": ['relu', 'relu', 'softmax']},
    # model specs
    depth=3,
    gcn_args={"units": 124, "use_bias": True, "activation": "relu", "has_unconnected": True}
)

# Set learning rate and epochs
learning_rate_start = 1e-3
learning_rate_stop = 1e-4
epo = 300
epomin = 260
epostep = 10

# Compile model with optimizer and loss
optimizer = tf.keras.optimizers.Adam(lr=learning_rate_start)
cbks = tf.keras.callbacks.LearningRateScheduler(lr_lin_reduction(learning_rate_start, learning_rate_stop, epomin, epo))
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              weighted_metrics=['categorical_accuracy'])
print(model.summary())

# Training loop
trainlossall = []
testlossall = []
start = time.process_time()
for iepoch in range(0, epo, epostep):
    hist = model.fit(xtrain, ytrain,
                     epochs=iepoch + epostep,
                     initial_epoch=iepoch,
                     batch_size=1,
                     callbacks=[cbks],
                     verbose=2,
                     sample_weight=train_mask  # Important!!!
                     )

    trainlossall.append(hist.history)
    testlossall.append(model.evaluate(xtrain, ytrain, sample_weight=val_mask))
stop = time.process_time()
print("Print Time for taining: ", stop - start)

# Pick out accuracy
testlossall = np.array(testlossall)
trainlossall = np.concatenate([x['categorical_accuracy'] for x in trainlossall])

# Plot loss vs epochs
plt.figure()
plt.plot(np.arange(1, len(trainlossall) + 1), trainlossall, label='Training Loss', c='blue')
plt.plot(np.arange(epostep, epo + epostep, epostep), testlossall[:, 1], label='Test Loss', c='red')
plt.xlabel('Epochs')
plt.ylabel('Accurarcy')
plt.title('GCN')
plt.legend(loc='lower right', fontsize='x-large')
plt.savefig('gcn_explain_loss_cora.png')
plt.show()

# Evaluate model
model.evaluate(xtrain, ytrain, sample_weight=val_mask)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method GatherNodesOutgoing.call of <kgcnn.layers.ragged.gather.GatherNodesOutgoing object at 0x000002CF65B01F40>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method GatherNodesOutgoing.call of <kgcnn.layers.ragged.gather.GatherNodesOutgoing object at 0x000002CF65B01F40>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <bound method PoolingWeightedLocalEdges.call of <kgcnn.layers.ragged.pooling.PoolingWeightedLocalEdges object at 0x000002CF65B81CD0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method PoolingWeightedLocalEdges.call of <kgcnn.layers.ragged.pooling.PoolingWeightedLocalEdges object at 0x000002CF65B81CD0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <bound method MLPRagged.call of <kgcnn.layers.ragged.mlp.MLPRagged object at 0x000002CF65C63CA0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method MLPRagged.call of <kgcnn.layers.ragged.mlp.MLPRagged object at 0x000002CF65C63CA0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# node_input (InputLayer)         [(None, None, 1433)] 0
# __________________________________________________________________________________________________
# dense_ragged (DenseRagged)      (None, None, 124)    177816      node_input[0][0]
# __________________________________________________________________________________________________
# edge_input (InputLayer)         [(None, None, 1)]    0
# __________________________________________________________________________________________________
# edge_index_input (InputLayer)   [(None, None, 2)]    0
# __________________________________________________________________________________________________
# gcn (GCN)                       (None, None, 124)    15500       dense_ragged[0][0]
#                                                                  edge_input[0][0]
#                                                                  edge_index_input[0][0]
# __________________________________________________________________________________________________
# gcn_1 (GCN)                     (None, None, 124)    15500       gcn[0][0]
#                                                                  edge_input[0][0]
#                                                                  edge_index_input[0][0]
# __________________________________________________________________________________________________
# gcn_2 (GCN)                     (None, None, 124)    15500       gcn_1[0][0]
#                                                                  edge_input[0][0]
#                                                                  edge_index_input[0][0]
# __________________________________________________________________________________________________
# mlp_ragged (MLPRagged)          (None, None, 7)      9152        gcn_2[0][0]
# __________________________________________________________________________________________________
# cast_ragged_to_dense (CastRagge (None, None, 7)      0           mlp_ragged[0][0]
# ==================================================================================================
# Total params: 233,468
# Trainable params: 233,468
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/10
# C:\Users\Patrick\.conda\envs\aimat\lib\site-packages\tensorflow\python\framework\indexed_slices.py:431: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# 1/1 - 0s - loss: 1.7607 - categorical_accuracy: 0.0583
# Epoch 2/10
# 1/1 - 0s - loss: 1.7479 - categorical_accuracy: 0.2228
# Epoch 3/10
# 1/1 - 0s - loss: 1.7421 - categorical_accuracy: 0.3615
# Epoch 4/10
# 1/1 - 0s - loss: 1.7354 - categorical_accuracy: 0.4222
# Epoch 5/10
# 1/1 - 0s - loss: 1.7260 - categorical_accuracy: 0.4218
# Epoch 6/10
# 1/1 - 0s - loss: 1.7135 - categorical_accuracy: 0.4087
# Epoch 7/10
# 1/1 - 0s - loss: 1.6965 - categorical_accuracy: 0.4309
# Epoch 8/10
# 1/1 - 0s - loss: 1.6741 - categorical_accuracy: 0.4867
# Epoch 9/10
# 1/1 - 0s - loss: 1.6459 - categorical_accuracy: 0.5585
# Epoch 10/10
# 1/1 - 0s - loss: 1.6114 - categorical_accuracy: 0.6020
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1765 - categorical_accuracy: 0.5867
# Epoch 11/20
# 1/1 - 0s - loss: 1.5699 - categorical_accuracy: 0.6274
# Epoch 12/20
# 1/1 - 0s - loss: 1.5204 - categorical_accuracy: 0.6393
# Epoch 13/20
# 1/1 - 0s - loss: 1.4624 - categorical_accuracy: 0.6623
# Epoch 14/20
# 1/1 - 0s - loss: 1.3961 - categorical_accuracy: 0.6865
# Epoch 15/20
# 1/1 - 0s - loss: 1.3222 - categorical_accuracy: 0.7087
# Epoch 16/20
# 1/1 - 0s - loss: 1.2429 - categorical_accuracy: 0.7325
# Epoch 17/20
# 1/1 - 0s - loss: 1.1608 - categorical_accuracy: 0.7411
# Epoch 18/20
# 1/1 - 0s - loss: 1.0782 - categorical_accuracy: 0.7357
# Epoch 19/20
# 1/1 - 0s - loss: 0.9991 - categorical_accuracy: 0.7444
# Epoch 20/20
# 1/1 - 0s - loss: 0.9254 - categorical_accuracy: 0.7456
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1102 - categorical_accuracy: 0.6937
# Epoch 21/30
# 1/1 - 0s - loss: 0.8588 - categorical_accuracy: 0.7439
# Epoch 22/30
# 1/1 - 0s - loss: 0.7968 - categorical_accuracy: 0.7546
# Epoch 23/30
# 1/1 - 0s - loss: 0.7376 - categorical_accuracy: 0.7751
# Epoch 24/30
# 1/1 - 0s - loss: 0.6818 - categorical_accuracy: 0.7993
# Epoch 25/30
# 1/1 - 0s - loss: 0.6295 - categorical_accuracy: 0.8145
# Epoch 26/30
# 1/1 - 0s - loss: 0.5796 - categorical_accuracy: 0.8199
# Epoch 27/30
# 1/1 - 0s - loss: 0.5316 - categorical_accuracy: 0.8227
# Epoch 28/30
# 1/1 - 0s - loss: 0.4897 - categorical_accuracy: 0.8465
# Epoch 29/30
# 1/1 - 0s - loss: 0.4602 - categorical_accuracy: 0.8670
# Epoch 30/30
# 1/1 - 0s - loss: 0.4406 - categorical_accuracy: 0.8666
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0601 - categorical_accuracy: 0.8782
# Epoch 31/40
# 1/1 - 0s - loss: 0.4183 - categorical_accuracy: 0.8732
# Epoch 32/40
# 1/1 - 0s - loss: 0.3934 - categorical_accuracy: 0.8802
# Epoch 33/40
# 1/1 - 0s - loss: 0.3750 - categorical_accuracy: 0.8835
# Epoch 34/40
# 1/1 - 0s - loss: 0.3624 - categorical_accuracy: 0.8867
# Epoch 35/40
# 1/1 - 0s - loss: 0.3500 - categorical_accuracy: 0.8908
# Epoch 36/40
# 1/1 - 0s - loss: 0.3344 - categorical_accuracy: 0.8933
# Epoch 37/40
# 1/1 - 0s - loss: 0.3178 - categorical_accuracy: 0.8999
# Epoch 38/40
# 1/1 - 0s - loss: 0.3050 - categorical_accuracy: 0.9032
# Epoch 39/40
# 1/1 - 0s - loss: 0.2954 - categorical_accuracy: 0.9093
# Epoch 40/40
# 1/1 - 0s - loss: 0.2873 - categorical_accuracy: 0.9093
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0595 - categorical_accuracy: 0.8819
# Epoch 41/50
# 1/1 - 0s - loss: 0.2774 - categorical_accuracy: 0.9142
# Epoch 42/50
# 1/1 - 0s - loss: 0.2628 - categorical_accuracy: 0.9142
# Epoch 43/50
# 1/1 - 0s - loss: 0.2510 - categorical_accuracy: 0.9183
# Epoch 44/50
# 1/1 - 0s - loss: 0.2459 - categorical_accuracy: 0.9241
# Epoch 45/50
# 1/1 - 0s - loss: 0.2397 - categorical_accuracy: 0.9196
# Epoch 46/50
# 1/1 - 0s - loss: 0.2298 - categorical_accuracy: 0.9261
# Epoch 47/50
# 1/1 - 0s - loss: 0.2222 - categorical_accuracy: 0.9282
# Epoch 48/50
# 1/1 - 0s - loss: 0.2194 - categorical_accuracy: 0.9216
# Epoch 49/50
# 1/1 - 0s - loss: 0.2124 - categorical_accuracy: 0.9282
# Epoch 50/50
# 1/1 - 0s - loss: 0.2050 - categorical_accuracy: 0.9302
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0588 - categorical_accuracy: 0.8708
# Epoch 51/60
# 1/1 - 0s - loss: 0.2017 - categorical_accuracy: 0.9261
# Epoch 52/60
# 1/1 - 0s - loss: 0.1953 - categorical_accuracy: 0.9348
# Epoch 53/60
# 1/1 - 0s - loss: 0.1898 - categorical_accuracy: 0.9311
# Epoch 54/60
# 1/1 - 0s - loss: 0.1862 - categorical_accuracy: 0.9311
# Epoch 55/60
# 1/1 - 0s - loss: 0.1818 - categorical_accuracy: 0.9352
# Epoch 56/60
# 1/1 - 0s - loss: 0.1766 - categorical_accuracy: 0.9384
# Epoch 57/60
# 1/1 - 0s - loss: 0.1722 - categorical_accuracy: 0.9417
# Epoch 58/60
# 1/1 - 0s - loss: 0.1702 - categorical_accuracy: 0.9401
# Epoch 59/60
# 1/1 - 0s - loss: 0.1664 - categorical_accuracy: 0.9393
# Epoch 60/60
# 1/1 - 0s - loss: 0.1614 - categorical_accuracy: 0.9442
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0627 - categorical_accuracy: 0.8745
# Epoch 61/70
# 1/1 - 0s - loss: 0.1585 - categorical_accuracy: 0.9450
# Epoch 62/70
# 1/1 - 0s - loss: 0.1565 - categorical_accuracy: 0.9417
# Epoch 63/70
# 1/1 - 0s - loss: 0.1538 - categorical_accuracy: 0.9438
# Epoch 64/70
# 1/1 - 0s - loss: 0.1495 - categorical_accuracy: 0.9454
# Epoch 65/70
# 1/1 - 0s - loss: 0.1460 - categorical_accuracy: 0.9495
# Epoch 66/70
# 1/1 - 0s - loss: 0.1439 - categorical_accuracy: 0.9458
# Epoch 67/70
# 1/1 - 0s - loss: 0.1419 - categorical_accuracy: 0.9483
# Epoch 68/70
# 1/1 - 0s - loss: 0.1400 - categorical_accuracy: 0.9471
# Epoch 69/70
# 1/1 - 0s - loss: 0.1373 - categorical_accuracy: 0.9479
# Epoch 70/70
# 1/1 - 0s - loss: 0.1340 - categorical_accuracy: 0.9475
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0672 - categorical_accuracy: 0.8782
# Epoch 71/80
# 1/1 - 0s - loss: 0.1312 - categorical_accuracy: 0.9499
# Epoch 72/80
# 1/1 - 0s - loss: 0.1283 - categorical_accuracy: 0.9499
# Epoch 73/80
# 1/1 - 0s - loss: 0.1261 - categorical_accuracy: 0.9536
# Epoch 74/80
# 1/1 - 0s - loss: 0.1247 - categorical_accuracy: 0.9524
# Epoch 75/80
# 1/1 - 0s - loss: 0.1233 - categorical_accuracy: 0.9532
# Epoch 76/80
# 1/1 - 0s - loss: 0.1217 - categorical_accuracy: 0.9516
# Epoch 77/80
# 1/1 - 0s - loss: 0.1201 - categorical_accuracy: 0.9549
# Epoch 78/80
# 1/1 - 0s - loss: 0.1186 - categorical_accuracy: 0.9512
# Epoch 79/80
# 1/1 - 0s - loss: 0.1159 - categorical_accuracy: 0.9565
# Epoch 80/80
# 1/1 - 0s - loss: 0.1132 - categorical_accuracy: 0.9553
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0714 - categorical_accuracy: 0.8782
# Epoch 81/90
# 1/1 - 0s - loss: 0.1109 - categorical_accuracy: 0.9590
# Epoch 82/90
# 1/1 - 0s - loss: 0.1087 - categorical_accuracy: 0.9594
# Epoch 83/90
# 1/1 - 0s - loss: 0.1070 - categorical_accuracy: 0.9594
# Epoch 84/90
# 1/1 - 0s - loss: 0.1059 - categorical_accuracy: 0.9610
# Epoch 85/90
# 1/1 - 0s - loss: 0.1052 - categorical_accuracy: 0.9602
# Epoch 86/90
# 1/1 - 0s - loss: 0.1047 - categorical_accuracy: 0.9618
# Epoch 87/90
# 1/1 - 0s - loss: 0.1046 - categorical_accuracy: 0.9590
# Epoch 88/90
# 1/1 - 0s - loss: 0.1046 - categorical_accuracy: 0.9594
# Epoch 89/90
# 1/1 - 0s - loss: 0.1038 - categorical_accuracy: 0.9577
# Epoch 90/90
# 1/1 - 0s - loss: 0.1000 - categorical_accuracy: 0.9627
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0769 - categorical_accuracy: 0.8856
# Epoch 91/100
# 1/1 - 0s - loss: 0.0956 - categorical_accuracy: 0.9622
# Epoch 92/100
# 1/1 - 0s - loss: 0.0934 - categorical_accuracy: 0.9643
# Epoch 93/100
# 1/1 - 0s - loss: 0.0934 - categorical_accuracy: 0.9643
# Epoch 94/100
# 1/1 - 0s - loss: 0.0938 - categorical_accuracy: 0.9627
# Epoch 95/100
# 1/1 - 0s - loss: 0.0927 - categorical_accuracy: 0.9664
# Epoch 96/100
# 1/1 - 0s - loss: 0.0901 - categorical_accuracy: 0.9668
# Epoch 97/100
# 1/1 - 0s - loss: 0.0873 - categorical_accuracy: 0.9655
# Epoch 98/100
# 1/1 - 0s - loss: 0.0857 - categorical_accuracy: 0.9696
# Epoch 99/100
# 1/1 - 0s - loss: 0.0855 - categorical_accuracy: 0.9668
# Epoch 100/100
# 1/1 - 0s - loss: 0.0855 - categorical_accuracy: 0.9709
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0825 - categorical_accuracy: 0.8635
# Epoch 101/110
# 1/1 - 0s - loss: 0.0847 - categorical_accuracy: 0.9659
# Epoch 102/110
# 1/1 - 0s - loss: 0.0826 - categorical_accuracy: 0.9713
# Epoch 103/110
# 1/1 - 0s - loss: 0.0803 - categorical_accuracy: 0.9696
# Epoch 104/110
# 1/1 - 0s - loss: 0.0785 - categorical_accuracy: 0.9700
# Epoch 105/110
# 1/1 - 0s - loss: 0.0776 - categorical_accuracy: 0.9705
# Epoch 106/110
# 1/1 - 0s - loss: 0.0772 - categorical_accuracy: 0.9696
# Epoch 107/110
# 1/1 - 0s - loss: 0.0769 - categorical_accuracy: 0.9725
# Epoch 108/110
# 1/1 - 0s - loss: 0.0772 - categorical_accuracy: 0.9696
# Epoch 109/110
# 1/1 - 0s - loss: 0.0778 - categorical_accuracy: 0.9709
# Epoch 110/110
# 1/1 - 0s - loss: 0.0795 - categorical_accuracy: 0.9635
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0894 - categorical_accuracy: 0.8598
# Epoch 111/120
# 1/1 - 0s - loss: 0.0788 - categorical_accuracy: 0.9713
# Epoch 112/120
# 1/1 - 0s - loss: 0.0762 - categorical_accuracy: 0.9680
# Epoch 113/120
# 1/1 - 0s - loss: 0.0710 - categorical_accuracy: 0.9746
# Epoch 114/120
# 1/1 - 0s - loss: 0.0687 - categorical_accuracy: 0.9729
# Epoch 115/120
# 1/1 - 0s - loss: 0.0700 - categorical_accuracy: 0.9729
# Epoch 116/120
# 1/1 - 0s - loss: 0.0707 - categorical_accuracy: 0.9741
# Epoch 117/120
# 1/1 - 0s - loss: 0.0694 - categorical_accuracy: 0.9725
# Epoch 118/120
# 1/1 - 0s - loss: 0.0664 - categorical_accuracy: 0.9758
# Epoch 119/120
# 1/1 - 0s - loss: 0.0652 - categorical_accuracy: 0.9762
# Epoch 120/120
# 1/1 - 0s - loss: 0.0652 - categorical_accuracy: 0.9725
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0937 - categorical_accuracy: 0.8524
# Epoch 121/130
# 1/1 - 0s - loss: 0.0645 - categorical_accuracy: 0.9762
# Epoch 122/130
# 1/1 - 0s - loss: 0.0632 - categorical_accuracy: 0.9741
# Epoch 123/130
# 1/1 - 0s - loss: 0.0623 - categorical_accuracy: 0.9778
# Epoch 124/130
# 1/1 - 0s - loss: 0.0625 - categorical_accuracy: 0.9754
# Epoch 125/130
# 1/1 - 0s - loss: 0.0623 - categorical_accuracy: 0.9725
# Epoch 126/130
# 1/1 - 0s - loss: 0.0601 - categorical_accuracy: 0.9770
# Epoch 127/130
# 1/1 - 0s - loss: 0.0579 - categorical_accuracy: 0.9791
# Epoch 128/130
# 1/1 - 0s - loss: 0.0574 - categorical_accuracy: 0.9778
# Epoch 129/130
# 1/1 - 0s - loss: 0.0576 - categorical_accuracy: 0.9778
# Epoch 130/130
# 1/1 - 0s - loss: 0.0567 - categorical_accuracy: 0.9774
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0972 - categorical_accuracy: 0.8487
# Epoch 131/140
# 1/1 - 0s - loss: 0.0552 - categorical_accuracy: 0.9803
# Epoch 132/140
# 1/1 - 0s - loss: 0.0543 - categorical_accuracy: 0.9791
# Epoch 133/140
# 1/1 - 0s - loss: 0.0544 - categorical_accuracy: 0.9791
# Epoch 134/140
# 1/1 - 0s - loss: 0.0544 - categorical_accuracy: 0.9799
# Epoch 135/140
# 1/1 - 0s - loss: 0.0543 - categorical_accuracy: 0.9795
# Epoch 136/140
# 1/1 - 0s - loss: 0.0554 - categorical_accuracy: 0.9778
# Epoch 137/140
# 1/1 - 0s - loss: 0.0599 - categorical_accuracy: 0.9750
# Epoch 138/140
# 1/1 - 0s - loss: 0.0652 - categorical_accuracy: 0.9741
# Epoch 139/140
# 1/1 - 0s - loss: 0.0698 - categorical_accuracy: 0.9668
# Epoch 140/140
# 1/1 - 0s - loss: 0.0605 - categorical_accuracy: 0.9762
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0997 - categorical_accuracy: 0.8524
# Epoch 141/150
# 1/1 - 0s - loss: 0.0510 - categorical_accuracy: 0.9791
# Epoch 142/150
# 1/1 - 0s - loss: 0.0518 - categorical_accuracy: 0.9791
# Epoch 143/150
# 1/1 - 0s - loss: 0.0550 - categorical_accuracy: 0.9783
# Epoch 144/150
# 1/1 - 0s - loss: 0.0520 - categorical_accuracy: 0.9795
# Epoch 145/150
# 1/1 - 0s - loss: 0.0488 - categorical_accuracy: 0.9803
# Epoch 146/150
# 1/1 - 0s - loss: 0.0497 - categorical_accuracy: 0.9795
# Epoch 147/150
# 1/1 - 0s - loss: 0.0496 - categorical_accuracy: 0.9803
# Epoch 148/150
# 1/1 - 0s - loss: 0.0478 - categorical_accuracy: 0.9803
# Epoch 149/150
# 1/1 - 0s - loss: 0.0473 - categorical_accuracy: 0.9811
# Epoch 150/150
# 1/1 - 0s - loss: 0.0465 - categorical_accuracy: 0.9824
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1051 - categorical_accuracy: 0.8561
# Epoch 151/160
# 1/1 - 0s - loss: 0.0458 - categorical_accuracy: 0.9811
# Epoch 152/160
# 1/1 - 0s - loss: 0.0459 - categorical_accuracy: 0.9824
# Epoch 153/160
# 1/1 - 0s - loss: 0.0441 - categorical_accuracy: 0.9840
# Epoch 154/160
# 1/1 - 0s - loss: 0.0432 - categorical_accuracy: 0.9844
# Epoch 155/160
# 1/1 - 0s - loss: 0.0444 - categorical_accuracy: 0.9836
# Epoch 156/160
# 1/1 - 0s - loss: 0.0429 - categorical_accuracy: 0.9840
# Epoch 157/160
# 1/1 - 0s - loss: 0.0408 - categorical_accuracy: 0.9860
# Epoch 158/160
# 1/1 - 0s - loss: 0.0419 - categorical_accuracy: 0.9852
# Epoch 159/160
# 1/1 - 0s - loss: 0.0416 - categorical_accuracy: 0.9844
# Epoch 160/160
# 1/1 - 0s - loss: 0.0396 - categorical_accuracy: 0.9869
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1054 - categorical_accuracy: 0.8524
# Epoch 161/170
# 1/1 - 0s - loss: 0.0395 - categorical_accuracy: 0.9860
# Epoch 162/170
# 1/1 - 0s - loss: 0.0398 - categorical_accuracy: 0.9869
# Epoch 163/170
# 1/1 - 0s - loss: 0.0387 - categorical_accuracy: 0.9869
# Epoch 164/170
# 1/1 - 0s - loss: 0.0382 - categorical_accuracy: 0.9865
# Epoch 165/170
# 1/1 - 0s - loss: 0.0382 - categorical_accuracy: 0.9865
# Epoch 166/170
# 1/1 - 0s - loss: 0.0372 - categorical_accuracy: 0.9877
# Epoch 167/170
# 1/1 - 0s - loss: 0.0368 - categorical_accuracy: 0.9873
# Epoch 168/170
# 1/1 - 0s - loss: 0.0370 - categorical_accuracy: 0.9877
# Epoch 169/170
# 1/1 - 0s - loss: 0.0362 - categorical_accuracy: 0.9885
# Epoch 170/170
# 1/1 - 0s - loss: 0.0354 - categorical_accuracy: 0.9889
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1098 - categorical_accuracy: 0.8487
# Epoch 171/180
# 1/1 - 0s - loss: 0.0352 - categorical_accuracy: 0.9897
# Epoch 172/180
# 1/1 - 0s - loss: 0.0350 - categorical_accuracy: 0.9902
# Epoch 173/180
# 1/1 - 0s - loss: 0.0344 - categorical_accuracy: 0.9897
# Epoch 174/180
# 1/1 - 0s - loss: 0.0340 - categorical_accuracy: 0.9897
# Epoch 175/180
# 1/1 - 0s - loss: 0.0338 - categorical_accuracy: 0.9902
# Epoch 176/180
# 1/1 - 0s - loss: 0.0333 - categorical_accuracy: 0.9897
# Epoch 177/180
# 1/1 - 0s - loss: 0.0328 - categorical_accuracy: 0.9902
# Epoch 178/180
# 1/1 - 0s - loss: 0.0325 - categorical_accuracy: 0.9897
# Epoch 179/180
# 1/1 - 0s - loss: 0.0323 - categorical_accuracy: 0.9902
# Epoch 180/180
# 1/1 - 0s - loss: 0.0319 - categorical_accuracy: 0.9902
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1129 - categorical_accuracy: 0.8524
# Epoch 181/190
# 1/1 - 0s - loss: 0.0315 - categorical_accuracy: 0.9906
# Epoch 182/190
# 1/1 - 0s - loss: 0.0312 - categorical_accuracy: 0.9910
# Epoch 183/190
# 1/1 - 0s - loss: 0.0309 - categorical_accuracy: 0.9918
# Epoch 184/190
# 1/1 - 0s - loss: 0.0305 - categorical_accuracy: 0.9914
# Epoch 185/190
# 1/1 - 0s - loss: 0.0301 - categorical_accuracy: 0.9918
# Epoch 186/190
# 1/1 - 0s - loss: 0.0298 - categorical_accuracy: 0.9918
# Epoch 187/190
# 1/1 - 0s - loss: 0.0296 - categorical_accuracy: 0.9918
# Epoch 188/190
# 1/1 - 0s - loss: 0.0293 - categorical_accuracy: 0.9918
# Epoch 189/190
# 1/1 - 0s - loss: 0.0290 - categorical_accuracy: 0.9922
# Epoch 190/190
# 1/1 - 0s - loss: 0.0286 - categorical_accuracy: 0.9918
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1155 - categorical_accuracy: 0.8561
# Epoch 191/200
# 1/1 - 0s - loss: 0.0284 - categorical_accuracy: 0.9910
# Epoch 192/200
# 1/1 - 0s - loss: 0.0282 - categorical_accuracy: 0.9914
# Epoch 193/200
# 1/1 - 0s - loss: 0.0280 - categorical_accuracy: 0.9918
# Epoch 194/200
# 1/1 - 0s - loss: 0.0278 - categorical_accuracy: 0.9918
# Epoch 195/200
# 1/1 - 0s - loss: 0.0278 - categorical_accuracy: 0.9922
# Epoch 196/200
# 1/1 - 0s - loss: 0.0279 - categorical_accuracy: 0.9918
# Epoch 197/200
# 1/1 - 0s - loss: 0.0287 - categorical_accuracy: 0.9914
# Epoch 198/200
# 1/1 - 0s - loss: 0.0297 - categorical_accuracy: 0.9893
# Epoch 199/200
# 1/1 - 0s - loss: 0.0332 - categorical_accuracy: 0.9885
# Epoch 200/200
# 1/1 - 0s - loss: 0.0385 - categorical_accuracy: 0.9832
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1175 - categorical_accuracy: 0.8413
# Epoch 201/210
# 1/1 - 0s - loss: 0.0549 - categorical_accuracy: 0.9758
# Epoch 202/210
# 1/1 - 0s - loss: 0.0739 - categorical_accuracy: 0.9692
# Epoch 203/210
# 1/1 - 0s - loss: 0.0934 - categorical_accuracy: 0.9565
# Epoch 204/210
# 1/1 - 0s - loss: 0.0496 - categorical_accuracy: 0.9811
# Epoch 205/210
# 1/1 - 0s - loss: 0.0384 - categorical_accuracy: 0.9844
# Epoch 206/210
# 1/1 - 0s - loss: 0.0563 - categorical_accuracy: 0.9778
# Epoch 207/210
# 1/1 - 0s - loss: 0.0291 - categorical_accuracy: 0.9893
# Epoch 208/210
# 1/1 - 0s - loss: 0.0536 - categorical_accuracy: 0.9770
# Epoch 209/210
# 1/1 - 0s - loss: 0.0337 - categorical_accuracy: 0.9881
# Epoch 210/210
# 1/1 - 0s - loss: 0.0431 - categorical_accuracy: 0.9819
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1256 - categorical_accuracy: 0.8413
# Epoch 211/220
# 1/1 - 0s - loss: 0.0353 - categorical_accuracy: 0.9856
# Epoch 212/220
# 1/1 - 0s - loss: 0.0346 - categorical_accuracy: 0.9844
# Epoch 213/220
# 1/1 - 0s - loss: 0.0362 - categorical_accuracy: 0.9848
# Epoch 214/220
# 1/1 - 0s - loss: 0.0302 - categorical_accuracy: 0.9902
# Epoch 215/220
# 1/1 - 0s - loss: 0.0347 - categorical_accuracy: 0.9856
# Epoch 216/220
# 1/1 - 0s - loss: 0.0266 - categorical_accuracy: 0.9902
# Epoch 217/220
# 1/1 - 0s - loss: 0.0322 - categorical_accuracy: 0.9897
# Epoch 218/220
# 1/1 - 0s - loss: 0.0261 - categorical_accuracy: 0.9918
# Epoch 219/220
# 1/1 - 0s - loss: 0.0301 - categorical_accuracy: 0.9885
# Epoch 220/220
# 1/1 - 0s - loss: 0.0247 - categorical_accuracy: 0.9918
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1182 - categorical_accuracy: 0.8413
# Epoch 221/230
# 1/1 - 0s - loss: 0.0282 - categorical_accuracy: 0.9910
# Epoch 222/230
# 1/1 - 0s - loss: 0.0243 - categorical_accuracy: 0.9910
# Epoch 223/230
# 1/1 - 0s - loss: 0.0265 - categorical_accuracy: 0.9918
# Epoch 224/230
# 1/1 - 0s - loss: 0.0235 - categorical_accuracy: 0.9926
# Epoch 225/230
# 1/1 - 0s - loss: 0.0252 - categorical_accuracy: 0.9914
# Epoch 226/230
# 1/1 - 0s - loss: 0.0231 - categorical_accuracy: 0.9930
# Epoch 227/230
# 1/1 - 0s - loss: 0.0243 - categorical_accuracy: 0.9922
# Epoch 228/230
# 1/1 - 0s - loss: 0.0226 - categorical_accuracy: 0.9926
# Epoch 229/230
# 1/1 - 0s - loss: 0.0236 - categorical_accuracy: 0.9922
# Epoch 230/230
# 1/1 - 0s - loss: 0.0221 - categorical_accuracy: 0.9934
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1240 - categorical_accuracy: 0.8376
# Epoch 231/240
# 1/1 - 0s - loss: 0.0230 - categorical_accuracy: 0.9930
# Epoch 232/240
# 1/1 - 0s - loss: 0.0216 - categorical_accuracy: 0.9930
# Epoch 233/240
# 1/1 - 0s - loss: 0.0224 - categorical_accuracy: 0.9930
# Epoch 234/240
# 1/1 - 0s - loss: 0.0213 - categorical_accuracy: 0.9938
# Epoch 235/240
# 1/1 - 0s - loss: 0.0219 - categorical_accuracy: 0.9930
# Epoch 236/240
# 1/1 - 0s - loss: 0.0209 - categorical_accuracy: 0.9926
# Epoch 237/240
# 1/1 - 0s - loss: 0.0215 - categorical_accuracy: 0.9930
# Epoch 238/240
# 1/1 - 0s - loss: 0.0206 - categorical_accuracy: 0.9930
# Epoch 239/240
# 1/1 - 0s - loss: 0.0211 - categorical_accuracy: 0.9934
# Epoch 240/240
# 1/1 - 0s - loss: 0.0203 - categorical_accuracy: 0.9934
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1235 - categorical_accuracy: 0.8450
# Epoch 241/250
# 1/1 - 0s - loss: 0.0206 - categorical_accuracy: 0.9943
# Epoch 242/250
# 1/1 - 0s - loss: 0.0201 - categorical_accuracy: 0.9938
# Epoch 243/250
# 1/1 - 0s - loss: 0.0202 - categorical_accuracy: 0.9934
# Epoch 244/250
# 1/1 - 0s - loss: 0.0198 - categorical_accuracy: 0.9947
# Epoch 245/250
# 1/1 - 0s - loss: 0.0199 - categorical_accuracy: 0.9943
# Epoch 246/250
# 1/1 - 0s - loss: 0.0196 - categorical_accuracy: 0.9943
# Epoch 247/250
# 1/1 - 0s - loss: 0.0195 - categorical_accuracy: 0.9938
# Epoch 248/250
# 1/1 - 0s - loss: 0.0194 - categorical_accuracy: 0.9943
# Epoch 249/250
# 1/1 - 0s - loss: 0.0192 - categorical_accuracy: 0.9947
# Epoch 250/250
# 1/1 - 0s - loss: 0.0191 - categorical_accuracy: 0.9943
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1275 - categorical_accuracy: 0.8376
# Epoch 251/260
# 1/1 - 0s - loss: 0.0189 - categorical_accuracy: 0.9943
# Epoch 252/260
# 1/1 - 0s - loss: 0.0189 - categorical_accuracy: 0.9943
# Epoch 253/260
# 1/1 - 0s - loss: 0.0186 - categorical_accuracy: 0.9947
# Epoch 254/260
# 1/1 - 0s - loss: 0.0186 - categorical_accuracy: 0.9951
# Epoch 255/260
# 1/1 - 0s - loss: 0.0184 - categorical_accuracy: 0.9947
# Epoch 256/260
# 1/1 - 0s - loss: 0.0184 - categorical_accuracy: 0.9947
# Epoch 257/260
# 1/1 - 0s - loss: 0.0182 - categorical_accuracy: 0.9947
# Epoch 258/260
# 1/1 - 0s - loss: 0.0181 - categorical_accuracy: 0.9955
# Epoch 259/260
# 1/1 - 0s - loss: 0.0180 - categorical_accuracy: 0.9947
# Epoch 260/260
# 1/1 - 0s - loss: 0.0179 - categorical_accuracy: 0.9951
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1298 - categorical_accuracy: 0.8376
# Epoch 261/270
# 1/1 - 0s - loss: 0.0177 - categorical_accuracy: 0.9951
# Epoch 262/270
# 1/1 - 0s - loss: 0.0177 - categorical_accuracy: 0.9955
# Epoch 263/270
# 1/1 - 0s - loss: 0.0175 - categorical_accuracy: 0.9947
# Epoch 264/270
# 1/1 - 0s - loss: 0.0174 - categorical_accuracy: 0.9947
# Epoch 265/270
# 1/1 - 0s - loss: 0.0173 - categorical_accuracy: 0.9955
# Epoch 266/270
# 1/1 - 0s - loss: 0.0172 - categorical_accuracy: 0.9951
# Epoch 267/270
# 1/1 - 0s - loss: 0.0171 - categorical_accuracy: 0.9951
# Epoch 268/270
# 1/1 - 0s - loss: 0.0170 - categorical_accuracy: 0.9951
# Epoch 269/270
# 1/1 - 0s - loss: 0.0169 - categorical_accuracy: 0.9955
# Epoch 270/270
# 1/1 - 0s - loss: 0.0168 - categorical_accuracy: 0.9955
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1316 - categorical_accuracy: 0.8376
# Epoch 271/280
# 1/1 - 0s - loss: 0.0167 - categorical_accuracy: 0.9955
# Epoch 272/280
# 1/1 - 0s - loss: 0.0166 - categorical_accuracy: 0.9955
# Epoch 273/280
# 1/1 - 0s - loss: 0.0165 - categorical_accuracy: 0.9955
# Epoch 274/280
# 1/1 - 0s - loss: 0.0165 - categorical_accuracy: 0.9955
# Epoch 275/280
# 1/1 - 0s - loss: 0.0164 - categorical_accuracy: 0.9959
# Epoch 276/280
# 1/1 - 0s - loss: 0.0163 - categorical_accuracy: 0.9955
# Epoch 277/280
# 1/1 - 0s - loss: 0.0162 - categorical_accuracy: 0.9959
# Epoch 278/280
# 1/1 - 0s - loss: 0.0161 - categorical_accuracy: 0.9959
# Epoch 279/280
# 1/1 - 0s - loss: 0.0160 - categorical_accuracy: 0.9955
# Epoch 280/280
# 1/1 - 0s - loss: 0.0159 - categorical_accuracy: 0.9959
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1339 - categorical_accuracy: 0.8376
# Epoch 281/290
# 1/1 - 0s - loss: 0.0158 - categorical_accuracy: 0.9959
# Epoch 282/290
# 1/1 - 0s - loss: 0.0157 - categorical_accuracy: 0.9959
# Epoch 283/290
# 1/1 - 0s - loss: 0.0157 - categorical_accuracy: 0.9959
# Epoch 284/290
# 1/1 - 0s - loss: 0.0156 - categorical_accuracy: 0.9959
# Epoch 285/290
# 1/1 - 0s - loss: 0.0155 - categorical_accuracy: 0.9959
# Epoch 286/290
# 1/1 - 0s - loss: 0.0154 - categorical_accuracy: 0.9959
# Epoch 287/290
# 1/1 - 0s - loss: 0.0153 - categorical_accuracy: 0.9959
# Epoch 288/290
# 1/1 - 0s - loss: 0.0153 - categorical_accuracy: 0.9959
# Epoch 289/290
# 1/1 - 0s - loss: 0.0152 - categorical_accuracy: 0.9959
# Epoch 290/290
# 1/1 - 0s - loss: 0.0151 - categorical_accuracy: 0.9959
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1361 - categorical_accuracy: 0.8376
# Epoch 291/300
# 1/1 - 0s - loss: 0.0150 - categorical_accuracy: 0.9959
# Epoch 292/300
# 1/1 - 0s - loss: 0.0149 - categorical_accuracy: 0.9959
# Epoch 293/300
# 1/1 - 0s - loss: 0.0149 - categorical_accuracy: 0.9959
# Epoch 294/300
# 1/1 - 0s - loss: 0.0148 - categorical_accuracy: 0.9959
# Epoch 295/300
# 1/1 - 0s - loss: 0.0147 - categorical_accuracy: 0.9959
# Epoch 296/300
# 1/1 - 0s - loss: 0.0146 - categorical_accuracy: 0.9959
# Epoch 297/300
# 1/1 - 0s - loss: 0.0146 - categorical_accuracy: 0.9959
# Epoch 298/300
# 1/1 - 0s - loss: 0.0145 - categorical_accuracy: 0.9959
# Epoch 299/300
# 1/1 - 0s - loss: 0.0144 - categorical_accuracy: 0.9959
# Epoch 300/300
# 1/1 - 0s - loss: 0.0143 - categorical_accuracy: 0.9959
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1381 - categorical_accuracy: 0.8339
# Print Time for taining:  182.09375
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1381 - categorical_accuracy: 0.8339
# [0.13810418546199799, 0.8339483141899109]

# %% [markdown]
# ## Explaining Predictions
#
#
# Implementing the GNNInterface:

# %%
class ExplainableGCN(GNNInterface):

    def __init__(self, gnn_model, node_index, **kwargs):
        super(ExplainableGCN, self).__init__()
        self.gnn_model = gnn_model
        self.node_index = node_index

    def predict(self, gnn_input, masking_info=None):
        return tf.expand_dims(self.gnn_model(gnn_input, training=False)[0][self.node_index], 0)

    def masked_predict(self, gnn_input, edge_mask, feature_mask, node_mask, training=False):
        node_input, edge_input, edge_index_input = gnn_input

        masked_edge_input = tf.ragged.map_flat_values(tf.math.multiply, tf.dtypes.cast(edge_input, tf.float32),
                                                      edge_mask)
        masked_feature_input = tf.ragged.map_flat_values(tf.math.multiply, tf.dtypes.cast(node_input, tf.float32),
                                                         tf.transpose(feature_mask))
        masked_pred = tf.expand_dims(
            self.gnn_model([masked_feature_input, masked_edge_input, edge_index_input], training=training)[0][
                self.node_index], 0)
        return masked_pred

    def get_number_of_nodes(self, gnn_input):
        node_input, _, _ = gnn_input
        return node_input[0].shape[0]

    def get_number_of_node_features(self, gnn_input):
        node_input, _, _ = gnn_input
        return node_input[0].shape[1]

    def get_number_of_edges(self, gnn_input):
        _, edge_input, _ = gnn_input
        return edge_input[0].shape[0]

    def get_explanation(self, gnn_input, edge_mask, feature_mask, node_mask, node_labels=None):
        edge_relevance = np.array(edge_mask[:, 0])
        node_relevance = np.array(node_mask[:, 0])
        features = np.array(gnn_input[0][0])
        edges = np.array(gnn_input[2][0])
        g = nx.Graph()
        for i, f in enumerate(features):
            if node_labels is None:
                g.add_node(i, features=f, relevance=node_relevance[i])
            else:
                g.add_node(i, features=f, relevance=node_relevance[i], label=node_labels[i])
        for i, e in enumerate(edges):
            if edge_relevance is None:
                g.add_edge(e[0], e[1])
            else:
                g.add_edge(e[0], e[1], relevance=edge_relevance[i])
        return g

    def present_explanation(self, explanation, threshold=0.5):
        relevant_edges = []
        edge_color_map = []
        for (v, u, relevance) in explanation.edges.data('relevance'):
            if relevance > threshold:
                relevant_edges.append((v, u))
                edge_color_map.append((0, 0, 0, relevance))
        subgraph = explanation.edge_subgraph(relevant_edges)
        node_colors = []
        for n, l in subgraph.nodes.data('label'):
            r, g, b, a = get_label_color(l)
            a = subgraph.nodes[n]['relevance']
            node_colors.append((r, g, b, a))
        nx.draw(subgraph, node_color=node_colors, edge_color=edge_color_map, with_labels=True)

# %%
# Helper functions
def get_output_tensor_for_label(label):
    assert 0 <= label <= 6
    output_to_explain = np.zeros(7)
    output_to_explain[label] = 1.
    output_to_explain = np.expand_dims(output_to_explain, 0)
    return tf.Variable(output_to_explain)


def get_label_from_tensor(tensor_output):
    return np.argmax(tensor_output)

# %% [markdown]
# Choose a node to explain and instantiate an explainable GNN:

# %%
node_index = np.argwhere(val_mask[0] == 1)[:, 0][0]
# node_index = 9
explainable_gcn = ExplainableGCN(model, node_index)

# %% [markdown]
# Get the prediction of the GNN for the chosen node:

# %%
prediction = explainable_gcn.predict(xtrain)
predicted_label = get_label_from_tensor(prediction)
print('predicted label: ', predicted_label, get_label_name(predicted_label))
print("true label:", get_label_from_tensor(labels[node_index]))
print('node_index: ', node_index)
# Out:
# predicted label:  2 Neural_Networks
# true label: 2
# node_index:  9

# %% [markdown]
# Setup the GNNExplainer:

# %%
gnnexplaineroptimizer_options = {'edge_mask_loss_weight': 0.001,
                                 'edge_mask_norm_ord': 2,
                                 'feature_mask_loss_weight': 0,
                                 'feature_mask_norm_ord': 2,
                                 'node_mask_loss_weight': 0,
                                 'node_mask_norm_ord': 1}
compile_options = {'loss': 'categorical_crossentropy', 'optimizer': tf.keras.optimizers.Adam(lr=1)}
fit_options = {'epochs': 80, 'verbose': 0}

explainer = GNNExplainer(explainable_gcn,
                         compile_options=compile_options,
                         fit_options=fit_options,
                         gnnexplaineroptimizer_options=gnnexplaineroptimizer_options)

# %% [markdown]
# Explain the instance with index node_index:

# %%
# %%capture
inspection_result = explainer.explain(xtrain, inspection=True)
# Out:
# WARNING:tensorflow:Layer gnn_explainer_optimizer_1 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.

# %%
plt.figure()
explainer.present_explanation(explainer.get_explanation(node_labels=np.argmax(ytrain[0], axis=1)), threshold=0.1)
plt.show()

# %%
# Plot the inspection_result to see if we chose suitable parameters:
plt.figure()
for i in range(7):
    plt.plot(np.array(inspection_result['predictions'])[:, i], color=get_label_color(i))
plt.show()

# %%
# Plot Loss
plt.figure()
plt.plot(np.array(inspection_result['total_loss']), color="black")
plt.show()

# %%
# For comparison, the 2-hop graph around the chosen instance:
plt.figure()
cora_graph = nx.Graph()
cora_graph.add_nodes_from([(i, {"label": labels[i]}) for i in inds])
cora_graph.add_edges_from(edge_index)
hops = 2
khopgraph = nx.generators.ego.ego_graph(cora_graph, node_index, radius=hops)
for n in khopgraph.nodes:
    khopgraph.nodes[n]['label'] = np.argmax(khopgraph.nodes[n]['label'])
    khopgraph.nodes[n]['relevance'] = 1.
for (u, v) in khopgraph.edges:
    khopgraph.edges[u, v]['relevance'] = 1.0
explainer.present_explanation(khopgraph)
plt.show()
