# %%
import time

import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

from kgcnn.data.datasets.cora_lu import CoraLUDataset
from kgcnn.literature.GCN import make_model
from kgcnn.literature.GNNExplain import GNNExplainer, GNNInterface
from kgcnn.utils.adj import precompute_adjacency_scaled, sort_edge_indices, make_adjacency_from_edge_indices, \
    make_adjacency_undirected_logical_or, convert_scaled_adjacency_to_list
from kgcnn.utils.data import ragged_tensor_from_nested_numpy
from kgcnn.utils.learning import LinearLearningRateScheduler

# %% [markdown]
# ## Loading graph data

# %%
dataset = CoraLUDataset()
nodes, edge_index, labels, class_label_mapping = dataset.node_attributes, dataset.edge_indices, dataset.node_labels, dataset.class_label_mapping
labels = labels[0]
nodes = nodes[0][:, 1:]  # Remove IDs
edge_index = sort_edge_indices(edge_index[0])
adj_matrix = make_adjacency_from_edge_indices(edge_index)
adj_matrix = precompute_adjacency_scaled(make_adjacency_undirected_logical_or(adj_matrix))
edge_index, edge_weight = convert_scaled_adjacency_to_list(adj_matrix)
edge_weight = np.expand_dims(edge_weight, axis=-1)
# labels = np.expand_dims(labels, axis=-1)
# labels = np.array(labels == np.arange(7), dtype=np.float32)

# Find a color to visualize a label
def get_label_color(label):
    return plt.get_cmap('Set1')(label / 7)


# Map label to class
def get_label_name(label):
    return ["Case_Based",
            "Genetic_Algorithms",
            "Neural_Networks",
            "Probabilistic_Methods",
            "Reinforcement_Learning",
            "Rule_Learning",
            "Theory"][label]
# Out:
# INFO:kgcnn: Dataset directory located at C:\Users\Patrick\.kgcnn\datasets
# INFO:kgcnn: Dataset directory found... done
# INFO:kgcnn: Dataset found... done
# INFO:kgcnn: Directory for extraction exists... done
# INFO:kgcnn: Not extracting tar File... stopped

# %% [markdown]
# ## Train test split

# %%
# Make test/train split
# Since only one graph in the dataset
# Use a mask to hide test nodes labels
inds = np.arange(len(labels))
ind_train, ind_val = train_test_split(inds, test_size=0.10, random_state=0)
val_mask = np.zeros_like(inds)
train_mask = np.zeros_like(inds)
val_mask[ind_val] = 1
train_mask[ind_train] = 1
val_mask = np.expand_dims(val_mask, axis=0)  # One graph in batch
train_mask = np.expand_dims(train_mask, axis=0)  # One graph in batch

# Make ragged graph tensors with 1 graph in batch
nodes, edges, edge_indices = ragged_tensor_from_nested_numpy([nodes]), ragged_tensor_from_nested_numpy(
    [edge_weight]), ragged_tensor_from_nested_numpy([edge_index])  # One graph in batch

# Set training data. But requires mask and batch-dimension of 1
xtrain = nodes, edges, edge_indices
ytrain = np.expand_dims(labels, axis=0)  # One graph in batch
print([x.shape for x in xtrain])
print(ytrain.shape)
# Out:
# [TensorShape([1, None, 1432]), TensorShape([1, None, 1]), TensorShape([1, None, 2])]
# (1, 2708, 7)

# %% [markdown]
# ## Train GCN model on cora dataset

# %%
model = make_model(
    inputs= [{'shape': (None, 1432), 'name': "node_attributes", 'dtype': 'float32', 'ragged': True},
             {'shape': (None, 1), 'name': "edge_attributes", 'dtype': 'float32', 'ragged': True},
             {'shape': (None, 2), 'name': "edge_indices", 'dtype': 'int64', 'ragged': True}],
    output_embedding = 'node',
    output_mlp = {"use_bias": [True, True, False], "units": [64, 16, 7], "activation": ['relu', 'relu', 'softmax']},
    gcn_args = {"units": 124, "use_bias": True, "activation": 'relu', "pooling_method": 'sum'},
    depth = 3, 
    verbose =  1
)

# Set learning rate and epochs
learning_rate_start = 1e-3
learning_rate_stop = 1e-4
epo = 300
epomin = 260
epostep = 10

# Compile model with optimizer and loss
optimizer = tf.keras.optimizers.Adam(lr=learning_rate_start)
cbks = LinearLearningRateScheduler(learning_rate_start, learning_rate_stop, epomin, epo)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              weighted_metrics=['categorical_accuracy'])
print(model.summary())

# Training loop
trainlossall = []
testlossall = []
start = time.process_time()
for iepoch in range(0, epo, epostep):
    hist = model.fit(xtrain, ytrain,
                     epochs=iepoch + epostep,
                     initial_epoch=iepoch,
                     batch_size=1,
                     callbacks=[cbks],
                     verbose=2,
                     sample_weight=train_mask  # Important!!!
                     )

    trainlossall.append(hist.history)
    testlossall.append(model.evaluate(xtrain, ytrain, sample_weight=val_mask))
stop = time.process_time()
print("Print Time for taining: ", stop - start)

# Pick out accuracy
testlossall = np.array(testlossall)
trainlossall = np.concatenate([x['categorical_accuracy'] for x in trainlossall])

# Plot loss vs epochs
plt.figure()
plt.plot(np.arange(1, len(trainlossall) + 1), trainlossall, label='Training Loss', c='blue')
plt.plot(np.arange(epostep, epo + epostep, epostep), testlossall[:, 1], label='Test Loss', c='red')
plt.xlabel('Epochs')
plt.ylabel('Accurarcy')
plt.title('GCN')
plt.legend(loc='lower right', fontsize='x-large')
plt.savefig('gcn_explain_loss_cora.png')
plt.show()

# Evaluate model
model.evaluate(xtrain, ytrain, sample_weight=val_mask)
# Out:
# INFO:kgcnn: Updated model kwargs:
# {'depth': 3,
#  'gcn_args': {'activation': 'relu',
#               'has_unconnected': True,
#               'is_sorted': False,
#               'pooling_method': 'sum',
#               'units': 124,
#               'use_bias': True},
#  'input_embedding': {'edge': {'input_dim': 10, 'output_dim': 64},
#                      'node': {'input_dim': 95, 'output_dim': 64}},
#  'inputs': [{'dtype': 'float32',
#              'name': 'node_attributes',
#              'ragged': True,
#              'shape': (None, 1432)},
#             {'dtype': 'float32',
#              'name': 'edge_attributes',
#              'ragged': True,
#              'shape': (None, 1)},
#             {'dtype': 'int64',
#              'name': 'edge_indices',
#              'ragged': True,
#              'shape': (None, 2)}],
#  'name': 'GCN',
#  'output_embedding': 'node',
#  'output_mlp': {'activation': ['relu', 'relu', 'softmax'],
#                 'units': [64, 16, 7],
#                 'use_bias': [True, True, False]},
#  'verbose': 1}
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# node_attributes (InputLayer)    [(None, None, 1432)] 0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 124)    177692      node_attributes[0][0]
# __________________________________________________________________________________________________
# edge_attributes (InputLayer)    [(None, None, 1)]    0
# __________________________________________________________________________________________________
# edge_indices (InputLayer)       [(None, None, 2)]    0
# __________________________________________________________________________________________________
# gcn (GCN)                       (None, None, 124)    15500       dense[0][0]
#                                                                  edge_attributes[0][0]
#                                                                  edge_indices[0][0]
# __________________________________________________________________________________________________
# gcn_1 (GCN)                     (None, None, 124)    15500       gcn[0][0]
#                                                                  edge_attributes[0][0]
#                                                                  edge_indices[0][0]
# __________________________________________________________________________________________________
# gcn_2 (GCN)                     (None, None, 124)    15500       gcn_1[0][0]
#                                                                  edge_attributes[0][0]
#                                                                  edge_indices[0][0]
# __________________________________________________________________________________________________
# mlp (MLP)                       (None, None, 7)      9152        gcn_2[0][0]
# __________________________________________________________________________________________________
# change_tensor_type (ChangeTenso (None, None, 7)      0           mlp[0][0]
# ==================================================================================================
# Total params: 233,344
# Trainable params: 233,344
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/10
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/change_tensor_type/RaggedToTensor/boolean_mask_1/GatherV2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/change_tensor_type/RaggedToTensor/boolean_mask/GatherV2:0", shape=(None, 7), dtype=float32), dense_shape=Tensor("gradient_tape/model/change_tensor_type/RaggedToTensor/Shape:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn_2/pooling_weighted_local_edges_2/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/gcn_2/pooling_weighted_local_edges_2/Reshape:0", shape=(None, 124), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn_2/pooling_weighted_local_edges_2/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn_2/gather_nodes_outgoing_2/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/gcn_2/gather_nodes_outgoing_2/Reshape:0", shape=(None, 124), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn_2/gather_nodes_outgoing_2/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn_1/pooling_weighted_local_edges_1/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/gcn_1/pooling_weighted_local_edges_1/Reshape:0", shape=(None, 124), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn_1/pooling_weighted_local_edges_1/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn_1/gather_nodes_outgoing_1/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/gcn_1/gather_nodes_outgoing_1/Reshape:0", shape=(None, 124), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn_1/gather_nodes_outgoing_1/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn/pooling_weighted_local_edges/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/gcn/pooling_weighted_local_edges/Reshape:0", shape=(None, 124), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn/pooling_weighted_local_edges/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn/gather_nodes_outgoing/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/gcn/gather_nodes_outgoing/Reshape:0", shape=(None, 124), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn/gather_nodes_outgoing/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# 1/1 - 2s - loss: 1.7524 - categorical_accuracy: 0.1194
# Epoch 2/10
# 1/1 - 0s - loss: 1.7413 - categorical_accuracy: 0.3697
# Epoch 3/10
# 1/1 - 0s - loss: 1.7305 - categorical_accuracy: 0.5043
# Epoch 4/10
# 1/1 - 0s - loss: 1.7149 - categorical_accuracy: 0.5244
# Epoch 5/10
# 1/1 - 0s - loss: 1.6941 - categorical_accuracy: 0.5334
# Epoch 6/10
# 1/1 - 0s - loss: 1.6676 - categorical_accuracy: 0.5478
# Epoch 7/10
# 1/1 - 0s - loss: 1.6340 - categorical_accuracy: 0.5556
# Epoch 8/10
# 1/1 - 0s - loss: 1.5919 - categorical_accuracy: 0.5630
# Epoch 9/10
# 1/1 - 0s - loss: 1.5405 - categorical_accuracy: 0.5716
# Epoch 10/10
# 1/1 - 0s - loss: 1.4799 - categorical_accuracy: 0.5700
# 1/1 [==============================] - 0s 418ms/step - loss: 0.1617 - categorical_accuracy: 0.5387
# Epoch 11/20
# 1/1 - 0s - loss: 1.4112 - categorical_accuracy: 0.5728
# Epoch 12/20
# 1/1 - 0s - loss: 1.3361 - categorical_accuracy: 0.5815
# Epoch 13/20
# 1/1 - 0s - loss: 1.2578 - categorical_accuracy: 0.5884
# Epoch 14/20
# 1/1 - 0s - loss: 1.1802 - categorical_accuracy: 0.5925
# Epoch 15/20
# 1/1 - 0s - loss: 1.1072 - categorical_accuracy: 0.6003
# Epoch 16/20
# 1/1 - 0s - loss: 1.0409 - categorical_accuracy: 0.6094
# Epoch 17/20
# 1/1 - 0s - loss: 0.9800 - categorical_accuracy: 0.6192
# Epoch 18/20
# 1/1 - 0s - loss: 0.9227 - categorical_accuracy: 0.6381
# Epoch 19/20
# 1/1 - 0s - loss: 0.8667 - categorical_accuracy: 0.7009
# Epoch 20/20
# 1/1 - 0s - loss: 0.8108 - categorical_accuracy: 0.7534
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1011 - categorical_accuracy: 0.7343
# Epoch 21/30
# 1/1 - 0s - loss: 0.7557 - categorical_accuracy: 0.7702
# Epoch 22/30
# 1/1 - 0s - loss: 0.7027 - categorical_accuracy: 0.7805
# Epoch 23/30
# 1/1 - 0s - loss: 0.6522 - categorical_accuracy: 0.7899
# Epoch 24/30
# 1/1 - 0s - loss: 0.6042 - categorical_accuracy: 0.8100
# Epoch 25/30
# 1/1 - 0s - loss: 0.5581 - categorical_accuracy: 0.8412
# Epoch 26/30
# 1/1 - 0s - loss: 0.5138 - categorical_accuracy: 0.8646
# Epoch 27/30
# 1/1 - 0s - loss: 0.4722 - categorical_accuracy: 0.8822
# Epoch 28/30
# 1/1 - 0s - loss: 0.4347 - categorical_accuracy: 0.8921
# Epoch 29/30
# 1/1 - 0s - loss: 0.4015 - categorical_accuracy: 0.8950
# Epoch 30/30
# 1/1 - 0s - loss: 0.3727 - categorical_accuracy: 0.8999
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0582 - categorical_accuracy: 0.8524
# Epoch 31/40
# 1/1 - 0s - loss: 0.3513 - categorical_accuracy: 0.9015
# Epoch 32/40
# 1/1 - 0s - loss: 0.3429 - categorical_accuracy: 0.9023
# Epoch 33/40
# 1/1 - 0s - loss: 0.3153 - categorical_accuracy: 0.9064
# Epoch 34/40
# 1/1 - 0s - loss: 0.2912 - categorical_accuracy: 0.9105
# Epoch 35/40
# 1/1 - 0s - loss: 0.2912 - categorical_accuracy: 0.9122
# Epoch 36/40
# 1/1 - 0s - loss: 0.2662 - categorical_accuracy: 0.9183
# Epoch 37/40
# 1/1 - 0s - loss: 0.2579 - categorical_accuracy: 0.9163
# Epoch 38/40
# 1/1 - 0s - loss: 0.2523 - categorical_accuracy: 0.9171
# Epoch 39/40
# 1/1 - 0s - loss: 0.2328 - categorical_accuracy: 0.9200
# Epoch 40/40
# 1/1 - 0s - loss: 0.2324 - categorical_accuracy: 0.9192
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0510 - categorical_accuracy: 0.8745
# Epoch 41/50
# 1/1 - 0s - loss: 0.2216 - categorical_accuracy: 0.9212
# Epoch 42/50
# 1/1 - 0s - loss: 0.2117 - categorical_accuracy: 0.9270
# Epoch 43/50
# 1/1 - 0s - loss: 0.2120 - categorical_accuracy: 0.9220
# Epoch 44/50
# 1/1 - 0s - loss: 0.2007 - categorical_accuracy: 0.9282
# Epoch 45/50
# 1/1 - 0s - loss: 0.1969 - categorical_accuracy: 0.9282
# Epoch 46/50
# 1/1 - 0s - loss: 0.1953 - categorical_accuracy: 0.9241
# Epoch 47/50
# 1/1 - 0s - loss: 0.1852 - categorical_accuracy: 0.9307
# Epoch 48/50
# 1/1 - 0s - loss: 0.1843 - categorical_accuracy: 0.9302
# Epoch 49/50
# 1/1 - 0s - loss: 0.1802 - categorical_accuracy: 0.9307
# Epoch 50/50
# 1/1 - 0s - loss: 0.1726 - categorical_accuracy: 0.9335
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0517 - categorical_accuracy: 0.8745
# Epoch 51/60
# 1/1 - 0s - loss: 0.1725 - categorical_accuracy: 0.9348
# Epoch 52/60
# 1/1 - 0s - loss: 0.1682 - categorical_accuracy: 0.9352
# Epoch 53/60
# 1/1 - 0s - loss: 0.1626 - categorical_accuracy: 0.9368
# Epoch 54/60
# 1/1 - 0s - loss: 0.1616 - categorical_accuracy: 0.9389
# Epoch 55/60
# 1/1 - 0s - loss: 0.1581 - categorical_accuracy: 0.9405
# Epoch 56/60
# 1/1 - 0s - loss: 0.1531 - categorical_accuracy: 0.9421
# Epoch 57/60
# 1/1 - 0s - loss: 0.1515 - categorical_accuracy: 0.9421
# Epoch 58/60
# 1/1 - 0s - loss: 0.1493 - categorical_accuracy: 0.9450
# Epoch 59/60
# 1/1 - 0s - loss: 0.1448 - categorical_accuracy: 0.9450
# Epoch 60/60
# 1/1 - 0s - loss: 0.1424 - categorical_accuracy: 0.9450
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0530 - categorical_accuracy: 0.8856
# Epoch 61/70
# 1/1 - 0s - loss: 0.1414 - categorical_accuracy: 0.9491
# Epoch 62/70
# 1/1 - 0s - loss: 0.1381 - categorical_accuracy: 0.9475
# Epoch 63/70
# 1/1 - 0s - loss: 0.1346 - categorical_accuracy: 0.9503
# Epoch 64/70
# 1/1 - 0s - loss: 0.1330 - categorical_accuracy: 0.9503
# Epoch 65/70
# 1/1 - 0s - loss: 0.1313 - categorical_accuracy: 0.9528
# Epoch 66/70
# 1/1 - 0s - loss: 0.1287 - categorical_accuracy: 0.9508
# Epoch 67/70
# 1/1 - 0s - loss: 0.1258 - categorical_accuracy: 0.9553
# Epoch 68/70
# 1/1 - 0s - loss: 0.1237 - categorical_accuracy: 0.9557
# Epoch 69/70
# 1/1 - 0s - loss: 0.1223 - categorical_accuracy: 0.9528
# Epoch 70/70
# 1/1 - 0s - loss: 0.1207 - categorical_accuracy: 0.9557
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0577 - categorical_accuracy: 0.8745
# Epoch 71/80
# 1/1 - 0s - loss: 0.1185 - categorical_accuracy: 0.9512
# Epoch 72/80
# 1/1 - 0s - loss: 0.1160 - categorical_accuracy: 0.9549
# Epoch 73/80
# 1/1 - 0s - loss: 0.1137 - categorical_accuracy: 0.9553
# Epoch 74/80
# 1/1 - 0s - loss: 0.1118 - categorical_accuracy: 0.9573
# Epoch 75/80
# 1/1 - 0s - loss: 0.1105 - categorical_accuracy: 0.9565
# Epoch 76/80
# 1/1 - 0s - loss: 0.1092 - categorical_accuracy: 0.9557
# Epoch 77/80
# 1/1 - 0s - loss: 0.1080 - categorical_accuracy: 0.9618
# Epoch 78/80
# 1/1 - 0s - loss: 0.1066 - categorical_accuracy: 0.9561
# Epoch 79/80
# 1/1 - 0s - loss: 0.1053 - categorical_accuracy: 0.9610
# Epoch 80/80
# 1/1 - 0s - loss: 0.1044 - categorical_accuracy: 0.9553
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0633 - categorical_accuracy: 0.8745
# Epoch 81/90
# 1/1 - 0s - loss: 0.1036 - categorical_accuracy: 0.9594
# Epoch 82/90
# 1/1 - 0s - loss: 0.1030 - categorical_accuracy: 0.9569
# Epoch 83/90
# 1/1 - 0s - loss: 0.1019 - categorical_accuracy: 0.9618
# Epoch 84/90
# 1/1 - 0s - loss: 0.1005 - categorical_accuracy: 0.9557
# Epoch 85/90
# 1/1 - 0s - loss: 0.0982 - categorical_accuracy: 0.9631
# Epoch 86/90
# 1/1 - 0s - loss: 0.0959 - categorical_accuracy: 0.9590
# Epoch 87/90
# 1/1 - 0s - loss: 0.0941 - categorical_accuracy: 0.9631
# Epoch 88/90
# 1/1 - 0s - loss: 0.0924 - categorical_accuracy: 0.9635
# Epoch 89/90
# 1/1 - 0s - loss: 0.0906 - categorical_accuracy: 0.9635
# Epoch 90/90
# 1/1 - 0s - loss: 0.0889 - categorical_accuracy: 0.9659
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0672 - categorical_accuracy: 0.8708
# Epoch 91/100
# 1/1 - 0s - loss: 0.0881 - categorical_accuracy: 0.9631
# Epoch 92/100
# 1/1 - 0s - loss: 0.0882 - categorical_accuracy: 0.9647
# Epoch 93/100
# 1/1 - 0s - loss: 0.0885 - categorical_accuracy: 0.9627
# Epoch 94/100
# 1/1 - 0s - loss: 0.0887 - categorical_accuracy: 0.9643
# Epoch 95/100
# 1/1 - 0s - loss: 0.0893 - categorical_accuracy: 0.9627
# Epoch 96/100
# 1/1 - 0s - loss: 0.0901 - categorical_accuracy: 0.9651
# Epoch 97/100
# 1/1 - 0s - loss: 0.0906 - categorical_accuracy: 0.9586
# Epoch 98/100
# 1/1 - 0s - loss: 0.0849 - categorical_accuracy: 0.9680
# Epoch 99/100
# 1/1 - 0s - loss: 0.0791 - categorical_accuracy: 0.9672
# Epoch 100/100
# 1/1 - 0s - loss: 0.0783 - categorical_accuracy: 0.9664
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0727 - categorical_accuracy: 0.8635
# Epoch 101/110
# 1/1 - 0s - loss: 0.0808 - categorical_accuracy: 0.9672
# Epoch 102/110
# 1/1 - 0s - loss: 0.0803 - categorical_accuracy: 0.9664
# Epoch 103/110
# 1/1 - 0s - loss: 0.0762 - categorical_accuracy: 0.9696
# Epoch 104/110
# 1/1 - 0s - loss: 0.0744 - categorical_accuracy: 0.9709
# Epoch 105/110
# 1/1 - 0s - loss: 0.0750 - categorical_accuracy: 0.9684
# Epoch 106/110
# 1/1 - 0s - loss: 0.0743 - categorical_accuracy: 0.9705
# Epoch 107/110
# 1/1 - 0s - loss: 0.0729 - categorical_accuracy: 0.9705
# Epoch 108/110
# 1/1 - 0s - loss: 0.0718 - categorical_accuracy: 0.9709
# Epoch 109/110
# 1/1 - 0s - loss: 0.0705 - categorical_accuracy: 0.9721
# Epoch 110/110
# 1/1 - 0s - loss: 0.0688 - categorical_accuracy: 0.9713
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0753 - categorical_accuracy: 0.8598
# Epoch 111/120
# 1/1 - 0s - loss: 0.0681 - categorical_accuracy: 0.9717
# Epoch 112/120
# 1/1 - 0s - loss: 0.0687 - categorical_accuracy: 0.9750
# Epoch 113/120
# 1/1 - 0s - loss: 0.0682 - categorical_accuracy: 0.9713
# Epoch 114/120
# 1/1 - 0s - loss: 0.0662 - categorical_accuracy: 0.9750
# Epoch 115/120
# 1/1 - 0s - loss: 0.0644 - categorical_accuracy: 0.9725
# Epoch 116/120
# 1/1 - 0s - loss: 0.0638 - categorical_accuracy: 0.9750
# Epoch 117/120
# 1/1 - 0s - loss: 0.0634 - categorical_accuracy: 0.9770
# Epoch 118/120
# 1/1 - 0s - loss: 0.0624 - categorical_accuracy: 0.9746
# Epoch 119/120
# 1/1 - 0s - loss: 0.0613 - categorical_accuracy: 0.9787
# Epoch 120/120
# 1/1 - 0s - loss: 0.0610 - categorical_accuracy: 0.9746
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0794 - categorical_accuracy: 0.8598
# Epoch 121/130
# 1/1 - 0s - loss: 0.0610 - categorical_accuracy: 0.9754
# Epoch 122/130
# 1/1 - 0s - loss: 0.0603 - categorical_accuracy: 0.9766
# Epoch 123/130
# 1/1 - 0s - loss: 0.0595 - categorical_accuracy: 0.9787
# Epoch 124/130
# 1/1 - 0s - loss: 0.0585 - categorical_accuracy: 0.9754
# Epoch 125/130
# 1/1 - 0s - loss: 0.0582 - categorical_accuracy: 0.9791
# Epoch 126/130
# 1/1 - 0s - loss: 0.0577 - categorical_accuracy: 0.9746
# Epoch 127/130
# 1/1 - 0s - loss: 0.0571 - categorical_accuracy: 0.9791
# Epoch 128/130
# 1/1 - 0s - loss: 0.0559 - categorical_accuracy: 0.9766
# Epoch 129/130
# 1/1 - 0s - loss: 0.0550 - categorical_accuracy: 0.9803
# Epoch 130/130
# 1/1 - 0s - loss: 0.0541 - categorical_accuracy: 0.9778
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0843 - categorical_accuracy: 0.8561
# Epoch 131/140
# 1/1 - 0s - loss: 0.0537 - categorical_accuracy: 0.9787
# Epoch 132/140
# 1/1 - 0s - loss: 0.0530 - categorical_accuracy: 0.9795
# Epoch 133/140
# 1/1 - 0s - loss: 0.0522 - categorical_accuracy: 0.9799
# Epoch 134/140
# 1/1 - 0s - loss: 0.0511 - categorical_accuracy: 0.9807
# Epoch 135/140
# 1/1 - 0s - loss: 0.0502 - categorical_accuracy: 0.9815
# Epoch 136/140
# 1/1 - 0s - loss: 0.0495 - categorical_accuracy: 0.9811
# Epoch 137/140
# 1/1 - 0s - loss: 0.0491 - categorical_accuracy: 0.9824
# Epoch 138/140
# 1/1 - 0s - loss: 0.0487 - categorical_accuracy: 0.9795
# Epoch 139/140
# 1/1 - 0s - loss: 0.0484 - categorical_accuracy: 0.9836
# Epoch 140/140
# 1/1 - 0s - loss: 0.0478 - categorical_accuracy: 0.9799
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0903 - categorical_accuracy: 0.8524
# Epoch 141/150
# 1/1 - 0s - loss: 0.0475 - categorical_accuracy: 0.9832
# Epoch 142/150
# 1/1 - 0s - loss: 0.0471 - categorical_accuracy: 0.9819
# Epoch 143/150
# 1/1 - 0s - loss: 0.0478 - categorical_accuracy: 0.9844
# Epoch 144/150
# 1/1 - 0s - loss: 0.0489 - categorical_accuracy: 0.9803
# Epoch 145/150
# 1/1 - 0s - loss: 0.0526 - categorical_accuracy: 0.9787
# Epoch 146/150
# 1/1 - 0s - loss: 0.0545 - categorical_accuracy: 0.9774
# Epoch 147/150
# 1/1 - 0s - loss: 0.0582 - categorical_accuracy: 0.9762
# Epoch 148/150
# 1/1 - 0s - loss: 0.0524 - categorical_accuracy: 0.9770
# Epoch 149/150
# 1/1 - 0s - loss: 0.0469 - categorical_accuracy: 0.9815
# Epoch 150/150
# 1/1 - 0s - loss: 0.0438 - categorical_accuracy: 0.9828
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0975 - categorical_accuracy: 0.8413
# Epoch 151/160
# 1/1 - 0s - loss: 0.0461 - categorical_accuracy: 0.9815
# Epoch 152/160
# 1/1 - 0s - loss: 0.0468 - categorical_accuracy: 0.9840
# Epoch 153/160
# 1/1 - 0s - loss: 0.0423 - categorical_accuracy: 0.9824
# Epoch 154/160
# 1/1 - 0s - loss: 0.0422 - categorical_accuracy: 0.9844
# Epoch 155/160
# 1/1 - 0s - loss: 0.0440 - categorical_accuracy: 0.9840
# Epoch 156/160
# 1/1 - 0s - loss: 0.0411 - categorical_accuracy: 0.9860
# Epoch 157/160
# 1/1 - 0s - loss: 0.0395 - categorical_accuracy: 0.9865
# Epoch 158/160
# 1/1 - 0s - loss: 0.0410 - categorical_accuracy: 0.9848
# Epoch 159/160
# 1/1 - 0s - loss: 0.0399 - categorical_accuracy: 0.9860
# Epoch 160/160
# 1/1 - 0s - loss: 0.0377 - categorical_accuracy: 0.9860
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0991 - categorical_accuracy: 0.8524
# Epoch 161/170
# 1/1 - 0s - loss: 0.0380 - categorical_accuracy: 0.9856
# Epoch 162/170
# 1/1 - 0s - loss: 0.0387 - categorical_accuracy: 0.9869
# Epoch 163/170
# 1/1 - 0s - loss: 0.0370 - categorical_accuracy: 0.9873
# Epoch 164/170
# 1/1 - 0s - loss: 0.0358 - categorical_accuracy: 0.9865
# Epoch 165/170
# 1/1 - 0s - loss: 0.0366 - categorical_accuracy: 0.9869
# Epoch 166/170
# 1/1 - 0s - loss: 0.0365 - categorical_accuracy: 0.9873
# Epoch 167/170
# 1/1 - 0s - loss: 0.0348 - categorical_accuracy: 0.9885
# Epoch 168/170
# 1/1 - 0s - loss: 0.0346 - categorical_accuracy: 0.9885
# Epoch 169/170
# 1/1 - 0s - loss: 0.0352 - categorical_accuracy: 0.9873
# Epoch 170/170
# 1/1 - 0s - loss: 0.0344 - categorical_accuracy: 0.9889
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1040 - categorical_accuracy: 0.8487
# Epoch 171/180
# 1/1 - 0s - loss: 0.0333 - categorical_accuracy: 0.9889
# Epoch 172/180
# 1/1 - 0s - loss: 0.0332 - categorical_accuracy: 0.9881
# Epoch 173/180
# 1/1 - 0s - loss: 0.0334 - categorical_accuracy: 0.9893
# Epoch 174/180
# 1/1 - 0s - loss: 0.0328 - categorical_accuracy: 0.9889
# Epoch 175/180
# 1/1 - 0s - loss: 0.0319 - categorical_accuracy: 0.9902
# Epoch 176/180
# 1/1 - 0s - loss: 0.0318 - categorical_accuracy: 0.9906
# Epoch 177/180
# 1/1 - 0s - loss: 0.0319 - categorical_accuracy: 0.9897
# Epoch 178/180
# 1/1 - 0s - loss: 0.0314 - categorical_accuracy: 0.9906
# Epoch 179/180
# 1/1 - 0s - loss: 0.0307 - categorical_accuracy: 0.9897
# Epoch 180/180
# 1/1 - 0s - loss: 0.0304 - categorical_accuracy: 0.9897
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1088 - categorical_accuracy: 0.8450
# Epoch 181/190
# 1/1 - 0s - loss: 0.0304 - categorical_accuracy: 0.9910
# Epoch 182/190
# 1/1 - 0s - loss: 0.0302 - categorical_accuracy: 0.9897
# Epoch 183/190
# 1/1 - 0s - loss: 0.0296 - categorical_accuracy: 0.9906
# Epoch 184/190
# 1/1 - 0s - loss: 0.0291 - categorical_accuracy: 0.9902
# Epoch 185/190
# 1/1 - 0s - loss: 0.0290 - categorical_accuracy: 0.9906
# Epoch 186/190
# 1/1 - 0s - loss: 0.0289 - categorical_accuracy: 0.9918
# Epoch 187/190
# 1/1 - 0s - loss: 0.0286 - categorical_accuracy: 0.9906
# Epoch 188/190
# 1/1 - 0s - loss: 0.0282 - categorical_accuracy: 0.9918
# Epoch 189/190
# 1/1 - 0s - loss: 0.0277 - categorical_accuracy: 0.9906
# Epoch 190/190
# 1/1 - 0s - loss: 0.0275 - categorical_accuracy: 0.9906
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1126 - categorical_accuracy: 0.8487
# Epoch 191/200
# 1/1 - 0s - loss: 0.0274 - categorical_accuracy: 0.9918
# Epoch 192/200
# 1/1 - 0s - loss: 0.0272 - categorical_accuracy: 0.9914
# Epoch 193/200
# 1/1 - 0s - loss: 0.0269 - categorical_accuracy: 0.9918
# Epoch 194/200
# 1/1 - 0s - loss: 0.0265 - categorical_accuracy: 0.9906
# Epoch 195/200
# 1/1 - 0s - loss: 0.0262 - categorical_accuracy: 0.9918
# Epoch 196/200
# 1/1 - 0s - loss: 0.0260 - categorical_accuracy: 0.9910
# Epoch 197/200
# 1/1 - 0s - loss: 0.0258 - categorical_accuracy: 0.9918
# Epoch 198/200
# 1/1 - 0s - loss: 0.0256 - categorical_accuracy: 0.9910
# Epoch 199/200
# 1/1 - 0s - loss: 0.0254 - categorical_accuracy: 0.9914
# Epoch 200/200
# 1/1 - 0s - loss: 0.0251 - categorical_accuracy: 0.9910
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1160 - categorical_accuracy: 0.8450
# Epoch 201/210
# 1/1 - 0s - loss: 0.0248 - categorical_accuracy: 0.9918
# Epoch 202/210
# 1/1 - 0s - loss: 0.0245 - categorical_accuracy: 0.9918
# Epoch 203/210
# 1/1 - 0s - loss: 0.0242 - categorical_accuracy: 0.9910
# Epoch 204/210
# 1/1 - 0s - loss: 0.0241 - categorical_accuracy: 0.9918
# Epoch 205/210
# 1/1 - 0s - loss: 0.0239 - categorical_accuracy: 0.9910
# Epoch 206/210
# 1/1 - 0s - loss: 0.0238 - categorical_accuracy: 0.9930
# Epoch 207/210
# 1/1 - 0s - loss: 0.0236 - categorical_accuracy: 0.9926
# Epoch 208/210
# 1/1 - 0s - loss: 0.0235 - categorical_accuracy: 0.9930
# Epoch 209/210
# 1/1 - 0s - loss: 0.0236 - categorical_accuracy: 0.9926
# Epoch 210/210
# 1/1 - 0s - loss: 0.0241 - categorical_accuracy: 0.9934
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1202 - categorical_accuracy: 0.8376
# Epoch 211/220
# 1/1 - 0s - loss: 0.0248 - categorical_accuracy: 0.9918
# Epoch 212/220
# 1/1 - 0s - loss: 0.0275 - categorical_accuracy: 0.9897
# Epoch 213/220
# 1/1 - 0s - loss: 0.0306 - categorical_accuracy: 0.9885
# Epoch 214/220
# 1/1 - 0s - loss: 0.0446 - categorical_accuracy: 0.9815
# Epoch 215/220
# 1/1 - 0s - loss: 0.0800 - categorical_accuracy: 0.9631
# Epoch 216/220
# 1/1 - 0s - loss: 0.2509 - categorical_accuracy: 0.9134
# Epoch 217/220
# 1/1 - 0s - loss: 0.3656 - categorical_accuracy: 0.9060
# Epoch 218/220
# 1/1 - 0s - loss: 0.0457 - categorical_accuracy: 0.9811
# Epoch 219/220
# 1/1 - 0s - loss: 0.2445 - categorical_accuracy: 0.9220
# Epoch 220/220
# 1/1 - 0s - loss: 0.0453 - categorical_accuracy: 0.9824
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1316 - categorical_accuracy: 0.8524
# Epoch 221/230
# 1/1 - 0s - loss: 0.1456 - categorical_accuracy: 0.9508
# Epoch 222/230
# 1/1 - 0s - loss: 0.0871 - categorical_accuracy: 0.9680
# Epoch 223/230
# 1/1 - 0s - loss: 0.0552 - categorical_accuracy: 0.9741
# Epoch 224/230
# 1/1 - 0s - loss: 0.1224 - categorical_accuracy: 0.9499
# Epoch 225/230
# 1/1 - 0s - loss: 0.0447 - categorical_accuracy: 0.9795
# Epoch 226/230
# 1/1 - 0s - loss: 0.0675 - categorical_accuracy: 0.9725
# Epoch 227/230
# 1/1 - 0s - loss: 0.0850 - categorical_accuracy: 0.9664
# Epoch 228/230
# 1/1 - 0s - loss: 0.0482 - categorical_accuracy: 0.9799
# Epoch 229/230
# 1/1 - 0s - loss: 0.0460 - categorical_accuracy: 0.9787
# Epoch 230/230
# 1/1 - 0s - loss: 0.0677 - categorical_accuracy: 0.9659
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1199 - categorical_accuracy: 0.8487
# Epoch 231/240
# 1/1 - 0s - loss: 0.0480 - categorical_accuracy: 0.9762
# Epoch 232/240
# 1/1 - 0s - loss: 0.0365 - categorical_accuracy: 0.9824
# Epoch 233/240
# 1/1 - 0s - loss: 0.0492 - categorical_accuracy: 0.9807
# Epoch 234/240
# 1/1 - 0s - loss: 0.0490 - categorical_accuracy: 0.9795
# Epoch 235/240
# 1/1 - 0s - loss: 0.0327 - categorical_accuracy: 0.9873
# Epoch 236/240
# 1/1 - 0s - loss: 0.0357 - categorical_accuracy: 0.9840
# Epoch 237/240
# 1/1 - 0s - loss: 0.0440 - categorical_accuracy: 0.9811
# Epoch 238/240
# 1/1 - 0s - loss: 0.0320 - categorical_accuracy: 0.9885
# Epoch 239/240
# 1/1 - 0s - loss: 0.0303 - categorical_accuracy: 0.9881
# Epoch 240/240
# 1/1 - 0s - loss: 0.0371 - categorical_accuracy: 0.9836
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1181 - categorical_accuracy: 0.8561
# Epoch 241/250
# 1/1 - 0s - loss: 0.0352 - categorical_accuracy: 0.9865
# Epoch 242/250
# 1/1 - 0s - loss: 0.0274 - categorical_accuracy: 0.9902
# Epoch 243/250
# 1/1 - 0s - loss: 0.0284 - categorical_accuracy: 0.9897
# Epoch 244/250
# 1/1 - 0s - loss: 0.0330 - categorical_accuracy: 0.9897
# Epoch 245/250
# 1/1 - 0s - loss: 0.0295 - categorical_accuracy: 0.9902
# Epoch 246/250
# 1/1 - 0s - loss: 0.0249 - categorical_accuracy: 0.9914
# Epoch 247/250
# 1/1 - 0s - loss: 0.0271 - categorical_accuracy: 0.9902
# Epoch 248/250
# 1/1 - 0s - loss: 0.0294 - categorical_accuracy: 0.9893
# Epoch 249/250
# 1/1 - 0s - loss: 0.0261 - categorical_accuracy: 0.9910
# Epoch 250/250
# 1/1 - 0s - loss: 0.0241 - categorical_accuracy: 0.9910
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1191 - categorical_accuracy: 0.8413
# Epoch 251/260
# 1/1 - 0s - loss: 0.0260 - categorical_accuracy: 0.9914
# Epoch 252/260
# 1/1 - 0s - loss: 0.0260 - categorical_accuracy: 0.9918
# Epoch 253/260
# 1/1 - 0s - loss: 0.0236 - categorical_accuracy: 0.9918
# Epoch 254/260
# 1/1 - 0s - loss: 0.0230 - categorical_accuracy: 0.9922
# Epoch 255/260
# 1/1 - 0s - loss: 0.0243 - categorical_accuracy: 0.9926
# Epoch 256/260
# 1/1 - 0s - loss: 0.0238 - categorical_accuracy: 0.9922
# Epoch 257/260
# 1/1 - 0s - loss: 0.0221 - categorical_accuracy: 0.9930
# Epoch 258/260
# 1/1 - 0s - loss: 0.0222 - categorical_accuracy: 0.9930
# Epoch 259/260
# 1/1 - 0s - loss: 0.0230 - categorical_accuracy: 0.9914
# Epoch 260/260
# 1/1 - 0s - loss: 0.0221 - categorical_accuracy: 0.9926
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1210 - categorical_accuracy: 0.8487
# Epoch 261/270
# 1/1 - 0s - loss: 0.0211 - categorical_accuracy: 0.9930
# Epoch 262/270
# 1/1 - 0s - loss: 0.0215 - categorical_accuracy: 0.9934
# Epoch 263/270
# 1/1 - 0s - loss: 0.0217 - categorical_accuracy: 0.9934
# Epoch 264/270
# 1/1 - 0s - loss: 0.0209 - categorical_accuracy: 0.9930
# Epoch 265/270
# 1/1 - 0s - loss: 0.0205 - categorical_accuracy: 0.9938
# Epoch 266/270
# 1/1 - 0s - loss: 0.0208 - categorical_accuracy: 0.9938
# Epoch 267/270
# 1/1 - 0s - loss: 0.0207 - categorical_accuracy: 0.9943
# Epoch 268/270
# 1/1 - 0s - loss: 0.0202 - categorical_accuracy: 0.9930
# Epoch 269/270
# 1/1 - 0s - loss: 0.0200 - categorical_accuracy: 0.9922
# Epoch 270/270
# 1/1 - 0s - loss: 0.0201 - categorical_accuracy: 0.9930
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1228 - categorical_accuracy: 0.8450
# Epoch 271/280
# 1/1 - 0s - loss: 0.0200 - categorical_accuracy: 0.9934
# Epoch 272/280
# 1/1 - 0s - loss: 0.0197 - categorical_accuracy: 0.9934
# Epoch 273/280
# 1/1 - 0s - loss: 0.0195 - categorical_accuracy: 0.9938
# Epoch 274/280
# 1/1 - 0s - loss: 0.0195 - categorical_accuracy: 0.9947
# Epoch 275/280
# 1/1 - 0s - loss: 0.0195 - categorical_accuracy: 0.9943
# Epoch 276/280
# 1/1 - 0s - loss: 0.0193 - categorical_accuracy: 0.9938
# Epoch 277/280
# 1/1 - 0s - loss: 0.0191 - categorical_accuracy: 0.9938
# Epoch 278/280
# 1/1 - 0s - loss: 0.0191 - categorical_accuracy: 0.9943
# Epoch 279/280
# 1/1 - 0s - loss: 0.0191 - categorical_accuracy: 0.9938
# Epoch 280/280
# 1/1 - 0s - loss: 0.0190 - categorical_accuracy: 0.9934
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1238 - categorical_accuracy: 0.8450
# Epoch 281/290
# 1/1 - 0s - loss: 0.0188 - categorical_accuracy: 0.9938
# Epoch 282/290
# 1/1 - 0s - loss: 0.0187 - categorical_accuracy: 0.9938
# Epoch 283/290
# 1/1 - 0s - loss: 0.0187 - categorical_accuracy: 0.9947
# Epoch 284/290
# 1/1 - 0s - loss: 0.0187 - categorical_accuracy: 0.9951
# Epoch 285/290
# 1/1 - 0s - loss: 0.0186 - categorical_accuracy: 0.9947
# Epoch 286/290
# 1/1 - 0s - loss: 0.0185 - categorical_accuracy: 0.9947
# Epoch 287/290
# 1/1 - 0s - loss: 0.0185 - categorical_accuracy: 0.9934
# Epoch 288/290
# 1/1 - 0s - loss: 0.0184 - categorical_accuracy: 0.9938
# Epoch 289/290
# 1/1 - 0s - loss: 0.0184 - categorical_accuracy: 0.9938
# Epoch 290/290
# 1/1 - 0s - loss: 0.0184 - categorical_accuracy: 0.9938
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1247 - categorical_accuracy: 0.8450
# Epoch 291/300
# 1/1 - 0s - loss: 0.0183 - categorical_accuracy: 0.9938
# Epoch 292/300
# 1/1 - 0s - loss: 0.0183 - categorical_accuracy: 0.9934
# Epoch 293/300
# 1/1 - 0s - loss: 0.0182 - categorical_accuracy: 0.9934
# Epoch 294/300
# 1/1 - 0s - loss: 0.0182 - categorical_accuracy: 0.9943
# Epoch 295/300
# 1/1 - 0s - loss: 0.0182 - categorical_accuracy: 0.9943
# Epoch 296/300
# 1/1 - 0s - loss: 0.0181 - categorical_accuracy: 0.9951
# Epoch 297/300
# 1/1 - 0s - loss: 0.0181 - categorical_accuracy: 0.9951
# Epoch 298/300
# 1/1 - 0s - loss: 0.0181 - categorical_accuracy: 0.9951
# Epoch 299/300
# 1/1 - 0s - loss: 0.0181 - categorical_accuracy: 0.9947
# Epoch 300/300
# 1/1 - 0s - loss: 0.0180 - categorical_accuracy: 0.9947
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1251 - categorical_accuracy: 0.8450
# Print Time for taining:  17.140625
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1251 - categorical_accuracy: 0.8450
# [0.12514738738536835, 0.8450184464454651]

# %% [markdown]
# ## Explaining Predictions
#
#
# Implementing the GNNInterface:

# %%
class ExplainableGCN(GNNInterface):

    def __init__(self, gnn_model, node_index, **kwargs):
        super(ExplainableGCN, self).__init__()
        self.gnn_model = gnn_model
        self.node_index = node_index

    def predict(self, gnn_input, masking_info=None):
        return tf.expand_dims(self.gnn_model(gnn_input, training=False)[0][self.node_index], 0)

    def masked_predict(self, gnn_input, edge_mask, feature_mask, node_mask, training=False):
        node_input, edge_input, edge_index_input = gnn_input

        masked_edge_input = tf.ragged.map_flat_values(tf.math.multiply, tf.dtypes.cast(edge_input, tf.float32),
                                                      edge_mask)
        masked_feature_input = tf.ragged.map_flat_values(tf.math.multiply, tf.dtypes.cast(node_input, tf.float32),
                                                         tf.transpose(feature_mask))
        masked_pred = tf.expand_dims(
            self.gnn_model([masked_feature_input, masked_edge_input, edge_index_input], training=training)[0][
                self.node_index], 0)
        return masked_pred

    def get_number_of_nodes(self, gnn_input):
        node_input, _, _ = gnn_input
        return node_input[0].shape[0]

    def get_number_of_node_features(self, gnn_input):
        node_input, _, _ = gnn_input
        return node_input[0].shape[1]

    def get_number_of_edges(self, gnn_input):
        _, edge_input, _ = gnn_input
        return edge_input[0].shape[0]

    def get_explanation(self, gnn_input, edge_mask, feature_mask, node_mask, node_labels=None):
        edge_relevance = np.array(edge_mask[:, 0])
        node_relevance = np.array(node_mask[:, 0])
        features = np.array(gnn_input[0][0])
        edges = np.array(gnn_input[2][0])
        g = nx.Graph()
        for i, f in enumerate(features):
            if node_labels is None:
                g.add_node(i, features=f, relevance=node_relevance[i])
            else:
                g.add_node(i, features=f, relevance=node_relevance[i], label=node_labels[i])
        for i, e in enumerate(edges):
            if edge_relevance is None:
                g.add_edge(e[0], e[1])
            else:
                g.add_edge(e[0], e[1], relevance=edge_relevance[i])
        return g

    def present_explanation(self, explanation, threshold=0.5):
        relevant_edges = []
        edge_color_map = []
        for (v, u, relevance) in explanation.edges.data('relevance'):
            if relevance > threshold:
                relevant_edges.append((v, u))
                edge_color_map.append((0, 0, 0, relevance))
        subgraph = explanation.edge_subgraph(relevant_edges)
        node_colors = []
        for n, l in subgraph.nodes.data('label'):
            r, g, b, a = get_label_color(l)
            a = subgraph.nodes[n]['relevance']
            node_colors.append((r, g, b, a))
        nx.draw(subgraph, node_color=node_colors, edge_color=edge_color_map, with_labels=True)

# %%
# Helper functions
def get_output_tensor_for_label(label):
    assert 0 <= label <= 6
    output_to_explain = np.zeros(7)
    output_to_explain[label] = 1.
    output_to_explain = np.expand_dims(output_to_explain, 0)
    return tf.Variable(output_to_explain)


def get_label_from_tensor(tensor_output):
    return np.argmax(tensor_output)

# %% [markdown]
# Choose a node to explain and instantiate an explainable GNN:

# %%
node_index = np.argwhere(val_mask[0] == 1)[:, 0][0]
# node_index = 9
explainable_gcn = ExplainableGCN(model, node_index)

# %% [markdown]
# Get the prediction of the GNN for the chosen node:

# %%
prediction = explainable_gcn.predict(xtrain)
predicted_label = get_label_from_tensor(prediction)
print('predicted label: ', predicted_label, get_label_name(predicted_label))
print("true label:", get_label_from_tensor(labels[node_index]))
print('node_index: ', node_index)
# Out:
# predicted label:  2 Neural_Networks
# true label: 2
# node_index:  9

# %% [markdown]
# Setup the GNNExplainer:

# %%
gnnexplaineroptimizer_options = {'edge_mask_loss_weight': 0.001,
                                 'edge_mask_norm_ord': 2,
                                 'feature_mask_loss_weight': 0,
                                 'feature_mask_norm_ord': 2,
                                 'node_mask_loss_weight': 0,
                                 'node_mask_norm_ord': 1}
compile_options = {'loss': 'categorical_crossentropy', 'optimizer': tf.keras.optimizers.Adam(lr=1)}
fit_options = {'epochs': 80, 'verbose': 0}

explainer = GNNExplainer(explainable_gcn,
                         compile_options=compile_options,
                         fit_options=fit_options,
                         gnnexplaineroptimizer_options=gnnexplaineroptimizer_options)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %% [markdown]
# Explain the instance with index node_index:

# %%
# %%capture
inspection_result = explainer.explain(xtrain, inspection=True)

# %%
plt.figure()
explainer.present_explanation(explainer.get_explanation(node_labels=np.argmax(ytrain[0], axis=1)), threshold=0.1)
plt.show()

# %%
# Plot the inspection_result to see if we chose suitable parameters:
plt.figure()
for i in range(7):
    plt.plot(np.array(inspection_result['predictions'])[:, i], color=get_label_color(i))
plt.show()

# %%
# Plot Loss
plt.figure()
plt.plot(np.array(inspection_result['total_loss']), color="black")
plt.show()

# %%
# For comparison, the 2-hop graph around the chosen instance:
plt.figure()
cora_graph = nx.Graph()
cora_graph.add_nodes_from([(i, {"label": labels[i]}) for i in inds])
cora_graph.add_edges_from(edge_index)
hops = 2
khopgraph = nx.generators.ego.ego_graph(cora_graph, node_index, radius=hops)
for n in khopgraph.nodes:
    khopgraph.nodes[n]['label'] = np.argmax(khopgraph.nodes[n]['label'])
    khopgraph.nodes[n]['relevance'] = 1.
for (u, v) in khopgraph.edges:
    khopgraph.edges[u, v]['relevance'] = 1.0
explainer.present_explanation(khopgraph)
plt.show()
