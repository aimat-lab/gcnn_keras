# %%
import time

import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

from kgcnn.data.datasets.cora_lu import CoraLUDataset
from kgcnn.literature.GCN import make_model
from kgcnn.literature.GNNExplain import GNNExplainer, GNNInterface
from kgcnn.utils.adj import precompute_adjacency_scaled, sort_edge_indices, make_adjacency_from_edge_indices, \
    make_adjacency_undirected_logical_or, convert_scaled_adjacency_to_list
from kgcnn.utils.data import ragged_tensor_from_nested_numpy
from kgcnn.utils.learning import LinearLearningRateScheduler

# %% [markdown]
# ## Loading graph data

# %%
dataset = CoraLUDataset()
nodes, edge_index, labels, class_label_mapping = dataset.node_attributes, dataset.edge_indices, dataset.node_labels, dataset.class_label_mapping
labels = labels[0]
nodes = nodes[0][:, 1:]  # Remove IDs
edge_index = sort_edge_indices(edge_index[0])
adj_matrix = make_adjacency_from_edge_indices(edge_index)
adj_matrix = precompute_adjacency_scaled(make_adjacency_undirected_logical_or(adj_matrix))
edge_index, edge_weight = convert_scaled_adjacency_to_list(adj_matrix)
edge_weight = np.expand_dims(edge_weight, axis=-1)
# labels = np.expand_dims(labels, axis=-1)
# labels = np.array(labels == np.arange(7), dtype=np.float32)

# Find a color to visualize a label
def get_label_color(label):
    return plt.get_cmap('Set1')(label / 7)


# Map label to class
def get_label_name(label):
    return ["Case_Based",
            "Genetic_Algorithms",
            "Neural_Networks",
            "Probabilistic_Methods",
            "Reinforcement_Learning",
            "Rule_Learning",
            "Theory"][label]
# Out:
# WARNING:kgcnn: Unknown kwargs for `DownloadDataset`: ['fits_in_memory']
# INFO:kgcnn: Dataset directory located at C:\Users\Patrick\.kgcnn\datasets
# INFO:kgcnn: Dataset directory found... done
# INFO:kgcnn: Dataset found... done
# INFO:kgcnn: Directory for extraction exists... done
# INFO:kgcnn: Not extracting tar File... stopped

# %% [markdown]
# ## Train test split

# %%
# Make test/train split
# Since only one graph in the dataset
# Use a mask to hide test nodes labels
inds = np.arange(len(labels))
ind_train, ind_val = train_test_split(inds, test_size=0.10, random_state=0)
val_mask = np.zeros_like(inds)
train_mask = np.zeros_like(inds)
val_mask[ind_val] = 1
train_mask[ind_train] = 1
val_mask = np.expand_dims(val_mask, axis=0)  # One graph in batch
train_mask = np.expand_dims(train_mask, axis=0)  # One graph in batch

# Make ragged graph tensors with 1 graph in batch
nodes, edges, edge_indices = ragged_tensor_from_nested_numpy([nodes]), ragged_tensor_from_nested_numpy(
    [edge_weight]), ragged_tensor_from_nested_numpy([edge_index])  # One graph in batch

# Set training data. But requires mask and batch-dimension of 1
xtrain = nodes, edges, edge_indices
ytrain = np.expand_dims(labels, axis=0)  # One graph in batch
print([x.shape for x in xtrain])
print(ytrain.shape)
# Out:
# [TensorShape([1, None, 1432]), TensorShape([1, None, 1]), TensorShape([1, None, 2])]
# (1, 2708, 7)

# %% [markdown]
# ## Train GCN model on cora dataset

# %%
model = make_model(
    inputs= [{'shape': (None, 1432), 'name': "node_attributes", 'dtype': 'float32', 'ragged': True},
             {'shape': (None, 1), 'name': "edge_attributes", 'dtype': 'float32', 'ragged': True},
             {'shape': (None, 2), 'name': "edge_indices", 'dtype': 'int64', 'ragged': True}],
    output_embedding = 'node',
    output_mlp = {"use_bias": [True, True, False], "units": [64, 16, 7], "activation": ['relu', 'relu', 'softmax']},
    gcn_args = {"units": 124, "use_bias": True, "activation": 'relu', "pooling_method": 'sum'},
    depth = 3, 
    verbose =  1
)

# Set learning rate and epochs
learning_rate_start = 1e-3
learning_rate_stop = 1e-4
epo = 300
epomin = 260
epostep = 10

# Compile model with optimizer and loss
optimizer = tf.keras.optimizers.Adam(lr=learning_rate_start)
cbks = LinearLearningRateScheduler(learning_rate_start, learning_rate_stop, epomin, epo)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              weighted_metrics=['categorical_accuracy'])
print(model.summary())

# Training loop
trainlossall = []
testlossall = []
start = time.process_time()
for iepoch in range(0, epo, epostep):
    hist = model.fit(xtrain, ytrain,
                     epochs=iepoch + epostep,
                     initial_epoch=iepoch,
                     batch_size=1,
                     callbacks=[cbks],
                     verbose=2,
                     sample_weight=train_mask  # Important!!!
                     )

    trainlossall.append(hist.history)
    testlossall.append(model.evaluate(xtrain, ytrain, sample_weight=val_mask))
stop = time.process_time()
print("Print Time for taining: ", stop - start)

# Pick out accuracy
testlossall = np.array(testlossall)
trainlossall = np.concatenate([x['categorical_accuracy'] for x in trainlossall])

# Plot loss vs epochs
plt.figure()
plt.plot(np.arange(1, len(trainlossall) + 1), trainlossall, label='Training Loss', c='blue')
plt.plot(np.arange(epostep, epo + epostep, epostep), testlossall[:, 1], label='Test Loss', c='red')
plt.xlabel('Epochs')
plt.ylabel('Accurarcy')
plt.title('GCN')
plt.legend(loc='lower right', fontsize='x-large')
plt.savefig('gcn_explain_loss_cora.png')
plt.show()

# Evaluate model
model.evaluate(xtrain, ytrain, sample_weight=val_mask)
# Out:
# INFO:kgcnn: Updated model kwargs:
# {'depth': 3,
#  'gcn_args': {'activation': 'relu',
#               'has_unconnected': True,
#               'is_sorted': False,
#               'pooling_method': 'sum',
#               'units': 124,
#               'use_bias': True},
#  'input_embedding': {'edge': {'input_dim': 10, 'output_dim': 64},
#                      'node': {'input_dim': 95, 'output_dim': 64}},
#  'inputs': [{'dtype': 'float32',
#              'name': 'node_attributes',
#              'ragged': True,
#              'shape': (None, 1432)},
#             {'dtype': 'float32',
#              'name': 'edge_attributes',
#              'ragged': True,
#              'shape': (None, 1)},
#             {'dtype': 'int64',
#              'name': 'edge_indices',
#              'ragged': True,
#              'shape': (None, 2)}],
#  'name': 'GCN',
#  'output_embedding': 'node',
#  'output_mlp': {'activation': ['relu', 'relu', 'softmax'],
#                 'units': [64, 16, 7],
#                 'use_bias': [True, True, False]},
#  'verbose': 1}
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  node_attributes (InputLayer)   [(None, None, 1432)  0           []
#                                 ]
#
#  dense (Dense)                  (None, None, 124)    177692      ['node_attributes[0][0]']
#
#  edge_attributes (InputLayer)   [(None, None, 1)]    0           []
#
#  edge_indices (InputLayer)      [(None, None, 2)]    0           []
#
#  gcn (GCN)                      (None, None, 124)    15500       ['dense[0][0]',
#                                                                   'edge_attributes[0][0]',
#                                                                   'edge_indices[0][0]']
#
#  gcn_1 (GCN)                    (None, None, 124)    15500       ['gcn[0][0]',
#                                                                   'edge_attributes[0][0]',
#                                                                   'edge_indices[0][0]']
#
#  gcn_2 (GCN)                    (None, None, 124)    15500       ['gcn_1[0][0]',
#                                                                   'edge_attributes[0][0]',
#                                                                   'edge_indices[0][0]']
#
#  mlp (MLP)                      (None, None, 7)      9152        ['gcn_2[0][0]']
#
#  change_tensor_type (ChangeTens  (None, None, 7)     0           ['mlp[0][0]']
#  orType)
#
# ==================================================================================================
# Total params: 233,344
# Trainable params: 233,344
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/10
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/change_tensor_type/RaggedToTensor/boolean_mask_1/GatherV2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/change_tensor_type/RaggedToTensor/boolean_mask/GatherV2:0", shape=(None, 7), dtype=float32), dense_shape=Tensor("gradient_tape/model/change_tensor_type/RaggedToTensor/Shape:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn_2/pooling_weighted_local_edges_2/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/gcn_2/pooling_weighted_local_edges_2/Reshape:0", shape=(None, 124), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn_2/pooling_weighted_local_edges_2/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn_2/gather_nodes_outgoing_2/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/gcn_2/gather_nodes_outgoing_2/Reshape:0", shape=(None, 124), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn_2/gather_nodes_outgoing_2/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn_1/pooling_weighted_local_edges_1/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/gcn_1/pooling_weighted_local_edges_1/Reshape:0", shape=(None, 124), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn_1/pooling_weighted_local_edges_1/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn_1/gather_nodes_outgoing_1/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/gcn_1/gather_nodes_outgoing_1/Reshape:0", shape=(None, 124), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn_1/gather_nodes_outgoing_1/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn/pooling_weighted_local_edges/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/gcn/pooling_weighted_local_edges/Reshape:0", shape=(None, 124), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn/pooling_weighted_local_edges/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn/gather_nodes_outgoing/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/gcn/gather_nodes_outgoing/Reshape:0", shape=(None, 124), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn/gather_nodes_outgoing/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# 1/1 - 2s - loss: 1.7510 - categorical_accuracy: 0.1547 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 2/10
# 1/1 - 0s - loss: 1.7347 - categorical_accuracy: 0.3734 - lr: 0.0010 - 26ms/epoch - 26ms/step
# Epoch 3/10
# 1/1 - 0s - loss: 1.7183 - categorical_accuracy: 0.4140 - lr: 0.0010 - 26ms/epoch - 26ms/step
# Epoch 4/10
# 1/1 - 0s - loss: 1.6983 - categorical_accuracy: 0.4071 - lr: 0.0010 - 26ms/epoch - 26ms/step
# Epoch 5/10
# 1/1 - 0s - loss: 1.6727 - categorical_accuracy: 0.4190 - lr: 0.0010 - 25ms/epoch - 25ms/step
# Epoch 6/10
# 1/1 - 0s - loss: 1.6409 - categorical_accuracy: 0.4333 - lr: 0.0010 - 26ms/epoch - 26ms/step
# Epoch 7/10
# 1/1 - 0s - loss: 1.6029 - categorical_accuracy: 0.4387 - lr: 0.0010 - 26ms/epoch - 26ms/step
# Epoch 8/10
# 1/1 - 0s - loss: 1.5583 - categorical_accuracy: 0.4378 - lr: 0.0010 - 26ms/epoch - 26ms/step
# Epoch 9/10
# 1/1 - 0s - loss: 1.5068 - categorical_accuracy: 0.4395 - lr: 0.0010 - 25ms/epoch - 25ms/step
# Epoch 10/10
# 1/1 - 0s - loss: 1.4490 - categorical_accuracy: 0.4407 - lr: 0.0010 - 26ms/epoch - 26ms/step
# 1/1 [==============================] - 1s 502ms/step - loss: 0.1575 - categorical_accuracy: 0.4244
# Epoch 11/20
# 1/1 - 0s - loss: 1.3865 - categorical_accuracy: 0.4411 - lr: 0.0010 - 28ms/epoch - 28ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 1.3224 - categorical_accuracy: 0.4415 - lr: 0.0010 - 27ms/epoch - 27ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 1.2594 - categorical_accuracy: 0.4477 - lr: 0.0010 - 26ms/epoch - 26ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 1.1971 - categorical_accuracy: 0.4555 - lr: 0.0010 - 25ms/epoch - 25ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 1.1371 - categorical_accuracy: 0.4670 - lr: 0.0010 - 30ms/epoch - 30ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 1.0815 - categorical_accuracy: 0.4694 - lr: 0.0010 - 28ms/epoch - 28ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 1.0289 - categorical_accuracy: 0.4793 - lr: 0.0010 - 27ms/epoch - 27ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 0.9782 - categorical_accuracy: 0.5174 - lr: 0.0010 - 27ms/epoch - 27ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 0.9292 - categorical_accuracy: 0.5630 - lr: 0.0010 - 26ms/epoch - 26ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 0.8815 - categorical_accuracy: 0.6229 - lr: 0.0010 - 25ms/epoch - 25ms/step
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1001 - categorical_accuracy: 0.6827
# Epoch 21/30
# 1/1 - 0s - loss: 0.8329 - categorical_accuracy: 0.6820 - lr: 0.0010 - 27ms/epoch - 27ms/step
# Epoch 22/30
# 1/1 - 0s - loss: 0.7822 - categorical_accuracy: 0.7197 - lr: 0.0010 - 25ms/epoch - 25ms/step
# Epoch 23/30
# 1/1 - 0s - loss: 0.7293 - categorical_accuracy: 0.7653 - lr: 0.0010 - 26ms/epoch - 26ms/step
# Epoch 24/30
# 1/1 - 0s - loss: 0.6748 - categorical_accuracy: 0.8145 - lr: 0.0010 - 27ms/epoch - 27ms/step
# Epoch 25/30
# 1/1 - 0s - loss: 0.6205 - categorical_accuracy: 0.8465 - lr: 0.0010 - 27ms/epoch - 27ms/step
# Epoch 26/30
# 1/1 - 0s - loss: 0.5677 - categorical_accuracy: 0.8613 - lr: 0.0010 - 26ms/epoch - 26ms/step
# Epoch 27/30
# 1/1 - 0s - loss: 0.5165 - categorical_accuracy: 0.8740 - lr: 0.0010 - 26ms/epoch - 26ms/step
# Epoch 28/30
# 1/1 - 0s - loss: 0.4685 - categorical_accuracy: 0.8806 - lr: 0.0010 - 25ms/epoch - 25ms/step
# Epoch 29/30
# 1/1 - 0s - loss: 0.4262 - categorical_accuracy: 0.8863 - lr: 0.0010 - 25ms/epoch - 25ms/step
# Epoch 30/30
# 1/1 - 0s - loss: 0.3901 - categorical_accuracy: 0.8896 - lr: 0.0010 - 26ms/epoch - 26ms/step
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0561 - categorical_accuracy: 0.8819
# Epoch 31/40
# 1/1 - 0s - loss: 0.3603 - categorical_accuracy: 0.8941 - lr: 0.0010 - 25ms/epoch - 25ms/step
# Epoch 32/40
# 1/1 - 0s - loss: 0.3361 - categorical_accuracy: 0.8991 - lr: 0.0010 - 27ms/epoch - 27ms/step
# Epoch 33/40
# 1/1 - 0s - loss: 0.3171 - categorical_accuracy: 0.9007 - lr: 0.0010 - 29ms/epoch - 29ms/step
# Epoch 34/40
# 1/1 - 0s - loss: 0.3008 - categorical_accuracy: 0.9032 - lr: 0.0010 - 26ms/epoch - 26ms/step
# Epoch 35/40
# 1/1 - 0s - loss: 0.2870 - categorical_accuracy: 0.9073 - lr: 0.0010 - 29ms/epoch - 29ms/step
# Epoch 36/40
# 1/1 - 0s - loss: 0.2749 - categorical_accuracy: 0.9105 - lr: 0.0010 - 28ms/epoch - 28ms/step
# Epoch 37/40
# 1/1 - 0s - loss: 0.2634 - categorical_accuracy: 0.9122 - lr: 0.0010 - 28ms/epoch - 28ms/step
# Epoch 38/40
# 1/1 - 0s - loss: 0.2539 - categorical_accuracy: 0.9151 - lr: 0.0010 - 26ms/epoch - 26ms/step
# Epoch 39/40
# 1/1 - 0s - loss: 0.2509 - categorical_accuracy: 0.9146 - lr: 0.0010 - 24ms/epoch - 24ms/step
# Epoch 40/40
# 1/1 - 0s - loss: 0.2575 - categorical_accuracy: 0.9142 - lr: 0.0010 - 25ms/epoch - 25ms/step
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0512 - categorical_accuracy: 0.8819
# Epoch 41/50
# 1/1 - 0s - loss: 0.2403 - categorical_accuracy: 0.9118 - lr: 0.0010 - 26ms/epoch - 26ms/step
# Epoch 42/50
# 1/1 - 0s - loss: 0.2272 - categorical_accuracy: 0.9171 - lr: 0.0010 - 26ms/epoch - 26ms/step
# Epoch 43/50
# 1/1 - 0s - loss: 0.2338 - categorical_accuracy: 0.9171 - lr: 0.0010 - 32ms/epoch - 32ms/step
# Epoch 44/50
# 1/1 - 0s - loss: 0.2126 - categorical_accuracy: 0.9253 - lr: 0.0010 - 26ms/epoch - 26ms/step
# Epoch 45/50
# 1/1 - 0s - loss: 0.2183 - categorical_accuracy: 0.9175 - lr: 0.0010 - 28ms/epoch - 28ms/step
# Epoch 46/50
# 1/1 - 0s - loss: 0.2044 - categorical_accuracy: 0.9245 - lr: 0.0010 - 27ms/epoch - 27ms/step
# Epoch 47/50
# 1/1 - 0s - loss: 0.2057 - categorical_accuracy: 0.9200 - lr: 0.0010 - 27ms/epoch - 27ms/step
# Epoch 48/50
# 1/1 - 0s - loss: 0.1968 - categorical_accuracy: 0.9253 - lr: 0.0010 - 28ms/epoch - 28ms/step
# Epoch 49/50
# 1/1 - 0s - loss: 0.1945 - categorical_accuracy: 0.9249 - lr: 0.0010 - 34ms/epoch - 34ms/step
# Epoch 50/50
# 1/1 - 0s - loss: 0.1891 - categorical_accuracy: 0.9261 - lr: 0.0010 - 36ms/epoch - 36ms/step
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0530 - categorical_accuracy: 0.8782
# Epoch 51/60
# 1/1 - 0s - loss: 0.1856 - categorical_accuracy: 0.9257 - lr: 0.0010 - 26ms/epoch - 26ms/step
# Epoch 52/60
# 1/1 - 0s - loss: 0.1827 - categorical_accuracy: 0.9257 - lr: 0.0010 - 26ms/epoch - 26ms/step
# Epoch 53/60
# 1/1 - 0s - loss: 0.1781 - categorical_accuracy: 0.9298 - lr: 0.0010 - 27ms/epoch - 27ms/step
# Epoch 54/60
# 1/1 - 0s - loss: 0.1754 - categorical_accuracy: 0.9294 - lr: 0.0010 - 24ms/epoch - 24ms/step
# Epoch 55/60
# 1/1 - 0s - loss: 0.1714 - categorical_accuracy: 0.9311 - lr: 0.0010 - 24ms/epoch - 24ms/step
# Epoch 56/60
# 1/1 - 0s - loss: 0.1681 - categorical_accuracy: 0.9319 - lr: 0.0010 - 29ms/epoch - 29ms/step
# Epoch 57/60
# 1/1 - 0s - loss: 0.1655 - categorical_accuracy: 0.9343 - lr: 0.0010 - 25ms/epoch - 25ms/step
# Epoch 58/60
# 1/1 - 0s - loss: 0.1611 - categorical_accuracy: 0.9352 - lr: 0.0010 - 28ms/epoch - 28ms/step
# Epoch 59/60
# 1/1 - 0s - loss: 0.1595 - categorical_accuracy: 0.9348 - lr: 0.0010 - 27ms/epoch - 27ms/step
# Epoch 60/60
# 1/1 - 0s - loss: 0.1547 - categorical_accuracy: 0.9376 - lr: 0.0010 - 28ms/epoch - 28ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0530 - categorical_accuracy: 0.8745
# Epoch 61/70
# 1/1 - 0s - loss: 0.1534 - categorical_accuracy: 0.9384 - lr: 0.0010 - 30ms/epoch - 30ms/step
# Epoch 62/70
# 1/1 - 0s - loss: 0.1493 - categorical_accuracy: 0.9397 - lr: 0.0010 - 26ms/epoch - 26ms/step
# Epoch 63/70
# 1/1 - 0s - loss: 0.1474 - categorical_accuracy: 0.9409 - lr: 0.0010 - 27ms/epoch - 27ms/step
# Epoch
- lr: 0.0010 - 26ms/epoch - 26ms/step
# Epoch 247/250
# 1/1 - 0s - loss: 0.0177 - categorical_accuracy: 0.9951 - lr: 0.0010 - 27ms/epoch - 27ms/step
# Epoch 248/250
# 1/1 - 0s - loss: 0.0175 - categorical_accuracy: 0.9955 - lr: 0.0010 - 32ms/epoch - 32ms/step
# Epoch 249/250
# 1/1 - 0s - loss: 0.0174 - categorical_accuracy: 0.9955 - lr: 0.0010 - 27ms/epoch - 27ms/step
# Epoch 250/250
# 1/1 - 0s - loss: 0.0173 - categorical_accuracy: 0.9963 - lr: 0.0010 - 28ms/epoch - 28ms/step
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1349 - categorical_accuracy: 0.8376
# Epoch 251/260
# 1/1 - 0s - loss: 0.0172 - categorical_accuracy: 0.9959 - lr: 0.0010 - 27ms/epoch - 27ms/step
# Epoch 252/260
# 1/1 - 0s - loss: 0.0170 - categorical_accuracy: 0.9959 - lr: 0.0010 - 28ms/epoch - 28ms/step
# Epoch 253/260
# 1/1 - 0s - loss: 0.0169 - categorical_accuracy: 0.9959 - lr: 0.0010 - 26ms/epoch - 26ms/step
# Epoch 254/260
# 1/1 - 0s - loss: 0.0168 - categorical_accuracy: 0.9959 - lr: 0.0010 - 27ms/epoch - 27ms/step
# Epoch 255/260
# 1/1 - 0s - loss: 0.0167 - categorical_accuracy: 0.9955 - lr: 0.0010 - 28ms/epoch - 28ms/step
# Epoch 256/260
# 1/1 - 0s - loss: 0.0165 - categorical_accuracy: 0.9959 - lr: 0.0010 - 28ms/epoch - 28ms/step
# Epoch 257/260
# 1/1 - 0s - loss: 0.0164 - categorical_accuracy: 0.9959 - lr: 0.0010 - 27ms/epoch - 27ms/step
# Epoch 258/260
# 1/1 - 0s - loss: 0.0163 - categorical_accuracy: 0.9955 - lr: 0.0010 - 29ms/epoch - 29ms/step
# Epoch 259/260
# 1/1 - 0s - loss: 0.0162 - categorical_accuracy: 0.9959 - lr: 0.0010 - 25ms/epoch - 25ms/step
# Epoch 260/260
# 1/1 - 0s - loss: 0.0161 - categorical_accuracy: 0.9963 - lr: 0.0010 - 26ms/epoch - 26ms/step
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1374 - categorical_accuracy: 0.8339
# Epoch 261/270
# 1/1 - 0s - loss: 0.0159 - categorical_accuracy: 0.9963 - lr: 0.0010 - 25ms/epoch - 25ms/step
# Epoch 262/270
# 1/1 - 0s - loss: 0.0158 - categorical_accuracy: 0.9963 - lr: 9.7750e-04 - 29ms/epoch - 29ms/step
# Epoch 263/270
# 1/1 - 0s - loss: 0.0157 - categorical_accuracy: 0.9959 - lr: 9.5500e-04 - 28ms/epoch - 28ms/step
# Epoch 264/270
# 1/1 - 0s - loss: 0.0156 - categorical_accuracy: 0.9963 - lr: 9.3250e-04 - 33ms/epoch - 33ms/step
# Epoch 265/270
# 1/1 - 0s - loss: 0.0155 - categorical_accuracy: 0.9967 - lr: 9.1000e-04 - 29ms/epoch - 29ms/step
# Epoch 266/270
# 1/1 - 0s - loss: 0.0154 - categorical_accuracy: 0.9959 - lr: 8.8750e-04 - 27ms/epoch - 27ms/step
# Epoch 267/270
# 1/1 - 0s - loss: 0.0153 - categorical_accuracy: 0.9959 - lr: 8.6500e-04 - 28ms/epoch - 28ms/step
# Epoch 268/270
# 1/1 - 0s - loss: 0.0152 - categorical_accuracy: 0.9963 - lr: 8.4250e-04 - 31ms/epoch - 31ms/step
# Epoch 269/270
# 1/1 - 0s - loss: 0.0151 - categorical_accuracy: 0.9963 - lr: 8.2000e-04 - 26ms/epoch - 26ms/step
# Epoch 270/270
# 1/1 - 0s - loss: 0.0150 - categorical_accuracy: 0.9967 - lr: 7.9750e-04 - 30ms/epoch - 30ms/step
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1397 - categorical_accuracy: 0.8376
# Epoch 271/280
# 1/1 - 0s - loss: 0.0149 - categorical_accuracy: 0.9967 - lr: 7.7500e-04 - 28ms/epoch - 28ms/step
# Epoch 272/280
# 1/1 - 0s - loss: 0.0149 - categorical_accuracy: 0.9971 - lr: 7.5250e-04 - 26ms/epoch - 26ms/step
# Epoch 273/280
# 1/1 - 0s - loss: 0.0148 - categorical_accuracy: 0.9967 - lr: 7.3000e-04 - 26ms/epoch - 26ms/step
# Epoch 274/280
# 1/1 - 0s - loss: 0.0147 - categorical_accuracy: 0.9971 - lr: 7.0750e-04 - 27ms/epoch - 27ms/step
# Epoch 275/280
# 1/1 - 0s - loss: 0.0146 - categorical_accuracy: 0.9975 - lr: 6.8500e-04 - 28ms/epoch - 28ms/step
# Epoch 276/280
# 1/1 - 0s - loss: 0.0146 - categorical_accuracy: 0.9975 - lr: 6.6250e-04 - 28ms/epoch - 28ms/step
# Epoch 277/280
# 1/1 - 0s - loss: 0.0145 - categorical_accuracy: 0.9975 - lr: 6.4000e-04 - 28ms/epoch - 28ms/step
# Epoch 278/280
# 1/1 - 0s - loss: 0.0144 - categorical_accuracy: 0.9975 - lr: 6.1750e-04 - 27ms/epoch - 27ms/step
# Epoch 279/280
# 1/1 - 0s - loss: 0.0144 - categorical_accuracy: 0.9971 - lr: 5.9500e-04 - 27ms/epoch - 27ms/step
# Epoch 280/280
# 1/1 - 0s - loss: 0.0143 - categorical_accuracy: 0.9971 - lr: 5.7250e-04 - 26ms/epoch - 26ms/step
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1415 - categorical_accuracy: 0.8376
# Epoch 281/290
# 1/1 - 0s - loss: 0.0142 - categorical_accuracy: 0.9975 - lr: 5.5000e-04 - 29ms/epoch - 29ms/step
# Epoch 282/290
# 1/1 - 0s - loss: 0.0142 - categorical_accuracy: 0.9979 - lr: 5.2750e-04 - 29ms/epoch - 29ms/step
# Epoch 283/290
# 1/1 - 0s - loss: 0.0141 - categorical_accuracy: 0.9975 - lr: 5.0500e-04 - 28ms/epoch - 28ms/step
# Epoch 284/290
# 1/1 - 0s - loss: 0.0141 - categorical_accuracy: 0.9975 - lr: 4.8250e-04 - 28ms/epoch - 28ms/step
# Epoch 285/290
# 1/1 - 0s - loss: 0.0140 - categorical_accuracy: 0.9975 - lr: 4.6000e-04 - 26ms/epoch - 26ms/step
# Epoch 286/290
# 1/1 - 0s - loss: 0.0140 - categorical_accuracy: 0.9979 - lr: 4.3750e-04 - 27ms/epoch - 27ms/step
# Epoch 287/290
# 1/1 - 0s - loss: 0.0139 - categorical_accuracy: 0.9979 - lr: 4.1500e-04 - 27ms/epoch - 27ms/step
# Epoch 288/290
# 1/1 - 0s - loss: 0.0139 - categorical_accuracy: 0.9975 - lr: 3.9250e-04 - 27ms/epoch - 27ms/step
# Epoch 289/290
# 1/1 - 0s - loss: 0.0139 - categorical_accuracy: 0.9975 - lr: 3.7000e-04 - 28ms/epoch - 28ms/step
# Epoch 290/290
# 1/1 - 0s - loss: 0.0138 - categorical_accuracy: 0.9975 - lr: 3.4750e-04 - 29ms/epoch - 29ms/step
# 1/1 [==============================] - 0s 30ms/step - loss: 0.1425 - categorical_accuracy: 0.8376
# Epoch 291/300
# 1/1 - 0s - loss: 0.0138 - categorical_accuracy: 0.9975 - lr: 3.2500e-04 - 29ms/epoch - 29ms/step
# Epoch 292/300
# 1/1 - 0s - loss: 0.0138 - categorical_accuracy: 0.9979 - lr: 3.0250e-04 - 30ms/epoch - 30ms/step
# Epoch 293/300
# 1/1 - 0s - loss: 0.0137 - categorical_accuracy: 0.9979 - lr: 2.8000e-04 - 28ms/epoch - 28ms/step
# Epoch 294/300
# 1/1 - 0s - loss: 0.0137 - categorical_accuracy: 0.9979 - lr: 2.5750e-04 - 26ms/epoch - 26ms/step
# Epoch 295/300
# 1/1 - 0s - loss: 0.0137 - categorical_accuracy: 0.9979 - lr: 2.3500e-04 - 25ms/epoch - 25ms/step
# Epoch 296/300
# 1/1 - 0s - loss: 0.0136 - categorical_accuracy: 0.9979 - lr: 2.1250e-04 - 26ms/epoch - 26ms/step
# Epoch 297/300
# 1/1 - 0s - loss: 0.0136 - categorical_accuracy: 0.9975 - lr: 1.9000e-04 - 25ms/epoch - 25ms/step
# Epoch 298/300
# 1/1 - 0s - loss: 0.0136 - categorical_accuracy: 0.9975 - lr: 1.6750e-04 - 31ms/epoch - 31ms/step
# Epoch 299/300
# 1/1 - 0s - loss: 0.0136 - categorical_accuracy: 0.9975 - lr: 1.4500e-04 - 28ms/epoch - 28ms/step
# Epoch 300/300
# 1/1 - 0s - loss: 0.0136 - categorical_accuracy: 0.9975 - lr: 1.2250e-04 - 26ms/epoch - 26ms/step
# 1/1 [==============================] - 0s 30ms/step - loss: 0.1430 - categorical_accuracy: 0.8376
# Print Time for taining:  20.640625
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1430 - categorical_accuracy: 0.8376
# [0.14301486313343048, 0.8376383781433105]

# %% [markdown]
# ## Explaining Predictions
#
#
# Implementing the GNNInterface:

# %%
class ExplainableGCN(GNNInterface):

    def __init__(self, gnn_model, node_index, **kwargs):
        super(ExplainableGCN, self).__init__()
        self.gnn_model = gnn_model
        self.node_index = node_index

    def predict(self, gnn_input, masking_info=None):
        return tf.expand_dims(self.gnn_model(gnn_input, training=False)[0][self.node_index], 0)

    def masked_predict(self, gnn_input, edge_mask, feature_mask, node_mask, training=False):
        node_input, edge_input, edge_index_input = gnn_input

        masked_edge_input = tf.ragged.map_flat_values(tf.math.multiply, tf.dtypes.cast(edge_input, tf.float32),
                                                      edge_mask)
        masked_feature_input = tf.ragged.map_flat_values(tf.math.multiply, tf.dtypes.cast(node_input, tf.float32),
                                                         tf.transpose(feature_mask))
        masked_pred = tf.expand_dims(
            self.gnn_model([masked_feature_input, masked_edge_input, edge_index_input], training=training)[0][
                self.node_index], 0)
        return masked_pred

    def get_number_of_nodes(self, gnn_input):
        node_input, _, _ = gnn_input
        return node_input[0].shape[0]

    def get_number_of_node_features(self, gnn_input):
        node_input, _, _ = gnn_input
        return node_input[0].shape[1]

    def get_number_of_edges(self, gnn_input):
        _, edge_input, _ = gnn_input
        return edge_input[0].shape[0]

    def get_explanation(self, gnn_input, edge_mask, feature_mask, node_mask, node_labels=None):
        edge_relevance = np.array(edge_mask[:, 0])
        node_relevance = np.array(node_mask[:, 0])
        features = np.array(gnn_input[0][0])
        edges = np.array(gnn_input[2][0])
        g = nx.Graph()
        for i, f in enumerate(features):
            if node_labels is None:
                g.add_node(i, features=f, relevance=node_relevance[i])
            else:
                g.add_node(i, features=f, relevance=node_relevance[i], label=node_labels[i])
        for i, e in enumerate(edges):
            if edge_relevance is None:
                g.add_edge(e[0], e[1])
            else:
                g.add_edge(e[0], e[1], relevance=edge_relevance[i])
        return g

    def present_explanation(self, explanation, threshold=0.5):
        relevant_edges = []
        edge_color_map = []
        for (v, u, relevance) in explanation.edges.data('relevance'):
            if relevance > threshold:
                relevant_edges.append((v, u))
                edge_color_map.append((0, 0, 0, relevance))
        subgraph = explanation.edge_subgraph(relevant_edges)
        node_colors = []
        for n, l in subgraph.nodes.data('label'):
            r, g, b, a = get_label_color(l)
            a = subgraph.nodes[n]['relevance']
            node_colors.append((r, g, b, a))
        nx.draw(subgraph, node_color=node_colors, edge_color=edge_color_map, with_labels=True)

# %%
# Helper functions
def get_output_tensor_for_label(label):
    assert 0 <= label <= 6
    output_to_explain = np.zeros(7)
    output_to_explain[label] = 1.
    output_to_explain = np.expand_dims(output_to_explain, 0)
    return tf.Variable(output_to_explain)


def get_label_from_tensor(tensor_output):
    return np.argmax(tensor_output)

# %% [markdown]
# Choose a node to explain and instantiate an explainable GNN:

# %%
node_index = np.argwhere(val_mask[0] == 1)[:, 0][0]
# node_index = 9
explainable_gcn = ExplainableGCN(model, node_index)

# %% [markdown]
# Get the prediction of the GNN for the chosen node:

# %%
prediction = explainable_gcn.predict(xtrain)
predicted_label = get_label_from_tensor(prediction)
print('predicted label: ', predicted_label, get_label_name(predicted_label))
print("true label:", get_label_from_tensor(labels[node_index]))
print('node_index: ', node_index)
# Out:
# predicted label:  2 Neural_Networks
# true label: 2
# node_index:  9

# %% [markdown]
# Setup the GNNExplainer:

# %%
gnnexplaineroptimizer_options = {'edge_mask_loss_weight': 0.001,
                                 'edge_mask_norm_ord': 2,
                                 'feature_mask_loss_weight': 0,
                                 'feature_mask_norm_ord': 2,
                                 'node_mask_loss_weight': 0,
                                 'node_mask_norm_ord': 1}
compile_options = {'loss': 'categorical_crossentropy', 'optimizer': tf.keras.optimizers.Adam(lr=1)}
fit_options = {'epochs': 80, 'verbose': 0}

explainer = GNNExplainer(explainable_gcn,
                         compile_options=compile_options,
                         fit_options=fit_options,
                         gnnexplaineroptimizer_options=gnnexplaineroptimizer_options)
# Out:
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %% [markdown]
# Explain the instance with index node_index:

# %%
# %%capture
inspection_result = explainer.explain(xtrain, inspection=True)

# %%
plt.figure()
explainer.present_explanation(explainer.get_explanation(node_labels=np.argmax(ytrain[0], axis=1)), threshold=0.1)
plt.show()

# %%
# Plot the inspection_result to see if we chose suitable parameters:
plt.figure()
for i in range(7):
    plt.plot(np.array(inspection_result['predictions'])[:, i], color=get_label_color(i))
plt.show()

# %%
# Plot Loss
plt.figure()
plt.plot(np.array(inspection_result['total_loss']), color="black")
plt.show()

# %%
# For comparison, the 2-hop graph around the chosen instance:
plt.figure()
cora_graph = nx.Graph()
cora_graph.add_nodes_from([(i, {"label": labels[i]}) for i in inds])
cora_graph.add_edges_from(edge_index)
hops = 2
khopgraph = nx.generators.ego.ego_graph(cora_graph, node_index, radius=hops)
for n in khopgraph.nodes:
    khopgraph.nodes[n]['label'] = np.argmax(khopgraph.nodes[n]['label'])
    khopgraph.nodes[n]['relevance'] = 1.
for (u, v) in khopgraph.edges:
    khopgraph.edges[u, v]['relevance'] = 1.0
explainer.present_explanation(khopgraph)
plt.show()
