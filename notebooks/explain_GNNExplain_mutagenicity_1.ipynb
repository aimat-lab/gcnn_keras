# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import time

from kgcnn.literature.GNNExplain import GNNExplainer, GNNInterface
# from kgcnn.utils.adj import precompute_adjacency_scaled, convert_scaled_adjacency_to_list, add_self_loops_to_edge_indices
from kgcnn.literature.GCN import make_model
from kgcnn.utils.data import ragged_tensor_from_nested_numpy
from kgcnn.utils.learning import LinearLearningRateScheduler

from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import cdist
from sklearn.cluster import AgglomerativeClustering

from kgcnn.data.datasets.mutagenicity import MutagenicityDataset

# %% [markdown]
# ## Load Data

# %%
dataset = MutagenicityDataset()
labels, nodes, edge_indices, edges, atoms = dataset.graph_labels, dataset.node_attributes, dataset.edge_indices, dataset.edge_attributes, dataset.node_number

for i in range(len(labels)):
    # edge_indices[i], edges[i] = add_self_loops_to_edge_indices(edge_indices[i], np.expand_dims(edges[i],axis=-1))
    edges[i] = np.expand_dims(edges[i], axis=-1).astype(np.float32) # Make edge feature dimension
for i in range(len(labels)):
    nodes[i] = np.array(np.expand_dims(nodes[i],axis=-1) == np.array([[ 1,  3,  6,  7,  8,  9, 11, 15, 16, 17, 19, 20, 35, 53]]), dtype=np.int) # Make One-Hot encoding

# Train Test split
labels_train, labels_test, nodes_train, nodes_test, edges_train, edges_test, edge_indices_train, edge_indices_test = train_test_split(
    labels, nodes, edges, edge_indices,  train_size=0.8, random_state=1)

# Convert to tf.RaggedTensor or tf.tensor
# adj_matrix copy of the data is generated by ragged_tensor_from_nested_numpy()
nodes_train, edges_train, edge_indices_train = ragged_tensor_from_nested_numpy(
    nodes_train), ragged_tensor_from_nested_numpy(edges_train), ragged_tensor_from_nested_numpy(
    edge_indices_train)

nodes_test, edges_test, edge_indices_test = ragged_tensor_from_nested_numpy(
    nodes_test), ragged_tensor_from_nested_numpy(edges_test), ragged_tensor_from_nested_numpy(
    edge_indices_test)

xtrain = nodes_train, edges_train, edge_indices_train
xtest = nodes_test, edges_test, edge_indices_test
ytrain = np.array(labels_train)
ytest = np.array(labels_test)
print([x.shape for x in xtrain])
print([x.shape for x in xtest])
print(ytrain.shape, ytest.shape)
# Out:
# INFO:kgcnn: Dataset directory located at C:\Users\Patrick\.kgcnn\datasets
# INFO:kgcnn: Dataset directory found... done
# INFO:kgcnn: Dataset found... done
# INFO:kgcnn: Directory for extraction exists... done
# INFO:kgcnn: Not extracting zip file ... stopped
# INFO:kgcnn:  INFO:kgcnn: Reading dataset to memory with name Mutagenicity
# INFO:kgcnn:  INFO:kgcnn: Shift start of graph id to zero for Mutagenicity to match python indexing.
# INFO:kgcnn:  INFO:kgcnn: Graph index which has unconnected [  38  133  166  171  220  246  268  278  286  296  302  305  309  339
#   357  439  470  497  527  706  743  783  815  861  878  902  918 1029
#  1040 1044 1057 1085 1193 1233 1329 1394 1431 1525 1528 1532 1609 1645
#  1696 1915 1971 2024 2026 2036 2069 2133 2138 2142 2143 2174 2193 2210
#  2234 2258 2360 2422 2440 2471 2482 2483 2503 2553 2559 2604 2627 2673
#  2687 2720 2738 2808 2824 2878 2925 2959 3012 3018 3034 3037 3051 3079
#  3114 3118 3142 3208 3217 3310 3344 3349 3371 3380 3381 3395 3477 3498
#  3534 3538 3556 3571 3677 3683 3701 3782 3827 3855 3863 3869 3938 3955
#  3971 4019 4030 4036 4051 4075 4131 4267 4331] with [ 66   7   2   1   9  17   1 267   2  63  26   1   1 173   1   1   3   1
#    4   3  13  10   2   2   1   1   1   4   2   2   1  24   1 259   1   1
#    1  73   1   1 108   1   1   2   1  41   1   1   1   1   4   1 318  34
#    1   1   1   2  75   4  35   2   2  91  28  98  39  26   1   2   1  33
#    2   1   2   1   1  19   2   1   3   3   1   1   2   1   2   1  25   1
#    1  77  24   1  35   2   1   1   7  25   2  60   1  14   1   1   1   1
#    1   2   2  10   7   2   2   2  34   3   2   1   2] in total 121
# INFO:kgcnn:  INFO:kgcnn: Checking database...
# INFO:kgcnn:  INFO: Removing unconnected {'H': 66} from molecule 38
# INFO:kgcnn:  INFO: Removing unconnected {'H': 7} from molecule 133
# INFO:kgcnn:  INFO: Removing unconnected {'H': 9} from molecule 220
# INFO:kgcnn:  INFO: Removing unconnected {'H': 17} from molecule 246
# INFO:kgcnn:  INFO: Removing unconnected {'H': 170, 'C': 52, 'N': 17, 'O': 24, 'S': 4} from molecule 278
# INFO:kgcnn:  INFO: Removing unconnected {'H': 63} from molecule 296
# INFO:kgcnn:  INFO: Removing unconnected {'H': 26} from molecule 302
# INFO:kgcnn:  INFO: Removing unconnected {'H': 126, 'C': 42, 'N': 1, 'O': 4} from molecule 339
# INFO:kgcnn:  INFO: Removing unconnected {'H': 13} from molecule 743
# INFO:kgcnn:  INFO: Removing unconnected {'H': 10} from molecule 783
# INFO:kgcnn:  INFO: Removing unconnected {'H': 24} from molecule 1085
# INFO:kgcnn:  INFO: Removing unconnected {'H': 168, 'C': 50, 'N': 19, 'O': 20, 'S': 2} from molecule 1233
# INFO:kgcnn:  INFO: Removing unconnected {'H': 73} from molecule 1525
# INFO:kgcnn:  INFO: Removing unconnected {'H': 99, 'C': 7, 'N': 1, 'Cl': 1} from molecule 1609
# INFO:kgcnn:  INFO: Removing unconnected {'H': 41} from molecule 2024
# INFO:kgcnn:  INFO: Removing unconnected {'H': 203, 'C': 65, 'N': 28, 'O': 21, 'S': 1} from molecule 2143
# INFO:kgcnn:  INFO: Removing unconnected {'H': 34} from molecule 2174
# INFO:kgcnn:  INFO: Removing unconnected {'H': 75} from molecule 2360
# INFO:kgcnn:  INFO: Removing unconnected {'H': 4} from molecule 2422
# INFO:kgcnn:  INFO: Removing unconnected {'H': 35} from molecule 2440
# INFO:kgcnn:  INFO: Removing unconnected {'H': 88, 'C': 3} from molecule 2483
# INFO:kgcnn:  INFO: Removing unconnected {'H': 28} from molecule 2503
# INFO:kgcnn:  INFO: Removing unconnected {'H': 95, 'C': 3} from molecule 2553
# INFO:kgcnn:  INFO: Removing unconnected {'H': 39} from molecule 2559
# INFO:kgcnn:  INFO: Removing unconnected {'H': 25, 'N': 1} from molecule 2604
# INFO:kgcnn:  INFO: Removing unconnected {'H': 33} from molecule 2720
# INFO:kgcnn:  INFO: Removing unconnected {'H': 19} from molecule 2959
# INFO:kgcnn:  INFO: Removing unconnected {'H': 25} from molecule 3217
# INFO:kgcnn:  INFO: Removing unconnected {'H': 77} from molecule 3349
# INFO:kgcnn:  INFO: Removing unconnected {'H': 24} from molecule 3371
# INFO:kgcnn:  INFO: Removing unconnected {'H': 35} from molecule 3381
# INFO:kgcnn:  INFO: Removing unconnected {'H': 7} from molecule 3534
# INFO:kgcnn:  INFO: Removing unconnected {'H': 25} from molecule 3538
# INFO:kgcnn:  INFO: Removing unconnected {'H': 60} from molecule 3571
# INFO:kgcnn:  INFO: Removing unconnected {'H': 14} from molecule 3683
# INFO:kgcnn:  INFO: Removing unconnected {'H': 10} from molecule 3955
# INFO:kgcnn:  INFO: Removing unconnected {'H': 5} from molecule 3971
# INFO:kgcnn:  INFO: Removing unconnected {'H': 34} from molecule 4051
# INFO:kgcnn:  INFO:kgcnn: Database still has unconnected Na+, Li+, ksb+ etc.
# C:\Users\Patrick\AppData\Local\Temp/ipykernel_8408/3890858408.py:8: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   nodes[i] = np.array(np.expand_dims(nodes[i],axis=-1) == np.array([[ 1,  3,  6,  7,  8,  9, 11, 15, 16, 17, 19, 20, 35, 53]]), dtype=np.int) # Make One-Hot encoding
# [TensorShape([3469, None, 14]), TensorShape([3469, None, 1]), TensorShape([3469, None, 2])]
# [TensorShape([868, None, 14]), TensorShape([868, None, 1]), TensorShape([868, None, 2])]
# (3469, 1) (868, 1)

# %% [markdown]
# ## Make and train a GCN

# %%
model = make_model(
    name = "GCN",
    inputs = [{'shape': (None, 14), 'name': "node_attributes", 'dtype': 'float32', 'ragged': True},
            {'shape': (None, 1), 'name': "edge_attributes", 'dtype': 'float32', 'ragged': True},
            {'shape': (None, 2), 'name': "edge_indices", 'dtype': 'int64', 'ragged': True}],
    input_embedding = {"node": {"input_dim": 55, "output_dim": 64},
                       "edge": {"input_dim": 10, "output_dim": 64}},
    output_embedding =  'graph',
    output_mlp = {"use_bias": [True, True, False], "units": [140, 70, 1],
                "activation": ['relu', 'relu', 'sigmoid']},
    gcn_args = {"units": 64, "use_bias": True, "activation": 'relu', "pooling_method": 'mean', 
                "normalize_by_weights": False},
)

# Set learning rate and epochs
learning_rate_start = 1e-3
learning_rate_stop = 1e-4
epo = 150
epomin = 100
epostep = 10

# Compile model with optimizer and loss
optimizer = tf.keras.optimizers.Adam(lr=learning_rate_start)
cbks = LinearLearningRateScheduler(learning_rate_start, learning_rate_stop, epomin, epo)
model.compile(loss='binary_crossentropy',
              optimizer=optimizer,
              weighted_metrics=['accuracy'])
print(model.summary())

# Start and time training
start = time.process_time()
hist = model.fit(xtrain, ytrain,
                 epochs=epo,
                 batch_size=32,
                 callbacks=[cbks],
                 validation_freq=epostep,
                 validation_data=(xtest, ytest),
                 verbose=2
                 )
stop = time.process_time()
print("Print Time for taining: ", stop - start)

# Get loss from history
trainlossall = np.array(hist.history['accuracy'])
testlossall = np.array(hist.history['val_accuracy'])
acc_valid = testlossall[-1]

# Plot loss vs epochs
plt.figure()
plt.plot(np.arange(trainlossall.shape[0]), trainlossall, label='Training ACC', c='blue')
plt.plot(np.arange(epostep, epo + epostep, epostep), testlossall, label='Test ACC', c='red')
plt.scatter([trainlossall.shape[0]], [acc_valid], label="{0:0.4f} ".format(acc_valid), c='red')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Interaction Network Loss')
plt.legend(loc='upper right', fontsize='x-large')
plt.savefig('gcn_explain_mutag.png')
plt.show()
# Out:
# WARNING:kgcnn: Unknown model kwarg normalize_by_weights with value False
# INFO:kgcnn: Updated model kwargs:
# {'depth': 3,
#  'gcn_args': {'activation': 'relu',
#               'has_unconnected': True,
#               'is_sorted': False,
#               'normalize_by_weights': False,
#               'pooling_method': 'mean',
#               'units': 64,
#               'use_bias': True},
#  'input_embedding': {'edge': {'input_dim': 10, 'output_dim': 64},
#                      'node': {'input_dim': 55, 'output_dim': 64}},
#  'inputs': [{'dtype': 'float32',
#              'name': 'node_attributes',
#              'ragged': True,
#              'shape': (None, 14)},
#             {'dtype': 'float32',
#              'name': 'edge_attributes',
#              'ragged': True,
#              'shape': (None, 1)},
#             {'dtype': 'int64',
#              'name': 'edge_indices',
#              'ragged': True,
#              'shape': (None, 2)}],
#  'name': 'GCN',
#  'output_embedding': 'graph',
#  'output_mlp': {'activation': ['relu', 'relu', 'sigmoid'],
#                 'units': [140, 70, 1],
#                 'use_bias': [True, True, False]},
#  'verbose': 1}
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  node_attributes (InputLayer)   [(None, None, 14)]   0           []
#
#  dense (Dense)                  (None, None, 64)     960         ['node_attributes[0][0]']
#
#  edge_attributes (InputLayer)   [(None, None, 1)]    0           []
#
#  edge_indices (InputLayer)      [(None, None, 2)]    0           []
#
#  gcn (GCN)                      (None, None, 64)     4160        ['dense[0][0]',
#                                                                   'edge_attributes[0][0]',
#                                                                   'edge_indices[0][0]']
#
#  gcn_1 (GCN)                    (None, None, 64)     4160        ['gcn[0][0]',
#                                                                   'edge_attributes[0][0]',
#                                                                   'edge_indices[0][0]']
#
#  gcn_2 (GCN)                    (None, None, 64)     4160        ['gcn_1[0][0]',
#                                                                   'edge_attributes[0][0]',
#                                                                   'edge_indices[0][0]']
#
#  pooling_embedding (PoolingEmbe  (None, 64)          0           ['gcn_2[0][0]']
#  dding)
#
#  mlp (MLP)                      (None, 1)            19040       ['pooling_embedding[0][0]']
#
# ==================================================================================================
# Total params: 32,480
# Trainable params: 32,480
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/150
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn_2/pooling_weighted_local_edges_2/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/gcn_2/pooling_weighted_local_edges_2/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn_2/pooling_weighted_local_edges_2/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn_2/gather_nodes_outgoing_2/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/gcn_2/gather_nodes_outgoing_2/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn_2/gather_nodes_outgoing_2/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn_1/pooling_weighted_local_edges_1/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/gcn_1/pooling_weighted_local_edges_1/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn_1/pooling_weighted_local_edges_1/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn_1/gather_nodes_outgoing_1/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/gcn_1/gather_nodes_outgoing_1/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn_1/gather_nodes_outgoing_1/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn/pooling_weighted_local_edges/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/gcn/pooling_weighted_local_edges/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn/pooling_weighted_local_edges/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn/gather_nodes_outgoing/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/gcn/gather_nodes_outgoing/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn/gather_nodes_outgoing/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# 109/109 - 3s - loss: 0.6586 - accuracy: 0.6088 - lr: 0.0010 - 3s/epoch - 26ms/step
# Epoch 2/150
# 109/109 - 1s - loss: 0.6177 - accuracy: 0.6815 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 3/150
# 109/109 - 1s - loss: 0.6001 - accuracy: 0.6823 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 4/150
# 109/109 - 1s - loss: 0.5649 - accuracy: 0.7094 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 5/150
# 109/109 - 1s - loss: 0.5529 - accuracy: 0.7135 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 6/150
# 109/109 - 1s - loss: 0.5443 - accuracy: 0.7319 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 7/150
# 109/109 - 1s - loss: 0.5331 - accuracy: 0.7313 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 8/150
# 109/109 - 1s - loss: 0.5238 - accuracy: 0.7434 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 9/150
# 109/109 - 1s - loss: 0.5115 - accuracy: 0.7515 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 10/150
# 109/109 - 2s - loss: 0.5118 - accuracy: 0.7492 - val_loss: 0.5439 - val_accuracy: 0.7373 - lr: 0.0010 - 2s/epoch - 17ms/step
# Epoch 11/150
# 109/109 - 1s - loss: 0.5108 - accuracy: 0.7469 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 12/150
# 109/109 - 1s - loss: 0.5101 - accuracy: 0.7495 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 13/150
# 109/109 - 1s - loss: 0.4919 - accuracy: 0.7607 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 14/150
# 109/109 - 1s - loss: 0.4891 - accuracy: 0.7593 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 15/150
# 109/109 - 1s - loss: 0.4893 - accuracy: 0.7656 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 16/150
# 109/109 - 1s - loss: 0.4875 - accuracy: 0.7659 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 17/150
# 109/109 - 1s - loss: 0.4838 - accuracy: 0.7740 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 18/150
# 109/109 - 1s - loss: 0.4903 - accuracy: 0.7639 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 19/150
# 109/109 - 1s - loss: 0.4757 - accuracy: 0.7737 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 20/150
# 109/109 - 1s - loss: 0.4693 - accuracy: 0.7728 - val_loss: 0.5135 - val_accuracy: 0.7558 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 21/150
# 109/109 - 1s - loss: 0.4648 - accuracy: 0.7700 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 22/150
# 109/109 - 1s - loss: 0.4672 - accuracy: 0.7766 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 23/150
# 109/109 - 1s - loss: 0.4717 - accuracy: 0.7700 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 24/150
# 109/109 - 1s - loss: 0.4607 - accuracy: 0.7786 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 25/150
# 109/109 - 1s - loss: 0.4621 - accuracy: 0.7752 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 26/150
# 109/109 - 1s - loss: 0.4624 - accuracy: 0.7818 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 27/150
# 109/109 - 1s - loss: 0.4482 - accuracy: 0.7841 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 28/150
# 109/109 - 1s - loss: 0.4468 - accuracy: 0.7884 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 29/150
# 109/109 - 1s - loss: 0.4486 - accuracy: 0.7826 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 30/150
# 109/109 - 1s - loss: 0.4401 - accuracy: 0.7890 - val_loss: 0.4799 - val_accuracy: 0.7742 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 31/150
# 109/109 - 1s - loss: 0.4404 - accuracy: 0.7873 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 32/150
# 109/109 - 1s - loss: 0.4377 - accuracy: 0.7965 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 33/150
# 109/109 - 1s - loss: 0.4427 - accuracy: 0.7924 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 34/150
# 109/109 - 1s - loss: 0.4392 - accuracy: 0.7873 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 35/150
# 109/109 - 1s - loss: 0.4331 - accuracy: 0.7962 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 36/150
# 109/109 - 1s - loss: 0.4312 - accuracy: 0.7924 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 37/150
# 109/109 - 1s - loss: 0.4254 - accuracy: 0.8008 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 38/150
# 109/109 - 1s - loss: 0.4283 - accuracy: 0.7973 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 39/150
# 109/109 - 1s - loss: 0.4208 - accuracy: 0.8020 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 40/150
# 109/109 - 1s - loss: 0.4168 - accuracy: 0.8040 - val_loss: 0.4748 - val_accuracy: 0.7834 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 41/150
# 109/109 - 1s - loss: 0.4130 - accuracy: 0.8086 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 42/150
# 109/109 - 1s - loss: 0.4116 - accuracy: 0.8095 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 43/150
# 109/109 - 1s - loss: 0.4090 - accuracy: 0.8071 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 44/150
# 109/109 - 1s - loss: 0.4123 - accuracy: 0.8051 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 45/150
# 109/109 - 1s - loss: 0.4103 - accuracy: 0.8115 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 46/150
# 109/109 - 1s - loss: 0.3961 - accuracy: 0.8158 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 47/150
# 109/109 - 1s - loss: 0.4042 - accuracy: 0.8071 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 48/150
# 109/109 - 1s - loss: 0.3887 - accuracy: 0.8152 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 49/150
# 109/109 - 1s - loss: 0.3873 - accuracy: 0.8219 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 50/150
# 109/109 - 1s - loss: 0.3825 - accuracy: 0.8146 - val_loss: 0.4800 - val_accuracy: 0.7903 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 51/150
# 109/109 - 1s - loss: 0.3881 - accuracy: 0.8175 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 52/150
# 109/109 - 1s - loss: 0.3776 - accuracy: 0.8242 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 53/150
# 109/109 - 1s - loss: 0.3810 - accuracy: 0.8230 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 54/150
# 109/109 - 1s - loss: 0.3763 - accuracy: 0.8195 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 55/150
# 109/109 - 1s - loss: 0.3741 - accuracy: 0.8285 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 56/150
# 109/109 - 1s - loss: 0.3711 - accuracy: 0.8256 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 57/150
# 109/109 - 1s - loss: 0.3698 - accuracy: 0.8311 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 58/150
# 109/109 - 1s - loss: 0.3617 - accuracy: 0.8273 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 59/150
# 109/109 - 1s - loss: 0.3564 - accuracy: 0.8386 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 60/150
# 109/109 - 1s - loss: 0.3598 - accuracy: 0.8389 - val_loss: 0.4980 - val_accuracy: 0.7869 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 61/150
# 109/109 - 1s - loss: 0.3618 - accuracy: 0.8331 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 62/150
# 109/109 - 1s - loss: 0.3550 - accuracy: 0.8340 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 63/150
# 109/109 - 1s - loss: 0.3472 - accuracy: 0.8412 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 64/150
# 109/109 - 1s - loss: 0.3524 - accuracy: 0.8415 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 65/150
# 109/109 - 1s - loss: 0.3524 - accuracy: 0.8383 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 66/150
# 109/109 - 1s - loss: 0.3380 - accuracy: 0.8446 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 67/150
# 109/109 - 1s - loss: 0.3368 - accuracy: 0.8409 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 68/150
# 109/109 - 1s - loss: 0.3500 - accuracy: 0.8394 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 69/150
# 109/109 - 1s - loss: 0.3275 - accuracy: 0.8513 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 70/150
# 109/109 - 1s - loss: 0.3385 - accuracy: 0.8438 - val_loss: 0.4933 - val_accuracy: 0.7869 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 71/150
# 109/109 - 1s - loss: 0.3242 - accuracy: 0.8513 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 72/150
# 109/109 - 1s - loss: 0.3300 - accuracy: 0.8533 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 73/150
# 109/109 - 1s - loss: 0.3355 - accuracy: 0.8501 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 74/150
# 109/109 - 1s - loss: 0.3191 - accuracy: 0.8613 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 75/150
# 109/109 - 1s - loss: 0.3199 - accuracy: 0.8547 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 76/150
# 109/109 - 1s - loss: 0.3198 - accuracy: 0.8582 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 77/150
# 109/109 - 1s - loss: 0.3140 - accuracy: 0.8593 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 78/150
# 109/109 - 1s - loss: 0.3083 - accuracy: 0.8585 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 79/150
# 109/109 - 1s - loss: 0.3126 - accuracy: 0.8625 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 80/150
# 109/109 - 1s - loss: 0.3041 - accuracy: 0.8654 - val_loss: 0.5285 - val_accuracy: 0.7926 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 81/150
# 109/109 - 1s - loss: 0.3032 - accuracy: 0.8648 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 82/150
# 109/109 - 1s - loss: 0.2979 - accuracy: 0.8709 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 83/150
# 109/109 - 1s - loss: 0.2946 - accuracy: 0.8697 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 84/150
# 109/109 - 1s - loss: 0.2905 - accuracy: 0.8677 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 85/150
# 109/109 - 1s - loss: 0.2834 - accuracy: 0.8740 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 86/150
# 109/109 - 1s - loss: 0.2821 - accuracy: 0.8714 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 87/150
# 109/109 - 1s - loss: 0.2738 - accuracy: 0.8755 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 88/150
# 109/109 - 1s - loss: 0.2844 - accuracy: 0.8700 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 89/150
# 109/109 - 1s - loss: 0.2768 - accuracy: 0.8795 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 90/150
# 109/109 - 1s - loss: 0.2753 - accuracy: 0.8792 - val_loss: 0.5484 - val_accuracy: 0.7961 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 91/150
# 109/109 - 1s - loss: 0.2670 - accuracy: 0.8812 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 92/150
# 109/109 - 1s - loss: 0.2755 - accuracy: 0.8838 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 93/150
# 109/109 - 1s - loss: 0.2800 - accuracy: 0.8781 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 94/150
# 109/109 - 1s - loss: 0.2636 - accuracy: 0.8850 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 95/150
# 109/109 - 1s - loss: 0.2553 - accuracy: 0.8856 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 96/150
# 109/109 - 1s - loss: 0.2642 - accuracy: 0.8841 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 97/150
# 109/109 - 1s - loss: 0.2509 - accuracy: 0.8919 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 98/150
# 109/109 - 1s - loss: 0.2517 - accuracy: 0.8922 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 99/150
# 109/109 - 1s - loss: 0.2442 - accuracy: 0.8968 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 100/150
# 109/109 - 1s - loss: 0.2479 - accuracy: 0.8905 - val_loss: 0.6070 - val_accuracy: 0.7949 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 101/150
# 109/109 - 1s - loss: 0.2470 - accuracy: 0.8910 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 102/150
# 109/109 - 1s - loss: 0.2501 - accuracy: 0.8905 - lr: 9.8200e-04 - 1s/epoch - 11ms/step
# Epoch 103/150
# 109/109 - 1s - loss: 0.2356 - accuracy: 0.8982 - lr: 9.6400e-04 - 1s/epoch - 11ms/step
# Epoch 104/150
# 109/109 - 1s - loss: 0.2310 - accuracy: 0.8997 - lr: 9.4600e-04 - 1s/epoch - 10ms/step
# Epoch 105/150
# 109/109 - 1s - loss: 0.2196 - accuracy: 0.9078 - lr: 9.2800e-04 - 1s/epoch - 10ms/step
# Epoch 106/150
# 109/109 - 1s - loss: 0.2206 - accuracy: 0.9106 - lr: 9.1000e-04 - 1s/epoch - 10ms/step
# Epoch 107/150
# 109/109 - 1s - loss: 0.2205 - accuracy: 0.9054 - lr: 8.9200e-04 - 1s/epoch - 10ms/step
# Epoch 108/150
# 109/109 - 1s - loss: 0.2184 - accuracy: 0.9066 - lr: 8.7400e-04 - 1s/epoch - 10ms/step
# Epoch 109/150
# 109/109 - 1s - loss: 0.2108 - accuracy: 0.9066 - lr: 8.5600e-04 - 1s/epoch - 10ms/step
# Epoch 110/150
# 109/109 - 1s - loss: 0.2221 - accuracy: 0.9066 - val_loss: 0.6150 - val_accuracy: 0.7880 - lr: 8.3800e-04 - 1s/epoch - 12ms/step
# Epoch 111/150
# 109/109 - 1s - loss: 0.2066 - accuracy: 0.9109 - lr: 8.2000e-04 - 1s/epoch - 10ms/step
# Epoch 112/150
# 109/109 - 1s - loss: 0.2071 - accuracy: 0.9101 - lr: 8.0200e-04 - 1s/epoch - 10ms/step
# Epoch 113/150
# 109/109 - 1s - loss: 0.2095 - accuracy: 0.9147 - lr: 7.8400e-04 - 1s/epoch - 10ms/step
# Epoch 114/150
# 109/109 - 1s - loss: 0.2111 - accuracy: 0.9147 - lr: 7.6600e-04 - 1s/epoch - 10ms/step
# Epoch 115/150
# 109/109 - 1s - loss: 0.1902 - accuracy: 0.9222 - lr: 7.4800e-04 - 1s/epoch - 10ms/step
# Epoch 116/150
# 109/109 - 1s - loss: 0.1901 - accuracy: 0.9173 - lr: 7.3000e-04 - 1s/epoch - 10ms/step
# Epoch 117/150
# 109/109 - 1s - loss: 0.1824 - accuracy: 0.9236 - lr: 7.1200e-04 - 1s/epoch - 11ms/step
# Epoch 118/150
# 109/109 - 1s - loss: 0.1839 - accuracy: 0.9274 - lr: 6.9400e-04 - 1s/epoch - 11ms/step
# Epoch 119/150
# 109/109 - 1s - loss: 0.1829 - accuracy: 0.9236 - lr: 6.7600e-04 - 1s/epoch - 11ms/step
# Epoch 120/150
# 109/109 - 1s - loss: 0.1764 - accuracy: 0.9262 - val_loss: 0.7175 - val_accuracy: 0.7800 - lr: 6.5800e-04 - 1s/epoch - 12ms/step
# Epoch 121/150
# 109/109 - 1s - loss: 0.1797 - accuracy: 0.9251 - lr: 6.4000e-04 - 1s/epoch - 10ms/step
# Epoch 122/150
# 109/109 - 1s - loss: 0.1767 - accuracy: 0.9271 - lr: 6.2200e-04 - 1s/epoch - 11ms/step
# Epoch 123/150
# 109/109 - 1s - loss: 0.1672 - accuracy: 0.9297 - lr: 6.0400e-04 - 1s/epoch - 11ms/step
# Epoch 124/150
# 109/109 - 1s - loss: 0.1655 - accuracy: 0.9314 - lr: 5.8600e-04 - 1s/epoch - 11ms/step
# Epoch 125/150
# 109/109 - 1s - loss: 0.1619 - accuracy: 0.9337 - lr: 5.6800e-04 - 1s/epoch - 12ms/step
# Epoch 126/150
# 109/109 - 1s - loss: 0.1639 - accuracy: 0.9328 - lr: 5.5000e-04 - 1s/epoch - 11ms/step
# Epoch 127/150
# 109/109 - 1s - loss: 0.1522 - accuracy: 0.9366 - lr: 5.3200e-04 - 1s/epoch - 11ms/step
# Epoch 128/150
# 109/109 - 1s - loss: 0.1509 - accuracy: 0.9383 - lr: 5.1400e-04 - 1s/epoch - 11ms/step
# Epoch 129/150
# 109/109 - 1s - loss: 0.1472 - accuracy: 0.9398 - lr: 4.9600e-04 - 1s/epoch - 11ms/step
# Epoch 130/150
# 109/109 - 1s - loss: 0.1443 - accuracy: 0.9423 - val_loss: 0.8214 - val_accuracy: 0.7753 - lr: 4.7800e-04 - 1s/epoch - 12ms/step
# Epoch 131/150
# 109/109 - 1s - loss: 0.1471 - accuracy: 0.9389 - lr: 4.6000e-04 - 1s/epoch - 11ms/step
# Epoch 132/150
# 109/109 - 1s - loss: 0.1429 - accuracy: 0.9447 - lr: 4.4200e-04 - 1s/epoch - 11ms/step
# Epoch 133/150
# 109/109 - 1s - loss: 0.1399 - accuracy: 0.9426 - lr: 4.2400e-04 - 1s/epoch - 10ms/step
# Epoch 134/150
# 109/109 - 1s - loss: 0.1353 - accuracy: 0.9455 - lr: 4.0600e-04 - 1s/epoch - 10ms/step
# Epoch 135/150
# 109/109 - 1s - loss: 0.1327 - accuracy: 0.9507 - lr: 3.8800e-04 - 1s/epoch - 10ms/step
# Epoch 136/150
# 109/109 - 1s - loss: 0.1284 - accuracy: 0.9490 - lr: 3.7000e-04 - 1s/epoch - 10ms/step
# Epoch 137/150
# 109/109 - 1s - loss: 0.1255 - accuracy: 0.9487 - lr: 3.5200e-04 - 1s/epoch - 10ms/step
# Epoch 138/150
# 109/109 - 1s - loss: 0.1223 - accuracy: 0.9496 - lr: 3.3400e-04 - 1s/epoch - 10ms/step
# Epoch 139/150
# 109/109 - 1s - loss: 0.1254 - accuracy: 0.9504 - lr: 3.1600e-04 - 1s/epoch - 10ms/step
# Epoch 140/150
# 109/109 - 1s - loss: 0.1183 - accuracy: 0.9530 - val_loss: 0.9192 - val_accuracy: 0.7926 - lr: 2.9800e-04 - 1s/epoch - 12ms/step
# Epoch 141/150
# 109/109 - 1s - loss: 0.1211 - accuracy: 0.9530 - lr: 2.8000e-04 - 1s/epoch - 10ms/step
# Epoch 142/150
# 109/109 - 1s - loss: 0.1160 - accuracy: 0.9582 - lr: 2.6200e-04 - 1s/epoch - 10ms/step
# Epoch 143/150
# 109/109 - 1s - loss: 0.1133 - accuracy: 0.9553 - lr: 2.4400e-04 - 1s/epoch - 10ms/step
# Epoch 144/150
# 109/109 - 1s - loss: 0.1151 - accuracy: 0.9542 - lr: 2.2600e-04 - 1s/epoch - 10ms/step
# Epoch 145/150
# 109/109 - 1s - loss: 0.1121 - accuracy: 0.9550 - lr: 2.0800e-04 - 1s/epoch - 10ms/step
# Epoch 146/150
# 109/109 - 1s - loss: 0.1076 - accuracy: 0.9602 - lr: 1.9000e-04 - 1s/epoch - 10ms/step
# Epoch 147/150
# 109/109 - 1s - loss: 0.1048 - accuracy: 0.9617 - lr: 1.7200e-04 - 1s/epoch - 11ms/step
# Epoch 148/150
# 109/109 - 1s - loss: 0.1036 - accuracy: 0.9625 - lr: 1.5400e-04 - 1s/epoch - 11ms/step
# Epoch 149/150
# 109/109 - 1s - loss: 0.1023 - accuracy: 0.9614 - lr: 1.3600e-04 - 1s/epoch - 11ms/step
# Epoch 150/150
# 109/109 - 1s - loss: 0.0992 - accuracy: 0.9628 - val_loss: 0.9670 - val_accuracy: 0.7834 - lr: 1.1800e-04 - 1s/epoch - 12ms/step
# Print Time for taining:  272.828125

# %% [markdown]
# ## Implementation of the  ExplainableGCN from GNNInterface

# %%
# Now we have to implement the ExplainableGCN
class ExplainableGCN(GNNInterface):

    def __init__(self, gnn_model, **kwargs):
        super(ExplainableGCN, self).__init__()
        self.gnn_model = gnn_model

    def predict(self, gnn_input, masking_info=None):
        return self.gnn_model(gnn_input, training=False)[0]

    def masked_predict(self, gnn_input, edge_mask, feature_mask, node_mask, training=False):
        node_input, edge_input, edge_index_input = gnn_input

        masked_edge_input = tf.ragged.map_flat_values(tf.math.multiply, edge_input, edge_mask)
        masked_feature_input = tf.ragged.map_flat_values(tf.math.multiply, tf.dtypes.cast(node_input, tf.float32),
                                                         tf.transpose(feature_mask))
        masked_node_feature_input = tf.ragged.map_flat_values(tf.math.multiply, masked_feature_input, node_mask)
        masked_pred = \
        self.gnn_model([masked_node_feature_input, masked_edge_input, edge_index_input], training=training)[0]

        return masked_pred

    def get_number_of_nodes(self, gnn_input):
        node_input, _, _ = gnn_input
        return node_input[0].shape[0]

    def get_number_of_node_features(self, gnn_input):
        node_input, _, _ = gnn_input
        return node_input.shape[2]

    def get_number_of_edges(self, gnn_input):
        _, edge_input, _ = gnn_input
        return edge_input[0].shape[0]

    def get_explanation(self, gnn_input, edge_mask, feature_mask, node_mask):
        edge_relevance = np.array(edge_mask[:, 0])
        node_relevance = np.array(node_mask[:, 0])
        feature_relevance = np.array(feature_mask[:, 0])
        features = np.array(gnn_input[0][0])
        edges = np.array(gnn_input[2][0])
        graph = nx.Graph()
        for i, f in enumerate(features):
            graph.add_node(i, features=f, relevance=node_relevance[i])
        for i, e in enumerate(edges):
            if edge_relevance is None:
                graph.add_edge(e[0], e[1])
            else:
                graph.add_edge(e[0], e[1], relevance=edge_relevance[i])
        return graph, feature_relevance

    def present_explanation(self, explanation, threshold=0.5):
        graph = explanation[0]
        # element_labels = np.array([[ 1,  3,  6,  7,  8,  9, 11, 15, 16, 17, 19, 20, 35, 53]])
        element_labels = ['H', 'Li', 'C', 'N', 'O', 'F', 'Na', 'P', 'S', 'Cl', 'K', 'Ca', 'Br', 'I']
        important_edges = []
        color_map = []
        node_color_map = []
        node_labels = {}
        for (u, v, relevance) in graph.edges.data('relevance'):
            relevance = min(relevance + 0.1, 1.0)
            color_map.append((0, 0, 0, relevance))
        for n, f in graph.nodes.data('features'):
            element = np.argmax(f)
            r, g, b, a = plt.get_cmap('tab20')(element)
            node_color_map.append((r, g, b, graph.nodes[n]['relevance']))
            node_labels[n] = (element_labels[element])
        if np.all(explanation[1] == 1):
            nx.draw_kamada_kawai(graph, edge_color=color_map, labels=node_labels, node_color=node_color_map)
        else:
            f, axs = plt.subplots(2, figsize=(8, 12))
            nx.draw_kamada_kawai(graph, ax=axs[0], edge_color=color_map, labels=node_labels, node_color=node_color_map)
            bar_colors = [plt.get_cmap('tab20')(element) for element in np.arange(14)]
            axs[1].bar(np.array(element_labels), explanation[1], color=bar_colors)

# %% [markdown]
# Instanciate a Explainable GNN:

# %%
explainable_gcn = ExplainableGCN(model)
compile_options = {'loss': 'binary_crossentropy', 'optimizer': tf.keras.optimizers.Adam(lr=0.2)}
fit_options={'epochs': 100, 'batch_size': 1, 'verbose': 0}
gnnexplaineroptimizer_options = {'edge_mask_loss_weight': 0.001,
                 'edge_mask_norm_ord': 1,
                 'feature_mask_loss_weight': 0,
                 'feature_mask_norm_ord': 1,
                 'node_mask_loss_weight': 0,
                 'node_mask_norm_ord': 1}

explainer = GNNExplainer(explainable_gcn,
                              compile_options=compile_options,
                              fit_options=fit_options,
                              gnnexplaineroptimizer_options=gnnexplaineroptimizer_options)
# Out:
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %% [markdown]
# Explain Single Instance and check setup:

# %%
inspection_result = explainer.explain([tensor[776:777] for tensor in xtest], inspection=True)
# inspection_result = explainer.explain([tensor[264:265] for tensor in xtest], output_to_explain=tf.Variable([0.]), inspection=True)

# Present explanation
plt.figure()
explainer.present_explanation(explainer.get_explanation(), threshold=0.5)
plt.show()

# %%
# Predictions
plt.figure()
plt.plot(inspection_result['predictions'])
plt.xlabel('Iterations')
plt.ylabel('GNN output')
plt.show()

# %%
# loss
plt.figure()
plt.plot(inspection_result['total_loss'])
plt.xlabel('Iterations')
plt.ylabel('Total Loss')
plt.show()

# %%
# edge loss
plt.figure()
plt.plot(inspection_result['edge_mask_loss'])
plt.xlabel('Iterations')
plt.ylabel('Node Mask Loss')
plt.show()
