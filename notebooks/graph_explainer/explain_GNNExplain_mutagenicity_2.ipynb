# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import time

from kgcnn.literature.GNNExplain import GNNExplainer, GNNInterface
# from kgcnn.utils.adj import precompute_adjacency_scaled, convert_scaled_adjacency_to_list, add_self_loops_to_edge_indices
from kgcnn.literature.GCN import make_model, make_model_weighted
# from kgcnn.layers.ragged.pooling import PoolingWeightedNodes
from kgcnn.utils.data import ragged_tensor_from_nested_numpy
from kgcnn.utils.learning import LinearLearningRateScheduler

from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import cdist
from sklearn.cluster import AgglomerativeClustering

from kgcnn.data.datasets.MutagenicityDataset import MutagenicityDataset

# %% [markdown]
# ## Load Data

# %%
dataset = MutagenicityDataset()
labels, nodes, edge_indices, edges, atoms = dataset.graph_labels, dataset.node_attributes, dataset.edge_indices, dataset.edge_attributes, dataset.node_number
for i in range(len(labels)):
    # edge_indices[i], edges[i] = add_self_loops_to_edge_indices(edge_indices[i], np.expand_dims(edges[i],axis=-1))
    edges[i] = np.expand_dims(edges[i], axis=-1).astype(np.float32)# Make edge feature dimension
for i in range(len(labels)):
    nodes[i] = np.array(
        np.expand_dims(nodes[i],axis=-1) == np.array([[ 1,  3,  6,  7,  8,  9, 11, 15, 16, 17, 19, 20, 35, 53]])
                        , dtype=np.int) # Make One-Hot encoding

# Train Test split
labels_train, labels_test, nodes_train, nodes_test, edges_train, edges_test, edge_indices_train, edge_indices_test = train_test_split(
    labels, nodes, edges, edge_indices,  train_size=0.8, random_state=1)

# Convert to tf.RaggedTensor or tf.tensor
# a copy of the data is generated by ragged_tensor_from_nested_numpy()
nodes_train, edges_train, edge_indices_train = ragged_tensor_from_nested_numpy(
    nodes_train), ragged_tensor_from_nested_numpy(edges_train), ragged_tensor_from_nested_numpy(
    edge_indices_train)

nodes_test, edges_test, edge_indices_test = ragged_tensor_from_nested_numpy(
    nodes_test), ragged_tensor_from_nested_numpy(edges_test), ragged_tensor_from_nested_numpy(
    edge_indices_test)

xtrain = nodes_train, edges_train, edge_indices_train
xtest = nodes_test, edges_test, edge_indices_test
ytrain = np.expand_dims(labels_train, axis=-1)
ytest = np.expand_dims(labels_test, axis=-1)
print([x.shape for x in xtrain])
print([x.shape for x in xtest])
print(ytrain.shape, ytest.shape)
# Out:
# INFO:kgcnn.data.download:Checking and possibly downloading dataset with name Mutagenicity
# INFO:kgcnn.data.download:Dataset directory located at C:\Users\Patrick\.kgcnn\datasets
# INFO:kgcnn.data.download:Dataset directory found. Done.
# INFO:kgcnn.data.download:Dataset found. Done.
# INFO:kgcnn.data.download:Directory for extraction exists. Done.
# INFO:kgcnn.data.download:Not extracting zip file. Stopped.
# INFO:kgcnn.data.Mutagenicity:Reading dataset to memory with name Mutagenicity
# INFO:kgcnn.data.Mutagenicity:Shift start of graph id to zero for Mutagenicity to match python indexing.
# INFO:kgcnn.data.Mutagenicity:Graph index which has unconnected [  38  133  166  171  220  246  268  278  286  296  302  305  309  339
#   357  439  470  497  527  706  743  783  815  861  878  902  918 1029
#  1040 1044 1057 1085 1193 1233 1329 1394 1431 1525 1528 1532 1609 1645
#  1696 1915 1971 2024 2026 2036 2069 2133 2138 2142 2143 2174 2193 2210
#  2234 2258 2360 2422 2440 2471 2482 2483 2503 2553 2559 2604 2627 2673
#  2687 2720 2738 2808 2824 2878 2925 2959 3012 3018 3034 3037 3051 3079
#  3114 3118 3142 3208 3217 3310 3344 3349 3371 3380 3381 3395 3477 3498
#  3534 3538 3556 3571 3677 3683 3701 3782 3827 3855 3863 3869 3938 3955
#  3971 4019 4030 4036 4051 4075 4131 4267 4331] with [ 66   7   2   1   9  17   1 267   2  63  26   1   1 173   1   1   3   1
#    4   3  13  10   2   2   1   1   1   4   2   2   1  24   1 259   1   1
#    1  73   1   1 108   1   1   2   1  41   1   1   1   1   4   1 318  34
#    1   1   1   2  75   4  35   2   2  91  28  98  39  26   1   2   1  33
#    2   1   2   1   1  19   2   1   3   3   1   1   2   1   2   1  25   1
#    1  77  24   1  35   2   1   1   7  25   2  60   1  14   1   1   1   1
#    1   2   2  10   7   2   2   2  34   3   2   1   2] in total 121
# INFO:kgcnn.data.Mutagenicity:Checking database...
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 66} from molecule 38
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 7} from molecule 133
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 9} from molecule 220
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 17} from molecule 246
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 170, 'C': 52, 'N': 17, 'O': 24, 'S': 4} from molecule 278
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 63} from molecule 296
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 26} from molecule 302
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 126, 'C': 42, 'N': 1, 'O': 4} from molecule 339
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 13} from molecule 743
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 10} from molecule 783
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 24} from molecule 1085
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 168, 'C': 50, 'N': 19, 'O': 20, 'S': 2} from molecule 1233
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 73} from molecule 1525
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 99, 'C': 7, 'N': 1, 'Cl': 1} from molecule 1609
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 41} from molecule 2024
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 203, 'C': 65, 'N': 28, 'O': 21, 'S': 1} from molecule 2143
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 34} from molecule 2174
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 75} from molecule 2360
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 4} from molecule 2422
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 35} from molecule 2440
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 88, 'C': 3} from molecule 2483
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 28} from molecule 2503
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 95, 'C': 3} from molecule 2553
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 39} from molecule 2559
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 25, 'N': 1} from molecule 2604
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 33} from molecule 2720
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 19} from molecule 2959
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 25} from molecule 3217
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 77} from molecule 3349
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 24} from molecule 3371
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 35} from molecule 3381
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 7} from molecule 3534
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 25} from molecule 3538
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 60} from molecule 3571
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 14} from molecule 3683
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 10} from molecule 3955
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 5} from molecule 3971
# INFO:kgcnn.data.Mutagenicity:Removing unconnected {'H': 34} from molecule 4051
# INFO:kgcnn.data.Mutagenicity:Database still has unconnected Na+, Li+, ksb+ etc.
# C:\Users\Patrick\AppData\Local\Temp/ipykernel_13188/3749465830.py:9: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   , dtype=np.int) # Make One-Hot encoding
# [TensorShape([3469, None, 14]), TensorShape([3469, None, 1]), TensorShape([3469, None, 2])]
# [TensorShape([868, None, 14]), TensorShape([868, None, 1]), TensorShape([868, None, 2])]
# (3469, 1, 1) (868, 1, 1)

# %% [markdown]
# ## Load and train model

# %%
model_args = {
    'name': "GCN",
    'inputs': [{'shape': (None, 14), 'name': "node_attributes", 'dtype': 'float32', 'ragged': True},
            {'shape': (None, 1), 'name': "edge_attributes", 'dtype': 'float32', 'ragged': True},
            {'shape': (None, 2), 'name': "edge_indices", 'dtype': 'int64', 'ragged': True}],
    'input_embedding': {"node": {"input_dim": 55, "output_dim": 64},
                     "edge": {"input_dim": 10, "output_dim": 64}},
    'gcn_args': {"units": 64, "use_bias": True, "activation": 'relu', "pooling_method": 'mean',
              "is_sorted": False, "has_unconnected": True},
    'depth': 3, 'verbose': 10,
    'output_embedding': 'graph',
    'output_mlp': {"use_bias": [True, True, False], "units": [140, 70, 1],
                "activation": ['relu', 'relu', 'sigmoid']}
}
model_args2 = {
    'name': "GCN_weighted",
    'inputs': [{'shape': (None, 14), 'name': "node_attributes", 'dtype': 'float32', 'ragged': True},
             {'shape': (None, 1), 'name': "edge_attributes", 'dtype': 'float32', 'ragged': True},
             {'shape': (None, 2), 'name': "edge_indices", 'dtype': 'int64', 'ragged': True},
             {'shape': (None, 1), 'name': "node_weights", 'dtype': 'float32', 'ragged': True}],
    'input_embedding': {"node": {"input_dim": 55, "output_dim": 64},
                      "edge": {"input_dim": 10, "output_dim": 64}},
    'gcn_args': {"units": 64, "use_bias": True, "activation": 'relu', "pooling_method": 'mean',
               "is_sorted": False, "has_unconnected": True},
    'depth': 3, 'verbose': 10,
    'output_embedding': 'graph',
    'output_mlp': {"use_bias": [True, True, False], "units": [140, 70, 1],
                 "activation": ['relu', 'relu', 'sigmoid']}
}
model = make_model(**model_args)
model_node_weights = make_model_weighted(**model_args2)
# Set learning rate and epochs
learning_rate_start = 1e-3
learning_rate_stop = 1e-4
epo = 150
epomin = 100
epostep = 10

# Compile model with optimizer and loss
optimizer = tf.keras.optimizers.Adam(lr=learning_rate_start)
cbks = LinearLearningRateScheduler(learning_rate_start, learning_rate_stop, epomin, epo)
model.compile(loss='binary_crossentropy',
              optimizer=optimizer,
              weighted_metrics=['accuracy'])
print(model.summary())

# Start and time training
start = time.process_time()
hist = model.fit(xtrain, ytrain,
                 epochs=epo,
                 batch_size=32,
                 callbacks=[cbks],
                 validation_freq=epostep,
                 validation_data=(xtest, ytest),
                 verbose=2
                 )
stop = time.process_time()
print("Print Time for taining: ", stop - start)

# Get loss from history
trainlossall = np.array(hist.history['accuracy'])
testlossall = np.array(hist.history['val_accuracy'])
acc_valid = testlossall[-1]

# Plot loss vs epochs
plt.figure()
plt.plot(np.arange(trainlossall.shape[0]), trainlossall, label='Training ACC', c='blue')
plt.plot(np.arange(epostep, epo + epostep, epostep), testlossall, label='Test ACC', c='red')
plt.scatter([trainlossall.shape[0]], [acc_valid], label="{0:0.4f} ".format(acc_valid), c='red')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Interaction Network Loss')
plt.legend(loc='upper right', fontsize='x-large')
plt.savefig('gcn_explain_mutag_2.png')
plt.show()
# Out:
# INFO:kgcnn.utils.models:Updated model kwargs:
# INFO:kgcnn.utils.models:{'name': 'GCN', 'inputs': [{'shape': (None, 14), 'name': 'node_attributes', 'dtype': 'float32', 'ragged': True}, {'shape': (None, 1), 'name': 'edge_attributes', 'dtype': 'float32', 'ragged': True}, {'shape': (None, 2), 'name': 'edge_indices', 'dtype': 'int64', 'ragged': True}], 'input_embedding': {'node': {'input_dim': 55, 'output_dim': 64}, 'edge': {'input_dim': 10, 'output_dim': 64}}, 'gcn_args': {'units': 64, 'use_bias': True, 'activation': 'relu', 'pooling_method': 'mean', 'is_sorted': False, 'has_unconnected': True}, 'depth': 3, 'verbose': 10, 'output_embedding': 'graph', 'output_mlp': {'use_bias': [True, True, False], 'units': [140, 70, 1], 'activation': ['relu', 'relu', 'sigmoid']}}
# WARNING:kgcnn.utils.models:Unknown model kwarg is_sorted with value False
# WARNING:kgcnn.utils.models:Unknown model kwarg has_unconnected with value True
# INFO:kgcnn.utils.models:Updated model kwargs:
# INFO:kgcnn.utils.models:{'name': 'GCN_weighted', 'inputs': [{'shape': (None, 14), 'name': 'node_attributes', 'dtype': 'float32', 'ragged': True}, {'shape': (None, 1), 'name': 'edge_attributes', 'dtype': 'float32', 'ragged': True}, {'shape': (None, 2), 'name': 'edge_indices', 'dtype': 'int64', 'ragged': True}, {'shape': (None, 1), 'name': 'node_weights', 'dtype': 'float32', 'ragged': True}], 'input_embedding': {'node': {'input_dim': 55, 'output_dim': 64}, 'edge': {'input_dim': 10, 'output_dim': 64}}, 'output_embedding': 'graph', 'output_mlp': {'use_bias': [True, True, False], 'units': [140, 70, 1], 'activation': ['relu', 'relu', 'sigmoid']}, 'gcn_args': {'units': 64, 'use_bias': True, 'activation': 'relu', 'pooling_method': 'mean', 'is_sorted': False, 'has_unconnected': True}, 'depth': 3, 'verbose': 10}
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  node_attributes (InputLayer)   [(None, None, 14)]   0           []
#
#  optional_input_embedding (Opti  (None, None, 14)    0           ['node_attributes[0][0]']
#  onalInputEmbedding)
#
#  edge_attributes (InputLayer)   [(None, None, 1)]    0           []
#
#  dense_embedding (DenseEmbeddin  (None, None, 64)    960         ['optional_input_embedding[0][0]'
#  g)                                                              ]
#
#  optional_input_embedding_1 (Op  (None, None, 1)     0           ['edge_attributes[0][0]']
#  tionalInputEmbedding)
#
#  edge_indices (InputLayer)      [(None, None, 2)]    0           []
#
#  gcn (GCN)                      (None, None, 64)     4160        ['dense_embedding[0][0]',
#                                                                   'optional_input_embedding_1[0][0
#                                                                  ]',
#                                                                   'edge_indices[0][0]']
#
#  gcn_1 (GCN)                    (None, None, 64)     4160        ['gcn[0][0]',
#                                                                   'optional_input_embedding_1[0][0
#                                                                  ]',
#                                                                   'edge_indices[0][0]']
#
#  gcn_2 (GCN)                    (None, None, 64)     4160        ['gcn_1[0][0]',
#                                                                   'optional_input_embedding_1[0][0
#                                                                  ]',
#                                                                   'edge_indices[0][0]']
#
#  pooling_embedding (PoolingEmbe  (None, 64)          0           ['gcn_2[0][0]']
#  dding)
#
#  mlp (MLP)                      (None, 1)            19040       ['pooling_embedding[0][0]']
#
# ==================================================================================================
# Total params: 32,480
# Trainable params: 32,480
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/150
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn_2/pooling_weighted_local_edges_2/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/gcn_2/pooling_weighted_local_edges_2/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn_2/pooling_weighted_local_edges_2/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn_2/gather_nodes_outgoing_2/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/gcn_2/gather_nodes_outgoing_2/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn_2/gather_nodes_outgoing_2/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn_1/pooling_weighted_local_edges_1/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/gcn_1/pooling_weighted_local_edges_1/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn_1/pooling_weighted_local_edges_1/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn_1/gather_nodes_outgoing_1/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/gcn_1/gather_nodes_outgoing_1/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn_1/gather_nodes_outgoing_1/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn/pooling_weighted_local_edges/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/gcn/pooling_weighted_local_edges/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn/pooling_weighted_local_edges/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/gcn/gather_nodes_outgoing/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/gcn/gather_nodes_outgoing/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model/gcn/gather_nodes_outgoing/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# 109/109 - 3s - loss: 0.6614 - accuracy: 0.6005 - lr: 0.0010 - 3s/epoch - 27ms/step
# Epoch 2/150
# 109/109 - 1s - loss: 0.6225 - accuracy: 0.6780 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 3/150
# 109/109 - 1s - loss: 0.6039 - accuracy: 0.6846 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 4/150
# 109/109 - 1s - loss: 0.5784 - accuracy: 0.7022 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 5/150
# 109/109 - 1s - loss: 0.5532 - accuracy: 0.7189 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 6/150
# 109/109 - 1s - loss: 0.5349 - accuracy: 0.7336 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 7/150
# 109/109 - 1s - loss: 0.5296 - accuracy: 0.7322 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 8/150
# 109/109 - 1s - loss: 0.5233 - accuracy: 0.7414 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 9/150
# 109/109 - 1s - loss: 0.5191 - accuracy: 0.7455 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 10/150
# 109/109 - 2s - loss: 0.5036 - accuracy: 0.7619 - val_loss: 0.5302 - val_accuracy: 0.7339 - lr: 0.0010 - 2s/epoch - 17ms/step
# Epoch 11/150
# 109/109 - 1s - loss: 0.5066 - accuracy: 0.7564 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 12/150
# 109/109 - 1s - loss: 0.4926 - accuracy: 0.7553 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 13/150
# 109/109 - 1s - loss: 0.4934 - accuracy: 0.7573 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 14/150
# 109/109 - 1s - loss: 0.4888 - accuracy: 0.7607 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 15/150
# 109/109 - 1s - loss: 0.4814 - accuracy: 0.7651 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 16/150
# 109/109 - 1s - loss: 0.4821 - accuracy: 0.7625 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 17/150
# 109/109 - 1s - loss: 0.4756 - accuracy: 0.7651 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 18/150
# 109/109 - 1s - loss: 0.4768 - accuracy: 0.7633 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 19/150
# 109/109 - 1s - loss: 0.4760 - accuracy: 0.7662 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 20/150
# 109/109 - 1s - loss: 0.4708 - accuracy: 0.7682 - val_loss: 0.5086 - val_accuracy: 0.7465 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 21/150
# 109/109 - 1s - loss: 0.4648 - accuracy: 0.7731 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 22/150
# 109/109 - 1s - loss: 0.4629 - accuracy: 0.7639 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 23/150
# 109/109 - 1s - loss: 0.4588 - accuracy: 0.7763 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 24/150
# 109/109 - 1s - loss: 0.4572 - accuracy: 0.7752 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 25/150
# 109/109 - 1s - loss: 0.4523 - accuracy: 0.7838 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 26/150
# 109/109 - 1s - loss: 0.4493 - accuracy: 0.7783 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 27/150
# 109/109 - 1s - loss: 0.4594 - accuracy: 0.7786 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 28/150
# 109/109 - 1s - loss: 0.4530 - accuracy: 0.7875 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 29/150
# 109/109 - 1s - loss: 0.4560 - accuracy: 0.7829 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 30/150
# 109/109 - 1s - loss: 0.4434 - accuracy: 0.7919 - val_loss: 0.4984 - val_accuracy: 0.7650 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 31/150
# 109/109 - 1s - loss: 0.4461 - accuracy: 0.7881 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 32/150
# 109/109 - 1s - loss: 0.4407 - accuracy: 0.7910 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 33/150
# 109/109 - 1s - loss: 0.4374 - accuracy: 0.7884 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 34/150
# 109/109 - 1s - loss: 0.4321 - accuracy: 0.7991 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 35/150
# 109/109 - 1s - loss: 0.4300 - accuracy: 0.7936 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 36/150
# 109/109 - 1s - loss: 0.4264 - accuracy: 0.7945 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 37/150
# 109/109 - 1s - loss: 0.4284 - accuracy: 0.7979 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 38/150
# 109/109 - 1s - loss: 0.4254 - accuracy: 0.8008 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 39/150
# 109/109 - 1s - loss: 0.4171 - accuracy: 0.8086 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 40/150
# 109/109 - 1s - loss: 0.4184 - accuracy: 0.8017 - val_loss: 0.4770 - val_accuracy: 0.7604 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 41/150
# 109/109 - 1s - loss: 0.4235 - accuracy: 0.7973 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 42/150
# 109/109 - 1s - loss: 0.4072 - accuracy: 0.8161 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 43/150
# 109/109 - 1s - loss: 0.4063 - accuracy: 0.8095 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 44/150
# 109/109 - 1s - loss: 0.4074 - accuracy: 0.8097 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 45/150
# 109/109 - 1s - loss: 0.4136 - accuracy: 0.8014 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 46/150
# 109/109 - 1s - loss: 0.4057 - accuracy: 0.8069 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 47/150
# 109/109 - 1s - loss: 0.3933 - accuracy: 0.8129 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 48/150
# 109/109 - 1s - loss: 0.3916 - accuracy: 0.8126 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 49/150
# 109/109 - 1s - loss: 0.3871 - accuracy: 0.8210 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 50/150
# 109/109 - 1s - loss: 0.3818 - accuracy: 0.8213 - val_loss: 0.5381 - val_accuracy: 0.7396 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 51/150
# 109/109 - 1s - loss: 0.3919 - accuracy: 0.8187 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 52/150
# 109/109 - 1s - loss: 0.3850 - accuracy: 0.8187 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 53/150
# 109/109 - 1s - loss: 0.3892 - accuracy: 0.8210 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 54/150
# 109/109 - 1s - loss: 0.3818 - accuracy: 0.8311 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 55/150
# 109/109 - 1s - loss: 0.3746 - accuracy: 0.8262 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 56/150
# 109/109 - 1s - loss: 0.3728 - accuracy: 0.8314 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 57/150
# 109/109 - 1s - loss: 0.3620 - accuracy: 0.8377 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 58/150
# 109/109 - 1s - loss: 0.3685 - accuracy: 0.8337 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 59/150
# 109/109 - 1s - loss: 0.3615 - accuracy: 0.8377 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 60/150
# 109/109 - 1s - loss: 0.3674 - accuracy: 0.8377 - val_loss: 0.4946 - val_accuracy: 0.7696 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 61/150
# 109/109 - 1s - loss: 0.3534 - accuracy: 0.8415 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 62/150
# 109/109 - 1s - loss: 0.3609 - accuracy: 0.8368 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 63/150
# 109/109 - 1s - loss: 0.3536 - accuracy: 0.8426 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 64/150
# 109/109 - 1s - loss: 0.3608 - accuracy: 0.8340 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 65/150
# 109/109 - 1s - loss: 0.3482 - accuracy: 0.8458 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 66/150
# 109/109 - 1s - loss: 0.3424 - accuracy: 0.8484 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 67/150
# 109/109 - 1s - loss: 0.3441 - accuracy: 0.8478 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 68/150
# 109/109 - 1s - loss: 0.3363 - accuracy: 0.8446 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 69/150
# 109/109 - 1s - loss: 0.3323 - accuracy: 0.8547 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 70/150
# 109/109 - 1s - loss: 0.3315 - accuracy: 0.8510 - val_loss: 0.5194 - val_accuracy: 0.7938 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 71/150
# 109/109 - 1s - loss: 0.3415 - accuracy: 0.8429 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 72/150
# 109/109 - 1s - loss: 0.3197 - accuracy: 0.8530 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 73/150
# 109/109 - 1s - loss: 0.3211 - accuracy: 0.8550 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 74/150
# 109/109 - 1s - loss: 0.3171 - accuracy: 0.8611 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 75/150
# 109/109 - 1s - loss: 0.3157 - accuracy: 0.8567 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 76/150
# 109/109 - 1s - loss: 0.3184 - accuracy: 0.8582 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 77/150
# 109/109 - 1s - loss: 0.3246 - accuracy: 0.8579 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 78/150
# 109/109 - 1s - loss: 0.3130 - accuracy: 0.8636 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 79/150
# 109/109 - 1s - loss: 0.3158 - accuracy: 0.8608 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 80/150
# 109/109 - 1s - loss: 0.3044 - accuracy: 0.8657 - val_loss: 0.5496 - val_accuracy: 0.7638 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 81/150
# 109/109 - 1s - loss: 0.3111 - accuracy: 0.8645 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 82/150
# 109/109 - 1s - loss: 0.3035 - accuracy: 0.8625 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 83/150
# 109/109 - 1s - loss: 0.3005 - accuracy: 0.8662 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 84/150
# 109/109 - 1s - loss: 0.2987 - accuracy: 0.8717 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 85/150
# 109/109 - 1s - loss: 0.2884 - accuracy: 0.8786 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 86/150
# 109/109 - 1s - loss: 0.2879 - accuracy: 0.8763 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 87/150
# 109/109 - 1s - loss: 0.2795 - accuracy: 0.8815 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 88/150
# 109/109 - 1s - loss: 0.3050 - accuracy: 0.8703 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 89/150
# 109/109 - 1s - loss: 0.2871 - accuracy: 0.8775 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 90/150
# 109/109 - 1s - loss: 0.2639 - accuracy: 0.8910 - val_loss: 0.5839 - val_accuracy: 0.7823 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 91/150
# 109/109 - 1s - loss: 0.2795 - accuracy: 0.8766 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 92/150
# 109/109 - 1s - loss: 0.2827 - accuracy: 0.8769 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 93/150
# 109/109 - 1s - loss: 0.2729 - accuracy: 0.8830 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 94/150
# 109/109 - 1s - loss: 0.2713 - accuracy: 0.8847 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 95/150
# 109/109 - 1s - loss: 0.2764 - accuracy: 0.8789 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 96/150
# 109/109 - 1s - loss: 0.2756 - accuracy: 0.8833 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 97/150
# 109/109 - 1s - loss: 0.2554 - accuracy: 0.8925 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 98/150
# 109/109 - 1s - loss: 0.2555 - accuracy: 0.8893 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 99/150
# 109/109 - 1s - loss: 0.2544 - accuracy: 0.8933 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 100/150
# 109/109 - 1s - loss: 0.2527 - accuracy: 0.8893 - val_loss: 0.6264 - val_accuracy: 0.7834 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 101/150
# 109/109 - 1s - loss: 0.2477 - accuracy: 0.8916 - lr: 0.0010 - 1s/epoch - 10ms/step
# Epoch 102/150
# 109/109 - 1s - loss: 0.2449 - accuracy: 0.9003 - lr: 9.8200e-04 - 1s/epoch - 10ms/step
# Epoch 103/150
# 109/109 - 1s - loss: 0.2436 - accuracy: 0.8919 - lr: 9.6400e-04 - 1s/epoch - 10ms/step
# Epoch 104/150
# 109/109 - 1s - loss: 0.2363 - accuracy: 0.8994 - lr: 9.4600e-04 - 1s/epoch - 10ms/step
# Epoch 105/150
# 109/109 - 1s - loss: 0.2829 - accuracy: 0.8890 - lr: 9.2800e-04 - 1s/epoch - 10ms/step
# Epoch 106/150
# 109/109 - 1s - loss: 0.2594 - accuracy: 0.8956 - lr: 9.1000e-04 - 1s/epoch - 10ms/step
# Epoch 107/150
# 109/109 - 1s - loss: 0.2474 - accuracy: 0.8959 - lr: 8.9200e-04 - 1s/epoch - 10ms/step
# Epoch 108/150
# 109/109 - 1s - loss: 0.2311 - accuracy: 0.9060 - lr: 8.7400e-04 - 1s/epoch - 10ms/step
# Epoch 109/150
# 109/109 - 1s - loss: 0.2221 - accuracy: 0.9066 - lr: 8.5600e-04 - 1s/epoch - 10ms/step
# Epoch 110/150
# 109/109 - 1s - loss: 0.2197 - accuracy: 0.9066 - val_loss: 0.6600 - val_accuracy: 0.7776 - lr: 8.3800e-04 - 1s/epoch - 12ms/step
# Epoch 111/150
# 109/109 - 1s - loss: 0.2299 - accuracy: 0.9017 - lr: 8.2000e-04 - 1s/epoch - 10ms/step
# Epoch 112/150
# 109/109 - 1s - loss: 0.2231 - accuracy: 0.9057 - lr: 8.0200e-04 - 1s/epoch - 10ms/step
# Epoch 113/150
# 109/109 - 1s - loss: 0.2067 - accuracy: 0.9109 - lr: 7.8400e-04 - 1s/epoch - 10ms/step
# Epoch 114/150
# 109/109 - 1s - loss: 0.1984 - accuracy: 0.9173 - lr: 7.6600e-04 - 1s/epoch - 10ms/step
# Epoch 115/150
# 109/109 - 1s - loss: 0.2010 - accuracy: 0.9176 - lr: 7.4800e-04 - 1s/epoch - 10ms/step
# Epoch 116/150
# 109/109 - 1s - loss: 0.1959 - accuracy: 0.9204 - lr: 7.3000e-04 - 1s/epoch - 10ms/step
# Epoch 117/150
# 109/109 - 1s - loss: 0.1877 - accuracy: 0.9256 - lr: 7.1200e-04 - 1s/epoch - 10ms/step
# Epoch 118/150
# 109/109 - 1s - loss: 0.1871 - accuracy: 0.9236 - lr: 6.9400e-04 - 1s/epoch - 10ms/step
# Epoch 119/150
# 109/109 - 1s - loss: 0.1858 - accuracy: 0.9230 - lr: 6.7600e-04 - 1s/epoch - 10ms/step
# Epoch 120/150
# 109/109 - 1s - loss: 0.1825 - accuracy: 0.9239 - val_loss: 0.6703 - val_accuracy: 0.7857 - lr: 6.5800e-04 - 1s/epoch - 12ms/step
# Epoch 121/150
# 109/109 - 1s - loss: 0.1762 - accuracy: 0.9297 - lr: 6.4000e-04 - 1s/epoch - 10ms/step
# Epoch 122/150
# 109/109 - 1s - loss: 0.1804 - accuracy: 0.9242 - lr: 6.2200e-04 - 1s/epoch - 10ms/step
# Epoch 123/150
# 109/109 - 1s - loss: 0.1735 - accuracy: 0.9230 - lr: 6.0400e-04 - 1s/epoch - 10ms/step
# Epoch 124/150
# 109/109 - 1s - loss: 0.1770 - accuracy: 0.9227 - lr: 5.8600e-04 - 1s/epoch - 10ms/step
# Epoch 125/150
# 109/109 - 1s - loss: 0.1596 - accuracy: 0.9346 - lr: 5.6800e-04 - 1s/epoch - 10ms/step
# Epoch 126/150
# 109/109 - 1s - loss: 0.1615 - accuracy: 0.9369 - lr: 5.5000e-04 - 1s/epoch - 10ms/step
# Epoch 127/150
# 109/109 - 1s - loss: 0.1637 - accuracy: 0.9331 - lr: 5.3200e-04 - 1s/epoch - 10ms/step
# Epoch 128/150
# 109/109 - 1s - loss: 0.1648 - accuracy: 0.9305 - lr: 5.1400e-04 - 1s/epoch - 10ms/step
# Epoch 129/150
# 109/109 - 1s - loss: 0.1494 - accuracy: 0.9418 - lr: 4.9600e-04 - 1s/epoch - 10ms/step
# Epoch 130/150
# 109/109 - 1s - loss: 0.1560 - accuracy: 0.9357 - val_loss: 0.7974 - val_accuracy: 0.7696 - lr: 4.7800e-04 - 1s/epoch - 12ms/step
# Epoch 131/150
# 109/109 - 1s - loss: 0.1554 - accuracy: 0.9386 - lr: 4.6000e-04 - 1s/epoch - 10ms/step
# Epoch 132/150
# 109/109 - 1s - loss: 0.1486 - accuracy: 0.9398 - lr: 4.4200e-04 - 1s/epoch - 10ms/step
# Epoch 133/150
# 109/109 - 1s - loss: 0.1461 - accuracy: 0.9392 - lr: 4.2400e-04 - 1s/epoch - 10ms/step
# Epoch 134/150
# 109/109 - 1s - loss: 0.1404 - accuracy: 0.9444 - lr: 4.0600e-04 - 1s/epoch - 10ms/step
# Epoch 135/150
# 109/109 - 1s - loss: 0.1347 - accuracy: 0.9464 - lr: 3.8800e-04 - 1s/epoch - 10ms/step
# Epoch 136/150
# 109/109 - 1s - loss: 0.1288 - accuracy: 0.9519 - lr: 3.7000e-04 - 1s/epoch - 10ms/step
# Epoch 137/150
# 109/109 - 1s - loss: 0.1274 - accuracy: 0.9472 - lr: 3.5200e-04 - 1s/epoch - 10ms/step
# Epoch 138/150
# 109/109 - 1s - loss: 0.1277 - accuracy: 0.9527 - lr: 3.3400e-04 - 1s/epoch - 10ms/step
# Epoch 139/150
# 109/109 - 1s - loss: 0.1266 - accuracy: 0.9527 - lr: 3.1600e-04 - 1s/epoch - 10ms/step
# Epoch 140/150
# 109/109 - 1s - loss: 0.1260 - accuracy: 0.9487 - val_loss: 0.8731 - val_accuracy: 0.7742 - lr: 2.9800e-04 - 1s/epoch - 12ms/step
# Epoch 141/150
# 109/109 - 1s - loss: 0.1200 - accuracy: 0.9519 - lr: 2.8000e-04 - 1s/epoch - 10ms/step
# Epoch 142/150
# 109/109 - 1s - loss: 0.1145 - accuracy: 0.9559 - lr: 2.6200e-04 - 1s/epoch - 10ms/step
# Epoch 143/150
# 109/109 - 1s - loss: 0.1150 - accuracy: 0.9559 - lr: 2.4400e-04 - 1s/epoch - 10ms/step
# Epoch 144/150
# 109/109 - 1s - loss: 0.1134 - accuracy: 0.9565 - lr: 2.2600e-04 - 1s/epoch - 10ms/step
# Epoch 145/150
# 109/109 - 1s - loss: 0.1073 - accuracy: 0.9588 - lr: 2.0800e-04 - 1s/epoch - 10ms/step
# Epoch 146/150
# 109/109 - 1s - loss: 0.1057 - accuracy: 0.9599 - lr: 1.9000e-04 - 1s/epoch - 10ms/step
# Epoch 147/150
# 109/109 - 1s - loss: 0.1046 - accuracy: 0.9605 - lr: 1.7200e-04 - 1s/epoch - 10ms/step
# Epoch 148/150
# 109/109 - 1s - loss: 0.1022 - accuracy: 0.9654 - lr: 1.5400e-04 - 1s/epoch - 10ms/step
# Epoch 149/150
# 109/109 - 1s - loss: 0.0993 - accuracy: 0.9628 - lr: 1.3600e-04 - 1s/epoch - 10ms/step
# Epoch 150/150
# 109/109 - 1s - loss: 0.0990 - accuracy: 0.9645 - val_loss: 0.9062 - val_accuracy: 0.7880 - lr: 1.1800e-04 - 1s/epoch - 12ms/step
# Print Time for taining:  274.984375

# %% [markdown]
# ## We have to implement the ExplainableGCN from the GNNInterface

# %%
class ExplainableGCN(GNNInterface):

    def __init__(self, gnn_model, **kwargs):
        super(ExplainableGCN, self).__init__()

        # Here we modify the gcn model to allow node weights
        self.gnn_model = gnn_model

    def predict(self, gnn_input, masking_info=None):
        node_input, edge_input, edge_index_input = gnn_input
        node_weights = tf.RaggedTensor.from_row_splits(tf.expand_dims(tf.ones_like(node_input.values)[:,0],axis=-1), node_input.row_splits)
        return self.gnn_model([node_input, edge_input, edge_index_input, node_weights], training=False)[0]

    def masked_predict(self, gnn_input, edge_mask, feature_mask, node_mask, training=False):
        node_input, edge_input, edge_index_input = gnn_input

        masked_edge_input = edge_mask * edge_input[0]
        masked_edge_input = tf.RaggedTensor.from_row_splits(masked_edge_input, [0, len(masked_edge_input)])
        masked_feature_input = tf.ragged.map_flat_values(tf.math.multiply, tf.dtypes.cast(node_input, tf.float32),
                                                         tf.transpose(feature_mask))
        node_weights = tf.RaggedTensor.from_row_splits(tf.sigmoid(node_mask), np.array([0, len(node_mask)],dtype=np.int))

        masked_pred = self.gnn_model([masked_feature_input, masked_edge_input, edge_index_input, node_weights],
                                     training=training)[0]
        return masked_pred

    def get_number_of_nodes(self, gnn_input):
        node_input, _, _ = gnn_input
        return node_input[0].shape[0]

    def get_number_of_node_features(self, gnn_input):
        node_input, _, _ = gnn_input
        return node_input.shape[2]

    def get_number_of_edges(self, gnn_input):
        _, edge_input, _ = gnn_input
        return edge_input[0].shape[0]

    def get_explanation(self, gnn_input, edge_mask, feature_mask, node_mask):
        edge_relevance = np.array(edge_mask[:, 0])
        node_relevance = np.array(node_mask[:, 0])
        feature_relevance = np.array(feature_mask[:, 0])
        features = np.array(gnn_input[0][0])
        edges = np.array(gnn_input[2][0])
        graph = nx.Graph()
        for i, f in enumerate(features):
            graph.add_node(i, features=f, relevance=node_relevance[i])
        for i, e in enumerate(edges):
            if edge_relevance is None:
                graph.add_edge(e[0], e[1])
            else:
                graph.add_edge(e[0], e[1], relevance=edge_relevance[i])
        return graph, feature_relevance

    def present_explanation(self, explanation, threshold=0.5):
        graph = explanation[0]
        # element_labels = np.array([[ 1,  3,  6,  7,  8,  9, 11, 15, 16, 17, 19, 20, 35, 53]])
        element_labels = ['H', 'Li', 'C', 'N', 'O', 'F', 'Na', 'P', 'S', 'Cl', 'K', 'Ca', 'Br', 'I']
        important_edges = []
        color_map = []
        node_color_map = []
        node_labels = {}
        for (u, v, relevance) in graph.edges.data('relevance'):
            relevance = min(relevance + 0.1, 1.0)
            color_map.append((0, 0, 0, relevance))
        for n, f in graph.nodes.data('features'):
            element = np.argmax(f)
            r, g, b, a = plt.get_cmap('tab20')(element)
            node_color_map.append((r, g, b, graph.nodes[n]['relevance']))
            node_labels[n] = (element_labels[element])
        if np.all(explanation[1] == 1):
            nx.draw_kamada_kawai(graph, edge_color=color_map, labels=node_labels, node_color=node_color_map)
        else:
            f, axs = plt.subplots(2, figsize=(8, 12))
            nx.draw_kamada_kawai(graph, ax=axs[0], edge_color=color_map, labels=node_labels, node_color=node_color_map)
            bar_colors = [plt.get_cmap('tab20')(element) for element in np.arange(14)]
            axs[1].bar(np.array(element_labels), explanation[1], color=bar_colors)

# %%
# Transfer weights
model_node_weights.set_weights(model.get_weights())
# Instanciate a Explainable GNN:
explainable_gcn = ExplainableGCN(model_node_weights)

# %%
# Find the 100 most mutagenic molecules, according to the GNN:
pred = model.predict(xtest)[:,0]
print(np.argsort(pred)[:100])

# Select instance to explain
instance_index = 297
# Out:
# [ 63 652 333  68 466 500  90 602 537 775 126 848 653 379  85 709 862 143
#   35 543  55 584 804 176 595 272 105 733 534 448 418 779 805 443 312 317
#  524 761 807 859 334 116 839 412 303 196  27 170 496 554 248  43 302  87
#  212 736 313 615 808 387 444 138  44 811 344  18 367 857  59 809 706 512
#   16 467 635  28 369 567 737 818 103 118 703  67  34 276 324 549 596 347
#  284 553 233 451 401 256  26 478 134 388]

# %% [markdown]
# Setup an GNNExplainer and explain the instance:

# %%
compile_options = {'loss': 'binary_crossentropy', 'optimizer': tf.keras.optimizers.Adam(lr=0.1)}
fit_options={'epochs': 100, 'batch_size': 1, 'verbose': 0}
gnnexplaineroptimizer_options = {'edge_mask_loss_weight': 0.005,
                 'edge_mask_norm_ord': 1,
                 'feature_mask_loss_weight': 0.0001,
                 'feature_mask_norm_ord': 1,
                 'node_mask_loss_weight': 0.0001,
                 'node_mask_norm_ord': 1}

explainer = GNNExplainer(explainable_gcn,
                              compile_options=compile_options,
                              fit_options=fit_options,
                              gnnexplaineroptimizer_options=gnnexplaineroptimizer_options)

explainer.explain([tensor[instance_index:instance_index+1] for tensor in xtest])
#explainer.explain([tensor[instance_index:instance_index+1] for tensor in xtest], output_to_explain=tf.Variable([0.]))
# Out:
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# C:\Users\Patrick\AppData\Local\Temp\__autograph_generated_filemj89c2y1.py:14: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   node_weights = ag__.converted_call(ag__.ld(tf).RaggedTensor.from_row_splits, (ag__.converted_call(ag__.ld(tf).sigmoid, (ag__.ld(node_mask),), None, fscope), ag__.converted_call(ag__.ld(np).array, ([0, ag__.converted_call(ag__.ld(len), (ag__.ld(node_mask),), None, fscope)],), dict(dtype=ag__.ld(np).int), fscope)), None, fscope)
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gnn_explainer_optimizer/model_1/gcn_5/gather_nodes_outgoing_5/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gnn_explainer_optimizer/model_1/gcn_5/gather_nodes_outgoing_5/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/gnn_explainer_optimizer/model_1/gcn_5/gather_nodes_outgoing_5/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gnn_explainer_optimizer/model_1/gcn_4/gather_nodes_outgoing_4/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gnn_explainer_optimizer/model_1/gcn_4/gather_nodes_outgoing_4/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/gnn_explainer_optimizer/model_1/gcn_4/gather_nodes_outgoing_4/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gnn_explainer_optimizer/model_1/gcn_3/gather_nodes_outgoing_3/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gnn_explainer_optimizer/model_1/gcn_3/gather_nodes_outgoing_3/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/gnn_explainer_optimizer/model_1/gcn_3/gather_nodes_outgoing_3/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(

# %%
# Let's look at the explanation the GNNExplainer found:
plt.figure()
explainer.present_explanation(explainer.get_explanation(), threshold=0.5)
plt.show()

# %% [markdown]
# If we do not specify the output_to_explain as parameter to the explain method the Explainer
# will explain why the GNN came to its conclusion.
# For molecules which are classified as non-mutagenic by the GNN,
# the GNNExplainer will then explain why they are non-mutagenic.
# We can also specify output_to_explain to be tf.Variable([0.]).
# This way we can tell the Explainer to explain why a molecule could be mutagenic
# even for molecules which are classified as most likely non-mutagenic by the GNN):

# %%
plt.figure()
explainer.explain([tensor[instance_index:instance_index+1] for tensor in xtest], output_to_explain=tf.Variable([0.]))
explainer.present_explanation(explainer.get_explanation(), threshold=0.5)
plt.show()
# Out:
# C:\Users\Patrick\AppData\Local\Temp\__autograph_generated_filemj89c2y1.py:14: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   node_weights = ag__.converted_call(ag__.ld(tf).RaggedTensor.from_row_splits, (ag__.converted_call(ag__.ld(tf).sigmoid, (ag__.ld(node_mask),), None, fscope), ag__.converted_call(ag__.ld(np).array, ([0, ag__.converted_call(ag__.ld(len), (ag__.ld(node_mask),), None, fscope)],), dict(dtype=ag__.ld(np).int), fscope)), None, fscope)
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gnn_explainer_optimizer_1/model_1/gcn_5/gather_nodes_outgoing_5/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gnn_explainer_optimizer_1/model_1/gcn_5/gather_nodes_outgoing_5/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/gnn_explainer_optimizer_1/model_1/gcn_5/gather_nodes_outgoing_5/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gnn_explainer_optimizer_1/model_1/gcn_4/gather_nodes_outgoing_4/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gnn_explainer_optimizer_1/model_1/gcn_4/gather_nodes_outgoing_4/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/gnn_explainer_optimizer_1/model_1/gcn_4/gather_nodes_outgoing_4/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# C:\Users\Patrick\.conda\envs\gcnn_keras_test\lib\site-packages\tensorflow\python\framework\indexed_slices.py:448: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gnn_explainer_optimizer_1/model_1/gcn_3/gather_nodes_outgoing_3/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gnn_explainer_optimizer_1/model_1/gcn_3/gather_nodes_outgoing_3/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/gnn_explainer_optimizer_1/model_1/gcn_3/gather_nodes_outgoing_3/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
